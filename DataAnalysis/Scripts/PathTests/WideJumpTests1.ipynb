# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'WideJumpTests1'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(2, 2), 
    quantizationFactor=(3, 5), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 86
# GoalDistanceFlood: Start Position: (18.3700011, -24.48), Goal Positions: [(5.5, 5.5)], Goal Distance: 41.5
# PlotTensor: 0 42

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=999999)
# Skipped 2662 paths in 5.13 seconds
# Starting search: ActionPathFinder (iteration=38, hf=0.91, queue=195, seen=118, last=999999)
# Skipped 5137 paths in 10.29 seconds
# Starting search: ActionPathFinder (iteration=112, hf=0.92, queue=198, seen=176, last=999999)
# Skipped 7588 paths in 15.34 seconds
# Starting search: ActionPathFinder (iteration=181, hf=0.93, queue=234, seen=257, last=999999)
# Found path ActionPath(state=Undefined, g=275, h=3.0) in 18.49 seconds after 219 iterations and 9142 skipped paths
# Starting search: ActionPathFinder (iteration=219, hf=0.94, queue=263, seen=303, last=275)
# Found path ActionPath(state=Undefined, g=272, h=3.0) in 18.49 seconds after 220 iterations and 9142 skipped paths
# Starting search: ActionPathFinder (iteration=220, hf=0.95, queue=262, seen=304, last=272)
# Found path ActionPath(state=Undefined, g=266, h=3.0) in 18.49 seconds after 228 iterations and 9149 skipped paths
# Starting search: ActionPathFinder (iteration=228, hf=0.96, queue=260, seen=309, last=266)
# Found path ActionPath(state=Undefined, g=265, h=3.0) in 18.49 seconds after 234 iterations and 9153 skipped paths
# Starting search: ActionPathFinder (iteration=234, hf=0.97, queue=254, seen=311, last=265)
# Found path ActionPath(state=Undefined, g=264, h=3.0) in 18.49 seconds after 239 iterations and 9157 skipped paths
# Starting search: ActionPathFinder (iteration=239, hf=0.98, queue=249, seen=311, last=264)
# Skipped 12972 paths in 23.76 seconds
# Starting search: ActionPathFinder (iteration=274, hf=0.99, queue=226, seen=327, last=264)
# Skipped 15792 paths in 29.02 seconds
# Starting search: ActionPathFinder (iteration=286, hf=0.9, queue=216, seen=327, last=264)
# Skipped 19612 paths in 34.26 seconds
# Starting search: ActionPathFinder (iteration=323, hf=0.91, queue=198, seen=327, last=264)
# Skipped 23628 paths in 39.49 seconds
# Starting search: ActionPathFinder (iteration=354, hf=0.92, queue=176, seen=332, last=264)
# Skipped 28619 paths in 44.63 seconds
# Starting search: ActionPathFinder (iteration=409, hf=0.93, queue=168, seen=351, last=264)
# Skipped 32645 paths in 50.02 seconds
# Starting search: ActionPathFinder (iteration=483, hf=0.94, queue=221, seen=356, last=264)
# Skipped 34817 paths in 55.08 seconds
# Starting search: ActionPathFinder (iteration=558, hf=0.95, queue=213, seen=356, last=264)
# Skipped 36978 paths in 60.2 seconds
# Starting search: ActionPathFinder (iteration=612, hf=0.96, queue=214, seen=356, last=264)
# Found path ActionPath(state=Undefined, g=263, h=3.0) in 61.37 seconds after 627 iterations and 37943 skipped paths
# Starting search: ActionPathFinder (iteration=627, hf=0.97, queue=222, seen=356, last=263)
# Found path ActionPath(state=Undefined, g=262, h=3.0) in 61.37 seconds after 628 iterations and 37947 skipped paths
# Starting search: ActionPathFinder (iteration=628, hf=0.98, queue=221, seen=356, last=262)
# Found path ActionPath(state=Undefined, g=261, h=3.0) in 61.37 seconds after 629 iterations and 37951 skipped paths
# Starting search: ActionPathFinder (iteration=629, hf=0.99, queue=220, seen=356, last=261)
# Skipped 41816 paths in 66.58 seconds
# Starting search: ActionPathFinder (iteration=661, hf=0.9, queue=206, seen=356, last=261)
# Skipped 46466 paths in 71.8 seconds
# Starting search: ActionPathFinder (iteration=738, hf=0.91, queue=181, seen=358, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.92, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.93, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.94, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.95, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.96, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.97, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.98, queue=0, seen=363, last=261)
# Starting search: ActionPathFinder (iteration=946, hf=0.99, queue=0, seen=363, last=261)
# PlotTensor: 0 42

# %%
pathFinder.plotAnimation(fps=30, skipFrames=5)

break
# Out:
# 162
# PlotTensor: 0 42
#   Cell In[6], line 3
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 42
