# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'SimpleSpikeChallenge'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 49
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(-18.5, -1.5), (-18.5, -1.5)], Goal Distance: 21.5
# PlotTensor: 0 24

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Found path ActionPath(g=148, h=1.0, hVelocity=SprintLeft) in 1.79 seconds after 34 iterations and 2108 skipped paths
# Starting search: ActionPathFinder (iteration=34, hf=0.91, queue=92, seen=93, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Skipped 27723 paths in 6.87 seconds
# Starting search: ActionPathFinder (iteration=106, hf=0.92, queue=137, seen=128, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Skipped 55833 paths in 11.88 seconds
# Starting search: ActionPathFinder (iteration=166, hf=0.93, queue=83, seen=132, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Skipped 77868 paths in 16.9 seconds
# Starting search: ActionPathFinder (iteration=233, hf=0.94, queue=42, seen=141, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Starting search: ActionPathFinder (iteration=281, hf=0.95, queue=0, seen=145, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Starting search: ActionPathFinder (iteration=281, hf=0.96, queue=0, seen=145, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Starting search: ActionPathFinder (iteration=281, hf=0.97, queue=0, seen=145, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Starting search: ActionPathFinder (iteration=281, hf=0.98, queue=0, seen=145, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# Starting search: ActionPathFinder (iteration=281, hf=0.99, queue=0, seen=145, last=ActionPath(g=148, h=1.0, hVelocity=SprintLeft))
# PlotTensor: 0 24

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
