# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'SlideParcour1'           # Problem with wall clinging

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(1, 1), 
    # heuristicFactors=np.arange(0.9, 1.0, 0.01),
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 112
# GoalDistanceFlood: Start Position: (-26.6299989, 1.5200000999999999), Goal Positions: [(-19.5, 3.5), (-19.5, 3.5)], Goal Distance: 33.5
# PlotTensor: 0 55

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 1973 paths in 5.02 seconds
# Starting search: ActionPathFinder (iteration=26, hf=0.91, queue=161, seen=104, last=None)
# Skipped 6306 paths in 10.03 seconds
# Starting search: ActionPathFinder (iteration=103, hf=0.92, queue=148, seen=131, last=None)
# Skipped 13725 paths in 15.04 seconds
# Starting search: ActionPathFinder (iteration=157, hf=0.93, queue=246, seen=202, last=None)
# Found path ActionPath(g=250, h=-0.5, hVelocity=SprintLeft) in 15.8 seconds after 179 iterations and 15660 skipped paths
# Starting search: ActionPathFinder (iteration=179, hf=0.94, queue=243, seen=211, last=ActionPath(g=250, h=-0.5, hVelocity=SprintLeft))
# Found path ActionPath(g=248, h=2.0, hVelocity=WalkLeft) in 16.61 seconds after 191 iterations and 16305 skipped paths
# Starting search: ActionPathFinder (iteration=191, hf=0.95, queue=237, seen=218, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 21761 paths in 21.63 seconds
# Starting search: ActionPathFinder (iteration=249, hf=0.96, queue=196, seen=228, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 25847 paths in 27.0 seconds
# Starting search: ActionPathFinder (iteration=301, hf=0.97, queue=181, seen=242, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 32153 paths in 32.17 seconds
# Starting search: ActionPathFinder (iteration=329, hf=0.98, queue=170, seen=251, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 38257 paths in 37.34 seconds
# Starting search: ActionPathFinder (iteration=358, hf=0.99, queue=153, seen=259, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 43460 paths in 42.51 seconds
# Starting search: ActionPathFinder (iteration=396, hf=0.9, queue=153, seen=263, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Skipped 52693 paths in 47.84 seconds
# Starting search: ActionPathFinder (iteration=468, hf=0.91, queue=196, seen=263, last=ActionPath(g=248, h=2.0, hVelocity=WalkLeft))
# Found path ActionPath(g=236, h=-0.5, hVelocity=SprintLeft) in 47.84 seconds after 471 iterations and 52696 skipped paths
# Starting search: ActionPathFinder (iteration=471, hf=0.92, queue=196, seen=263, last=ActionPath(g=236, h=-0.5, hVelocity=SprintLeft))
# Found path ActionPath(g=234, h=2.0, hVelocity=WalkLeft) in 48.72 seconds after 483 iterations and 53341 skipped paths
# Starting search: ActionPathFinder (iteration=483, hf=0.93, queue=190, seen=263, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 59558 paths in 53.86 seconds
# Starting search: ActionPathFinder (iteration=544, hf=0.94, queue=151, seen=263, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 63733 paths in 59.05 seconds
# Starting search: ActionPathFinder (iteration=589, hf=0.95, queue=158, seen=270, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 69891 paths in 64.17 seconds
# Starting search: ActionPathFinder (iteration=633, hf=0.96, queue=144, seen=277, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 76533 paths in 69.37 seconds
# Starting search: ActionPathFinder (iteration=671, hf=0.97, queue=119, seen=283, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 83743 paths in 74.61 seconds
# Starting search: ActionPathFinder (iteration=701, hf=0.98, queue=105, seen=286, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 90623 paths in 79.82 seconds
# Starting search: ActionPathFinder (iteration=735, hf=0.99, queue=83, seen=293, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 97782 paths in 85.1 seconds
# Starting search: ActionPathFinder (iteration=767, hf=0.9, queue=61, seen=300, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 105740 paths in 90.47 seconds
# Starting search: ActionPathFinder (iteration=822, hf=0.91, queue=49, seen=314, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Skipped 112062 paths in 95.54 seconds
# Starting search: ActionPathFinder (iteration=862, hf=0.92, queue=22, seen=321, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.93, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.94, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.95, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.96, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.97, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.98, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# Starting search: ActionPathFinder (iteration=887, hf=0.99, queue=0, seen=324, last=ActionPath(g=234, h=2.0, hVelocity=WalkLeft))
# PlotTensor: 0 55

# %%
pathFinder.plotAnimation(fps=30, skipFrames=5)
break
# Out:
# 150
# PlotTensor: 0 55
#   Cell In[6], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 55

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
