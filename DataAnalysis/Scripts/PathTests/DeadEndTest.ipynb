# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'DeadEndTest'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Device used: cuda
# Flood fill steps: 194
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(17.5, -7.5)], Goal Distance: 64.5
# PlotTensor: 0 96

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 71810 paths in 7.8 seconds
# Starting search: ActionPathFinder (iteration=9, hf=0.91, queue=395, seen=307, last=None)
# Found path ActionPath(g=349, h=1.0, hVelocity=WalkLeft) in 7.8 seconds after 10 iterations and 71821 skipped paths
# Starting search: ActionPathFinder (iteration=10, hf=0.92, queue=401, seen=311, last=ActionPath(g=349, h=1.0, hVelocity=WalkLeft))
# Found path ActionPath(g=346, h=1.0, hVelocity=WalkLeft) in 10.82 seconds after 22 iterations and 74420 skipped paths
# Starting search: ActionPathFinder (iteration=22, hf=0.93, queue=404, seen=334, last=ActionPath(g=346, h=1.0, hVelocity=WalkLeft))
# Found path ActionPath(g=340, h=0.5, hVelocity=IdleRight) in 15.38 seconds after 41 iterations and 78700 skipped paths
# Starting search: ActionPathFinder (iteration=41, hf=0.94, queue=393, seen=346, last=ActionPath(g=340, h=0.5, hVelocity=IdleRight))
# Skipped 83420 paths in 20.48 seconds
# Starting search: ActionPathFinder (iteration=56, hf=0.95, queue=402, seen=348, last=ActionPath(g=340, h=0.5, hVelocity=IdleRight))
# Skipped 122557 paths in 26.44 seconds
# Starting search: ActionPathFinder (iteration=69, hf=0.96, queue=394, seen=351, last=ActionPath(g=340, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=335, h=1.0, hVelocity=IdleRight) in 26.99 seconds after 74 iterations and 123103 skipped paths
# Starting search: ActionPathFinder (iteration=74, hf=0.97, queue=409, seen=357, last=ActionPath(g=335, h=1.0, hVelocity=IdleRight))
# Skipped 194162 paths in 33.5 seconds
# Starting search: ActionPathFinder (iteration=79, hf=0.98, queue=405, seen=357, last=ActionPath(g=335, h=1.0, hVelocity=IdleRight))
# Skipped 265538 paths in 40.44 seconds
# Starting search: ActionPathFinder (iteration=82, hf=0.99, queue=403, seen=357, last=ActionPath(g=335, h=1.0, hVelocity=IdleRight))
# Skipped 338989 paths in 47.16 seconds
# Starting search: ActionPathFinder (iteration=86, hf=0.9, queue=400, seen=357, last=ActionPath(g=335, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=330, h=1.0, hVelocity=IdleRight) in 47.69 seconds after 88 iterations and 339594 skipped paths
# Starting search: ActionPathFinder (iteration=88, hf=0.91, queue=414, seen=363, last=ActionPath(g=330, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=326, h=0.5, hVelocity=IdleRight) in 51.27 seconds after 91 iterations and 375753 skipped paths
# Starting search: ActionPathFinder (iteration=91, hf=0.92, queue=428, seen=364, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 448779 paths in 58.01 seconds
# Starting search: ActionPathFinder (iteration=98, hf=0.93, queue=422, seen=364, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 523000 paths in 65.95 seconds
# Starting search: ActionPathFinder (iteration=107, hf=0.94, queue=433, seen=367, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 593899 paths in 72.33 seconds
# Starting search: ActionPathFinder (iteration=111, hf=0.95, queue=430, seen=367, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 668550 paths in 79.35 seconds
# Starting search: ActionPathFinder (iteration=115, hf=0.96, queue=427, seen=367, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 741949 paths in 86.8 seconds
# Starting search: ActionPathFinder (iteration=120, hf=0.97, queue=423, seen=371, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 812357 paths in 93.12 seconds
# Starting search: ActionPathFinder (iteration=123, hf=0.98, queue=421, seen=371, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 885149 paths in 99.86 seconds
# Starting search: ActionPathFinder (iteration=127, hf=0.99, queue=418, seen=371, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Skipped 960216 paths in 107.3 seconds
# Starting search: ActionPathFinder (iteration=133, hf=0.9, queue=413, seen=373, last=ActionPath(g=326, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=325, h=0.5, hVelocity=IdleRight) in 107.81 seconds after 135 iterations and 961435 skipped paths
# Starting search: ActionPathFinder (iteration=135, hf=0.91, queue=431, seen=373, last=ActionPath(g=325, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=324, h=0.5, hVelocity=IdleRight) in 111.63 seconds after 141 iterations and 1000680 skipped paths
# Starting search: ActionPathFinder (iteration=141, hf=0.92, queue=444, seen=373, last=ActionPath(g=324, h=0.5, hVelocity=IdleRight))
# Skipped 1089741 paths in 119.8 seconds
# Starting search: ActionPathFinder (iteration=149, hf=0.93, queue=437, seen=373, last=ActionPath(g=324, h=0.5, hVelocity=IdleRight))
# Skipped 1166711 paths in 127.0 seconds
# Starting search: ActionPathFinder (iteration=153, hf=0.94, queue=434, seen=373, last=ActionPath(g=324, h=0.5, hVelocity=IdleRight))
# Path search interrupted by User. FoundPaths: 8, QueueSize: 432
# PlotTensor: 0 96

# %%
pathFinder.plotAnimation(fps=30, skipFrames=0)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 96
