# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'SlideParcour3'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 2), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 77
# GoalDistanceFlood: Start Position: (-26.6299989, 1.5200000999999999), Goal Positions: [(-14.5, -14.5), (-14.5, -14.5)], Goal Distance: 27.5
# PlotTensor: 0 38

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Found path ActionPath(g=121, h=3.0, hVelocity=SprintRight) in 0.43 seconds after 7 iterations and 910 skipped paths
# Starting search: ActionPathFinder (iteration=7, hf=0.91, queue=164, seen=130, last=ActionPath(g=121, h=3.0, hVelocity=SprintRight))
# Skipped 6147 paths in 5.69 seconds
# Starting search: ActionPathFinder (iteration=32, hf=0.92, queue=200, seen=161, last=ActionPath(g=121, h=3.0, hVelocity=SprintRight))
# Found path ActionPath(g=120, h=2.5, hVelocity=SprintRight) in 9.24 seconds after 56 iterations and 11114 skipped paths
# Starting search: ActionPathFinder (iteration=56, hf=0.93, queue=203, seen=175, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 17286 paths in 14.59 seconds
# Starting search: ActionPathFinder (iteration=120, hf=0.94, queue=209, seen=199, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 23373 paths in 19.61 seconds
# Starting search: ActionPathFinder (iteration=181, hf=0.95, queue=202, seen=216, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 28575 paths in 24.78 seconds
# Starting search: ActionPathFinder (iteration=234, hf=0.96, queue=210, seen=229, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 33606 paths in 29.81 seconds
# Starting search: ActionPathFinder (iteration=345, hf=0.97, queue=206, seen=258, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 37799 paths in 34.82 seconds
# Starting search: ActionPathFinder (iteration=457, hf=0.98, queue=139, seen=282, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 41492 paths in 40.04 seconds
# Starting search: ActionPathFinder (iteration=516, hf=0.99, queue=155, seen=289, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 46077 paths in 45.36 seconds
# Starting search: ActionPathFinder (iteration=575, hf=0.9, queue=178, seen=305, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 53074 paths in 50.5 seconds
# Starting search: ActionPathFinder (iteration=609, hf=0.91, queue=194, seen=326, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 58645 paths in 55.68 seconds
# Starting search: ActionPathFinder (iteration=652, hf=0.92, queue=175, seen=334, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 65233 paths in 60.9 seconds
# Starting search: ActionPathFinder (iteration=733, hf=0.93, queue=131, seen=341, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 75562 paths in 65.91 seconds
# Starting search: ActionPathFinder (iteration=829, hf=0.94, queue=72, seen=358, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 81852 paths in 71.06 seconds
# Starting search: ActionPathFinder (iteration=852, hf=0.95, queue=57, seen=359, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 89951 paths in 76.51 seconds
# Starting search: ActionPathFinder (iteration=882, hf=0.96, queue=32, seen=361, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Skipped 94237 paths in 81.68 seconds
# Starting search: ActionPathFinder (iteration=927, hf=0.97, queue=3, seen=373, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=931, hf=0.98, queue=0, seen=374, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=931, hf=0.99, queue=0, seen=374, last=ActionPath(g=120, h=2.5, hVelocity=SprintRight))
# PlotTensor: 0 38

# %%
pathFinder.plotAnimation(fps=30, skipFrames=5)
break
# Out:
# 155
# PlotTensor: 0 38
#   Cell In[7], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 38

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
