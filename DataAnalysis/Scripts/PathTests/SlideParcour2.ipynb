# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'SlideParcour2'

# %%
PlayerConstants.frameCollisionOffset = 0.1

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 2), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 82
# GoalDistanceFlood: Start Position: (-26.6299989, 1.5200000999999999), Goal Positions: [(-19.5, -24.5), (-19.5, -24.5)], Goal Distance: 32.5
# PlotTensor: 0 40

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 3693 paths in 5.34 seconds
# Starting search: ActionPathFinder (iteration=21, hf=0.91, queue=284, seen=163, last=None)
# Skipped 8811 paths in 11.81 seconds
# Starting search: ActionPathFinder (iteration=49, hf=0.92, queue=353, seen=177, last=None)
# Skipped 13767 paths in 17.44 seconds
# Starting search: ActionPathFinder (iteration=89, hf=0.93, queue=477, seen=220, last=None)
# Found path ActionPath(g=206, h=0.5, hVelocity=IdleRight) in 18.25 seconds after 102 iterations and 14866 skipped paths
# Starting search: ActionPathFinder (iteration=102, hf=0.94, queue=495, seen=222, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 19518 paths in 23.36 seconds
# Starting search: ActionPathFinder (iteration=130, hf=0.95, queue=511, seen=275, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 26368 paths in 28.79 seconds
# Starting search: ActionPathFinder (iteration=151, hf=0.96, queue=518, seen=343, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 31847 paths in 34.44 seconds
# Starting search: ActionPathFinder (iteration=170, hf=0.97, queue=542, seen=390, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 37567 paths in 39.57 seconds
# Starting search: ActionPathFinder (iteration=190, hf=0.98, queue=543, seen=391, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 42496 paths in 44.67 seconds
# Starting search: ActionPathFinder (iteration=216, hf=0.99, queue=543, seen=397, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 46037 paths in 49.71 seconds
# Starting search: ActionPathFinder (iteration=252, hf=0.9, queue=521, seen=406, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Skipped 50381 paths in 54.81 seconds
# Starting search: ActionPathFinder (iteration=278, hf=0.91, queue=661, seen=414, last=ActionPath(g=206, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=200, h=0.5, hVelocity=IdleRight) in 58.16 seconds after 314 iterations and 53557 skipped paths
# Starting search: ActionPathFinder (iteration=314, hf=0.92, queue=742, seen=418, last=ActionPath(g=200, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=199, h=0.5, hVelocity=IdleRight) in 58.2 seconds after 318 iterations and 53870 skipped paths
# Starting search: ActionPathFinder (iteration=318, hf=0.93, queue=773, seen=418, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 58431 paths in 63.28 seconds
# Starting search: ActionPathFinder (iteration=336, hf=0.94, queue=779, seen=422, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 64060 paths in 68.55 seconds
# Starting search: ActionPathFinder (iteration=358, hf=0.95, queue=780, seen=424, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 70468 paths in 74.06 seconds
# Starting search: ActionPathFinder (iteration=379, hf=0.96, queue=796, seen=425, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 75463 paths in 79.34 seconds
# Starting search: ActionPathFinder (iteration=398, hf=0.97, queue=800, seen=425, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 81754 paths in 84.8 seconds
# Starting search: ActionPathFinder (iteration=419, hf=0.98, queue=797, seen=427, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 86620 paths in 90.04 seconds
# Starting search: ActionPathFinder (iteration=443, hf=0.99, queue=804, seen=428, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 89799 paths in 95.12 seconds
# Starting search: ActionPathFinder (iteration=485, hf=0.9, queue=777, seen=432, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Skipped 95903 paths in 100.5 seconds
# Starting search: ActionPathFinder (iteration=530, hf=0.91, queue=900, seen=436, last=ActionPath(g=199, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=173, h=0.5, hVelocity=IdleRight) in 103.22 seconds after 554 iterations and 98873 skipped paths
# Starting search: ActionPathFinder (iteration=554, hf=0.92, queue=981, seen=438, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 104904 paths in 108.42 seconds
# Starting search: ActionPathFinder (iteration=573, hf=0.93, queue=995, seen=438, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 111103 paths in 113.7 seconds
# Starting search: ActionPathFinder (iteration=591, hf=0.94, queue=1036, seen=438, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 116910 paths in 119.07 seconds
# Starting search: ActionPathFinder (iteration=619, hf=0.95, queue=1037, seen=438, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 121192 paths in 124.13 seconds
# Starting search: ActionPathFinder (iteration=660, hf=0.96, queue=1014, seen=438, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 124386 paths in 129.63 seconds
# Starting search: ActionPathFinder (iteration=710, hf=0.97, queue=980, seen=444, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 130104 paths in 134.64 seconds
# Starting search: ActionPathFinder (iteration=742, hf=0.98, queue=954, seen=446, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 135255 paths in 139.77 seconds
# Starting search: ActionPathFinder (iteration=764, hf=0.99, queue=938, seen=448, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 141204 paths in 145.27 seconds
# Starting search: ActionPathFinder (iteration=784, hf=0.9, queue=921, seen=450, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Skipped 147628 paths in 150.85 seconds
# Starting search: ActionPathFinder (iteration=834, hf=0.91, queue=978, seen=461, last=ActionPath(g=173, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=172, h=0.5, hVelocity=IdleRight) in 150.85 seconds after 835 iterations and 147888 skipped paths
# Starting search: ActionPathFinder (iteration=835, hf=0.92, queue=981, seen=461, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 154558 paths in 156.22 seconds
# Starting search: ActionPathFinder (iteration=856, hf=0.93, queue=1022, seen=462, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 160157 paths in 161.79 seconds
# Starting search: ActionPathFinder (iteration=875, hf=0.94, queue=1031, seen=462, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 163971 paths in 166.81 seconds
# Starting search: ActionPathFinder (iteration=900, hf=0.95, queue=1025, seen=462, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 167408 paths in 172.1 seconds
# Starting search: ActionPathFinder (iteration=934, hf=0.96, queue=1003, seen=462, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 174436 paths in 177.46 seconds
# Starting search: ActionPathFinder (iteration=963, hf=0.97, queue=978, seen=462, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 181192 paths in 182.92 seconds
# Starting search: ActionPathFinder (iteration=985, hf=0.98, queue=961, seen=466, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 187224 paths in 188.12 seconds
# Starting search: ActionPathFinder (iteration=1013, hf=0.99, queue=935, seen=467, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 192467 paths in 193.39 seconds
# Starting search: ActionPathFinder (iteration=1032, hf=0.9, queue=918, seen=468, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 198064 paths in 198.41 seconds
# Starting search: ActionPathFinder (iteration=1048, hf=0.91, queue=912, seen=471, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=171, h=0.5, hVelocity=IdleRight) in 203.07 seconds after 1090 iterations and 204386 skipped paths
# Starting search: ActionPathFinder (iteration=1090, hf=0.92, queue=929, seen=477, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 211743 paths in 208.45 seconds
# Starting search: ActionPathFinder (iteration=1129, hf=0.93, queue=925, seen=478, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 216392 paths in 213.69 seconds
# Starting search: ActionPathFinder (iteration=1151, hf=0.94, queue=917, seen=479, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 223132 paths in 218.93 seconds
# Starting search: ActionPathFinder (iteration=1187, hf=0.95, queue=886, seen=483, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 229488 paths in 224.04 seconds
# Starting search: ActionPathFinder (iteration=1213, hf=0.96, queue=880, seen=486, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 235632 paths in 229.4 seconds
# Starting search: ActionPathFinder (iteration=1248, hf=0.97, queue=849, seen=489, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 242097 paths in 234.59 seconds
# Starting search: ActionPathFinder (iteration=1274, hf=0.98, queue=825, seen=490, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 249012 paths in 240.14 seconds
# Starting search: ActionPathFinder (iteration=1302, hf=0.99, queue=802, seen=494, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 254803 paths in 245.16 seconds
# Starting search: ActionPathFinder (iteration=1322, hf=0.9, queue=784, seen=495, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 259931 paths in 250.24 seconds
# Starting search: ActionPathFinder (iteration=1350, hf=0.91, queue=810, seen=500, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 265829 paths in 255.26 seconds
# Starting search: ActionPathFinder (iteration=1385, hf=0.92, queue=824, seen=511, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 271860 paths in 260.4 seconds
# Starting search: ActionPathFinder (iteration=1438, hf=0.93, queue=817, seen=519, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 277234 paths in 265.49 seconds
# Starting search: ActionPathFinder (iteration=1470, hf=0.94, queue=788, seen=521, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 282760 paths in 270.5 seconds
# Starting search: ActionPathFinder (iteration=1494, hf=0.95, queue=773, seen=523, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 288981 paths in 275.69 seconds
# Starting search: ActionPathFinder (iteration=1533, hf=0.96, queue=736, seen=524, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 295585 paths in 280.75 seconds
# Starting search: ActionPathFinder (iteration=1570, hf=0.97, queue=709, seen=529, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 302322 paths in 286.07 seconds
# Starting search: ActionPathFinder (iteration=1601, hf=0.98, queue=683, seen=532, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 308664 paths in 291.37 seconds
# Starting search: ActionPathFinder (iteration=1628, hf=0.99, queue=658, seen=532, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 314981 paths in 296.42 seconds
# Starting search: ActionPathFinder (iteration=1660, hf=0.9, queue=631, seen=535, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 320169 paths in 301.88 seconds
# Starting search: ActionPathFinder (iteration=1679, hf=0.91, queue=713, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 325425 paths in 307.19 seconds
# Starting search: ActionPathFinder (iteration=1692, hf=0.92, queue=733, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 330491 paths in 312.25 seconds
# Starting search: ActionPathFinder (iteration=1734, hf=0.93, queue=763, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 335234 paths in 317.27 seconds
# Starting search: ActionPathFinder (iteration=1758, hf=0.94, queue=765, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 340507 paths in 322.42 seconds
# Starting search: ActionPathFinder (iteration=1774, hf=0.95, queue=755, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 345991 paths in 327.93 seconds
# Starting search: ActionPathFinder (iteration=1790, hf=0.96, queue=746, seen=558, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 351326 paths in 332.99 seconds
# Starting search: ActionPathFinder (iteration=1805, hf=0.97, queue=738, seen=559, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 358237 paths in 338.32 seconds
# Starting search: ActionPathFinder (iteration=1844, hf=0.98, queue=705, seen=560, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 364983 paths in 343.44 seconds
# Starting search: ActionPathFinder (iteration=1874, hf=0.99, queue=684, seen=563, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 371323 paths in 348.9 seconds
# Starting search: ActionPathFinder (iteration=1913, hf=0.9, queue=647, seen=564, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 376980 paths in 354.37 seconds
# Starting search: ActionPathFinder (iteration=1932, hf=0.91, queue=698, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 382683 paths in 359.44 seconds
# Starting search: ActionPathFinder (iteration=1956, hf=0.92, queue=706, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 388416 paths in 364.75 seconds
# Starting search: ActionPathFinder (iteration=1982, hf=0.93, queue=717, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 394871 paths in 370.32 seconds
# Starting search: ActionPathFinder (iteration=2000, hf=0.94, queue=745, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 401282 paths in 375.88 seconds
# Starting search: ActionPathFinder (iteration=2023, hf=0.95, queue=743, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 405813 paths in 381.0 seconds
# Starting search: ActionPathFinder (iteration=2050, hf=0.96, queue=740, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 410271 paths in 386.04 seconds
# Starting search: ActionPathFinder (iteration=2086, hf=0.97, queue=745, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 416338 paths in 391.46 seconds
# Starting search: ActionPathFinder (iteration=2110, hf=0.98, queue=759, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 422768 paths in 396.67 seconds
# Starting search: ActionPathFinder (iteration=2134, hf=0.99, queue=760, seen=572, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=170, h=0.5, hVelocity=IdleRight) in 397.24 seconds after 2141 iterations and 423830 skipped paths
# Starting search: ActionPathFinder (iteration=2141, hf=0.9, queue=763, seen=572, last=ActionPath(g=170, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=169, h=0.5, hVelocity=IdleRight) in 398.93 seconds after 2159 iterations and 426798 skipped paths
# Starting search: ActionPathFinder (iteration=2159, hf=0.91, queue=766, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 432604 paths in 404.33 seconds
# Starting search: ActionPathFinder (iteration=2175, hf=0.92, queue=783, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 437343 paths in 409.58 seconds
# Starting search: ActionPathFinder (iteration=2204, hf=0.93, queue=771, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 442927 paths in 415.11 seconds
# Starting search: ActionPathFinder (iteration=2243, hf=0.94, queue=763, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 448955 paths in 420.32 seconds
# Starting search: ActionPathFinder (iteration=2265, hf=0.95, queue=768, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 455581 paths in 425.79 seconds
# Starting search: ActionPathFinder (iteration=2288, hf=0.96, queue=781, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 461369 paths in 431.01 seconds
# Starting search: ActionPathFinder (iteration=2311, hf=0.97, queue=782, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 465105 paths in 436.34 seconds
# Starting search: ActionPathFinder (iteration=2339, hf=0.98, queue=773, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 470543 paths in 441.86 seconds
# Starting search: ActionPathFinder (iteration=2373, hf=0.99, queue=761, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 476420 paths in 447.57 seconds
# Starting search: ActionPathFinder (iteration=2397, hf=0.9, queue=746, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 483274 paths in 453.03 seconds
# Starting search: ActionPathFinder (iteration=2420, hf=0.91, queue=747, seen=572, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 487781 paths in 458.09 seconds
# Starting search: ActionPathFinder (iteration=2441, hf=0.92, queue=749, seen=575, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 493734 paths in 463.66 seconds
# Starting search: ActionPathFinder (iteration=2479, hf=0.93, queue=732, seen=581, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 498803 paths in 468.77 seconds
# Starting search: ActionPathFinder (iteration=2524, hf=0.94, queue=710, seen=592, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 504575 paths in 473.78 seconds
# Starting search: ActionPathFinder (iteration=2586, hf=0.95, queue=659, seen=597, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 511477 paths in 479.19 seconds
# Starting search: ActionPathFinder (iteration=2633, hf=0.96, queue=618, seen=599, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 518238 paths in 484.49 seconds
# Starting search: ActionPathFinder (iteration=2657, hf=0.97, queue=597, seen=602, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 524751 paths in 489.53 seconds
# Starting search: ActionPathFinder (iteration=2686, hf=0.98, queue=572, seen=604, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 531223 paths in 494.9 seconds
# Starting search: ActionPathFinder (iteration=2729, hf=0.99, queue=535, seen=606, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 537857 paths in 500.12 seconds
# Starting search: ActionPathFinder (iteration=2770, hf=0.9, queue=495, seen=608, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Skipped 542023 paths in 505.3 seconds
# Starting search: ActionPathFinder (iteration=2795, hf=0.91, queue=752, seen=624, last=ActionPath(g=169, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=143, h=0.5, hVelocity=IdleRight) in 505.38 seconds after 2799 iterations and 542089 skipped paths
# Starting search: ActionPathFinder (iteration=2799, hf=0.92, queue=749, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 547056 paths in 510.41 seconds
# Starting search: ActionPathFinder (iteration=2815, hf=0.93, queue=764, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 553405 paths in 515.57 seconds
# Starting search: ActionPathFinder (iteration=2837, hf=0.94, queue=774, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 559432 paths in 521.03 seconds
# Starting search: ActionPathFinder (iteration=2859, hf=0.95, queue=797, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 563789 paths in 526.2 seconds
# Starting search: ActionPathFinder (iteration=2897, hf=0.96, queue=784, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 567725 paths in 531.22 seconds
# Starting search: ActionPathFinder (iteration=2948, hf=0.97, queue=760, seen=624, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 572613 paths in 536.29 seconds
# Starting search: ActionPathFinder (iteration=2986, hf=0.98, queue=787, seen=626, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 578789 paths in 541.35 seconds
# Starting search: ActionPathFinder (iteration=3014, hf=0.99, queue=787, seen=628, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 582639 paths in 546.82 seconds
# Starting search: ActionPathFinder (iteration=3058, hf=0.9, queue=773, seen=628, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Skipped 589015 paths in 552.17 seconds
# Starting search: ActionPathFinder (iteration=3089, hf=0.91, queue=807, seen=628, last=ActionPath(g=143, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=137, h=0.5, hVelocity=IdleRight) in 555.92 seconds after 3111 iterations and 593219 skipped paths
# Starting search: ActionPathFinder (iteration=3111, hf=0.92, queue=824, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 597852 paths in 560.93 seconds
# Starting search: ActionPathFinder (iteration=3143, hf=0.93, queue=827, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 604173 paths in 566.29 seconds
# Starting search: ActionPathFinder (iteration=3174, hf=0.94, queue=843, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 610225 paths in 571.37 seconds
# Starting search: ActionPathFinder (iteration=3189, hf=0.95, queue=848, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 614441 paths in 576.39 seconds
# Starting search: ActionPathFinder (iteration=3218, hf=0.96, queue=844, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 618887 paths in 581.66 seconds
# Starting search: ActionPathFinder (iteration=3257, hf=0.97, queue=820, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 624326 paths in 587.1 seconds
# Starting search: ActionPathFinder (iteration=3283, hf=0.98, queue=822, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 629972 paths in 592.37 seconds
# Starting search: ActionPathFinder (iteration=3304, hf=0.99, queue=819, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 636321 paths in 597.65 seconds
# Starting search: ActionPathFinder (iteration=3335, hf=0.9, queue=820, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 642693 paths in 602.9 seconds
# Starting search: ActionPathFinder (iteration=3356, hf=0.91, queue=829, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 647920 paths in 607.99 seconds
# Starting search: ActionPathFinder (iteration=3375, hf=0.92, queue=825, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 653855 paths in 613.01 seconds
# Starting search: ActionPathFinder (iteration=3398, hf=0.93, queue=813, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 659617 paths in 618.43 seconds
# Starting search: ActionPathFinder (iteration=3418, hf=0.94, queue=819, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 665997 paths in 623.91 seconds
# Starting search: ActionPathFinder (iteration=3439, hf=0.95, queue=808, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 672396 paths in 629.11 seconds
# Starting search: ActionPathFinder (iteration=3457, hf=0.96, queue=798, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 678587 paths in 634.49 seconds
# Starting search: ActionPathFinder (iteration=3481, hf=0.97, queue=781, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 685087 paths in 639.82 seconds
# Starting search: ActionPathFinder (iteration=3500, hf=0.98, queue=779, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 691719 paths in 644.95 seconds
# Starting search: ActionPathFinder (iteration=3522, hf=0.99, queue=775, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 697491 paths in 650.08 seconds
# Starting search: ActionPathFinder (iteration=3539, hf=0.9, queue=774, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 703226 paths in 655.44 seconds
# Starting search: ActionPathFinder (iteration=3565, hf=0.91, queue=816, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 709754 paths in 660.72 seconds
# Starting search: ActionPathFinder (iteration=3590, hf=0.92, queue=822, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 716208 paths in 666.33 seconds
# Starting search: ActionPathFinder (iteration=3622, hf=0.93, queue=805, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 722967 paths in 671.82 seconds
# Starting search: ActionPathFinder (iteration=3648, hf=0.94, queue=821, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 728191 paths in 677.0 seconds
# Starting search: ActionPathFinder (iteration=3666, hf=0.95, queue=817, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 734545 paths in 682.58 seconds
# Starting search: ActionPathFinder (iteration=3685, hf=0.96, queue=836, seen=628, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 740170 paths in 687.65 seconds
# Starting search: ActionPathFinder (iteration=3699, hf=0.97, queue=827, seen=629, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 745246 paths in 692.66 seconds
# Starting search: ActionPathFinder (iteration=3710, hf=0.98, queue=818, seen=630, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 751008 paths in 697.89 seconds
# Starting search: ActionPathFinder (iteration=3723, hf=0.99, queue=822, seen=631, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 756904 paths in 703.17 seconds
# Starting search: ActionPathFinder (iteration=3738, hf=0.9, queue=808, seen=631, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 762157 paths in 708.42 seconds
# Starting search: ActionPathFinder (iteration=3754, hf=0.91, queue=805, seen=632, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 768170 paths in 713.91 seconds
# Starting search: ActionPathFinder (iteration=3784, hf=0.92, queue=791, seen=636, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 774193 paths in 719.52 seconds
# Starting search: ActionPathFinder (iteration=3802, hf=0.93, queue=781, seen=637, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 779337 paths in 725.21 seconds
# Starting search: ActionPathFinder (iteration=3822, hf=0.94, queue=783, seen=642, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 786279 paths in 730.66 seconds
# Starting search: ActionPathFinder (iteration=3842, hf=0.95, queue=780, seen=646, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 791998 paths in 735.89 seconds
# Starting search: ActionPathFinder (iteration=3857, hf=0.96, queue=768, seen=647, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 798325 paths in 741.02 seconds
# Starting search: ActionPathFinder (iteration=3875, hf=0.97, queue=756, seen=651, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 804659 paths in 746.26 seconds
# Starting search: ActionPathFinder (iteration=3896, hf=0.98, queue=737, seen=652, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 811133 paths in 751.46 seconds
# Starting search: ActionPathFinder (iteration=3945, hf=0.99, queue=716, seen=653, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 816839 paths in 756.65 seconds
# Starting search: ActionPathFinder (iteration=4010, hf=0.9, queue=655, seen=655, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 822102 paths in 761.98 seconds
# Starting search: ActionPathFinder (iteration=4035, hf=0.91, queue=669, seen=663, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 828475 paths in 767.11 seconds
# Starting search: ActionPathFinder (iteration=4060, hf=0.92, queue=674, seen=669, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 836676 paths in 772.5 seconds
# Starting search: ActionPathFinder (iteration=4132, hf=0.93, queue=642, seen=677, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 842142 paths in 777.88 seconds
# Starting search: ActionPathFinder (iteration=4187, hf=0.94, queue=593, seen=679, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 849007 paths in 783.27 seconds
# Starting search: ActionPathFinder (iteration=4221, hf=0.95, queue=578, seen=683, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 855297 paths in 788.38 seconds
# Starting search: ActionPathFinder (iteration=4246, hf=0.96, queue=559, seen=687, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 861618 paths in 793.77 seconds
# Starting search: ActionPathFinder (iteration=4265, hf=0.97, queue=552, seen=687, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 868528 paths in 799.19 seconds
# Starting search: ActionPathFinder (iteration=4295, hf=0.98, queue=528, seen=687, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 875438 paths in 804.47 seconds
# Starting search: ActionPathFinder (iteration=4366, hf=0.99, queue=461, seen=690, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 882248 paths in 809.78 seconds
# Starting search: ActionPathFinder (iteration=4431, hf=0.9, queue=409, seen=691, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 892028 paths in 814.79 seconds
# Starting search: ActionPathFinder (iteration=4526, hf=0.91, queue=342, seen=705, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 900770 paths in 819.88 seconds
# Starting search: ActionPathFinder (iteration=4595, hf=0.92, queue=283, seen=709, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 906421 paths in 824.99 seconds
# Starting search: ActionPathFinder (iteration=4616, hf=0.93, queue=268, seen=711, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 913238 paths in 830.53 seconds
# Starting search: ActionPathFinder (iteration=4635, hf=0.94, queue=265, seen=715, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 919490 paths in 835.59 seconds
# Starting search: ActionPathFinder (iteration=4650, hf=0.95, queue=261, seen=717, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 926288 paths in 840.94 seconds
# Starting search: ActionPathFinder (iteration=4673, hf=0.96, queue=250, seen=721, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 933088 paths in 846.17 seconds
# Starting search: ActionPathFinder (iteration=4704, hf=0.97, queue=234, seen=725, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 940465 paths in 851.42 seconds
# Starting search: ActionPathFinder (iteration=4739, hf=0.98, queue=204, seen=726, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 947244 paths in 856.72 seconds
# Starting search: ActionPathFinder (iteration=4779, hf=0.99, queue=170, seen=730, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 954055 paths in 861.86 seconds
# Starting search: ActionPathFinder (iteration=4820, hf=0.9, queue=134, seen=731, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 961156 paths in 867.2 seconds
# Starting search: ActionPathFinder (iteration=4852, hf=0.91, queue=115, seen=736, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 967901 paths in 872.25 seconds
# Starting search: ActionPathFinder (iteration=4891, hf=0.92, queue=81, seen=739, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 974002 paths in 877.42 seconds
# Starting search: ActionPathFinder (iteration=4918, hf=0.93, queue=71, seen=744, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 980230 paths in 882.74 seconds
# Starting search: ActionPathFinder (iteration=4943, hf=0.94, queue=59, seen=749, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Skipped 987596 paths in 887.96 seconds
# Starting search: ActionPathFinder (iteration=4971, hf=0.95, queue=38, seen=752, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=5018, hf=0.96, queue=0, seen=759, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=5018, hf=0.97, queue=0, seen=759, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=5018, hf=0.98, queue=0, seen=759, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=5018, hf=0.99, queue=0, seen=759, last=ActionPath(g=137, h=0.5, hVelocity=IdleRight))
# PlotTensor: 0 40

# %%
pathFinder.plotAnimation(fps=30, skipFrames=30)
break
# Out:
# 155
# PlotTensor: 0 40
#   Cell In[7], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 40

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
