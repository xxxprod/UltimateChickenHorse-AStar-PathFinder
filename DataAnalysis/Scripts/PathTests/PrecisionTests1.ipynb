# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'PrecisionTests1'

# %%
PlayerConstants.frameCollisionEndFrame = -2
PlayerConstants.frameCollisionOffset = 0.1

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(11, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 106
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(15.5, -7.5), (15.5, -7.5)], Goal Distance: 34.0
# PlotTensor: 0 52

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 3650 paths in 5.08 seconds
# Starting search: ActionPathFinder (iteration=100, hf=0.91, queue=522, seen=343, last=None)
# Skipped 7375 paths in 10.09 seconds
# Starting search: ActionPathFinder (iteration=286, hf=0.92, queue=460, seen=401, last=None)
# Skipped 11735 paths in 15.29 seconds
# Starting search: ActionPathFinder (iteration=550, hf=0.93, queue=470, seen=427, last=None)
# Skipped 16750 paths in 20.7 seconds
# Starting search: ActionPathFinder (iteration=739, hf=0.94, queue=633, seen=473, last=None)
# Skipped 24118 paths in 25.75 seconds
# Starting search: ActionPathFinder (iteration=851, hf=0.95, queue=769, seen=515, last=None)
# Skipped 45318 paths in 30.93 seconds
# Starting search: ActionPathFinder (iteration=955, hf=0.96, queue=879, seen=532, last=None)
# Skipped 66497 paths in 36.2 seconds
# Starting search: ActionPathFinder (iteration=1038, hf=0.97, queue=909, seen=534, last=None)
# Skipped 82804 paths in 41.24 seconds
# Starting search: ActionPathFinder (iteration=1086, hf=0.98, queue=865, seen=534, last=None)
# Skipped 103585 paths in 46.28 seconds
# Starting search: ActionPathFinder (iteration=1132, hf=0.99, queue=820, seen=534, last=None)
# Skipped 130851 paths in 51.51 seconds
# Starting search: ActionPathFinder (iteration=1186, hf=0.9, queue=768, seen=535, last=None)
# Found path ActionPath(g=201, h=2.0, hVelocity=SprintRight) in 53.88 seconds after 1214 iterations and 133565 skipped paths
# Starting search: ActionPathFinder (iteration=1214, hf=0.91, queue=885, seen=538, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 139987 paths in 58.93 seconds
# Starting search: ActionPathFinder (iteration=1326, hf=0.92, queue=915, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 156462 paths in 64.08 seconds
# Starting search: ActionPathFinder (iteration=1386, hf=0.93, queue=892, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 167622 paths in 69.14 seconds
# Starting search: ActionPathFinder (iteration=1412, hf=0.94, queue=868, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 183296 paths in 74.16 seconds
# Starting search: ActionPathFinder (iteration=1447, hf=0.95, queue=835, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 196781 paths in 79.19 seconds
# Starting search: ActionPathFinder (iteration=1477, hf=0.96, queue=807, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 214540 paths in 84.45 seconds
# Starting search: ActionPathFinder (iteration=1528, hf=0.97, queue=758, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 224894 paths in 89.53 seconds
# Starting search: ActionPathFinder (iteration=1552, hf=0.98, queue=738, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 235412 paths in 94.86 seconds
# Starting search: ActionPathFinder (iteration=1570, hf=0.99, queue=721, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 261659 paths in 99.87 seconds
# Starting search: ActionPathFinder (iteration=1621, hf=0.9, queue=671, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 276656 paths in 105.13 seconds
# Starting search: ActionPathFinder (iteration=1684, hf=0.91, queue=634, seen=539, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 300080 paths in 110.21 seconds
# Starting search: ActionPathFinder (iteration=1770, hf=0.92, queue=570, seen=547, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Skipped 315889 paths in 115.52 seconds
# Starting search: ActionPathFinder (iteration=1831, hf=0.93, queue=519, seen=550, last=ActionPath(g=201, h=2.0, hVelocity=SprintRight))
# Path search interrupted by User. FoundPaths: 1, QueueSize: 439
# PlotTensor: 0 52

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
# 209
#   Cell In[7], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
