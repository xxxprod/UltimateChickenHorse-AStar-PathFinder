# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'NarrowPathTest'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(1, 1), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 140
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(15.5, -7.5), (15.5, -7.5)], Goal Distance: 34.0
# PlotTensor: 0 69

# %%
pathFinder.heuristicFactors = np.arange(0.5, 1.01, 0.1)

for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.5, queue=1, seen=0, last=None)
# Found path ActionPath(g=188, h=2.0, hVelocity=SprintRight) in 0.0 seconds after 1 iterations and 262 skipped paths
# Starting search: ActionPathFinder (iteration=1, hf=0.6, queue=68, seen=68, last=ActionPath(g=188, h=2.0, hVelocity=SprintRight))
# Found path ActionPath(g=162, h=2.0, hVelocity=SprintRight) in 0.76 seconds after 4 iterations and 26888 skipped paths
# Starting search: ActionPathFinder (iteration=4, hf=0.7, queue=209, seen=127, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 78890 paths in 6.05 seconds
# Starting search: ActionPathFinder (iteration=8, hf=0.8, queue=214, seen=134, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 130187 paths in 11.51 seconds
# Starting search: ActionPathFinder (iteration=13, hf=0.9, queue=220, seen=136, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 166582 paths in 17.0 seconds
# Starting search: ActionPathFinder (iteration=92, hf=1.0, queue=200, seen=182, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 213760 paths in 22.35 seconds
# Starting search: ActionPathFinder (iteration=105, hf=0.5, queue=188, seen=182, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 269330 paths in 28.02 seconds
# Starting search: ActionPathFinder (iteration=110, hf=0.6, queue=189, seen=182, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 350778 paths in 35.45 seconds
# Starting search: ActionPathFinder (iteration=114, hf=0.7, queue=187, seen=182, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 427743 paths in 42.51 seconds
# Starting search: ActionPathFinder (iteration=118, hf=0.8, queue=184, seen=182, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 477085 paths in 47.56 seconds
# Starting search: ActionPathFinder (iteration=124, hf=0.9, queue=188, seen=187, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 536875 paths in 53.07 seconds
# Starting search: ActionPathFinder (iteration=131, hf=1.0, queue=191, seen=189, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 606239 paths in 59.29 seconds
# Starting search: ActionPathFinder (iteration=136, hf=0.5, queue=187, seen=189, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 683402 paths in 66.41 seconds
# Starting search: ActionPathFinder (iteration=145, hf=0.6, queue=181, seen=189, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 739225 paths in 71.49 seconds
# Starting search: ActionPathFinder (iteration=148, hf=0.7, queue=179, seen=189, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 793249 paths in 76.65 seconds
# Starting search: ActionPathFinder (iteration=154, hf=0.8, queue=182, seen=192, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 835537 paths in 83.08 seconds
# Starting search: ActionPathFinder (iteration=180, hf=0.9, queue=195, seen=208, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 894830 paths in 88.39 seconds
# Starting search: ActionPathFinder (iteration=185, hf=1.0, queue=191, seen=208, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 954002 paths in 93.75 seconds
# Starting search: ActionPathFinder (iteration=192, hf=0.5, queue=185, seen=208, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1010416 paths in 98.89 seconds
# Starting search: ActionPathFinder (iteration=198, hf=0.6, queue=182, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1062794 paths in 104.66 seconds
# Starting search: ActionPathFinder (iteration=204, hf=0.7, queue=177, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1144345 paths in 111.72 seconds
# Starting search: ActionPathFinder (iteration=208, hf=0.8, queue=174, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1217031 paths in 118.03 seconds
# Starting search: ActionPathFinder (iteration=214, hf=0.9, queue=169, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1275703 paths in 123.13 seconds
# Starting search: ActionPathFinder (iteration=218, hf=1.0, queue=166, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1346938 paths in 129.99 seconds
# Starting search: ActionPathFinder (iteration=226, hf=0.5, queue=159, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1399988 paths in 137.83 seconds
# Starting search: ActionPathFinder (iteration=229, hf=0.6, queue=157, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1440304 paths in 142.85 seconds
# Starting search: ActionPathFinder (iteration=235, hf=0.7, queue=152, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1497786 paths in 148.12 seconds
# Starting search: ActionPathFinder (iteration=241, hf=0.8, queue=147, seen=210, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1573327 paths in 154.61 seconds
# Starting search: ActionPathFinder (iteration=248, hf=0.9, queue=142, seen=211, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1636485 paths in 160.31 seconds
# Starting search: ActionPathFinder (iteration=252, hf=1.0, queue=139, seen=211, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1702262 paths in 166.74 seconds
# Starting search: ActionPathFinder (iteration=259, hf=0.5, queue=133, seen=211, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1735821 paths in 171.82 seconds
# Starting search: ActionPathFinder (iteration=268, hf=0.6, queue=125, seen=211, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1792464 paths in 178.56 seconds
# Starting search: ActionPathFinder (iteration=275, hf=0.7, queue=119, seen=211, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1863560 paths in 185.34 seconds
# Starting search: ActionPathFinder (iteration=282, hf=0.8, queue=114, seen=212, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1921766 paths in 190.47 seconds
# Starting search: ActionPathFinder (iteration=287, hf=0.9, queue=111, seen=213, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 1981584 paths in 196.44 seconds
# Starting search: ActionPathFinder (iteration=291, hf=1.0, queue=108, seen=213, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2045165 paths in 203.03 seconds
# Starting search: ActionPathFinder (iteration=295, hf=0.5, queue=105, seen=213, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2080943 paths in 208.43 seconds
# Starting search: ActionPathFinder (iteration=305, hf=0.6, queue=96, seen=213, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2131180 paths in 214.52 seconds
# Starting search: ActionPathFinder (iteration=313, hf=0.7, queue=90, seen=214, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2165582 paths in 220.06 seconds
# Starting search: ActionPathFinder (iteration=319, hf=0.8, queue=85, seen=214, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2223113 paths in 226.0 seconds
# Starting search: ActionPathFinder (iteration=325, hf=0.9, queue=80, seen=214, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2285047 paths in 232.59 seconds
# Starting search: ActionPathFinder (iteration=337, hf=1.0, queue=69, seen=214, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2348667 paths in 238.31 seconds
# Starting search: ActionPathFinder (iteration=341, hf=0.5, queue=66, seen=214, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2398316 paths in 244.7 seconds
# Starting search: ActionPathFinder (iteration=355, hf=0.6, queue=58, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2443031 paths in 249.98 seconds
# Starting search: ActionPathFinder (iteration=362, hf=0.7, queue=52, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2513871 paths in 256.9 seconds
# Starting search: ActionPathFinder (iteration=367, hf=0.8, queue=48, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2578809 paths in 262.77 seconds
# Starting search: ActionPathFinder (iteration=371, hf=0.9, queue=45, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2637240 paths in 268.96 seconds
# Starting search: ActionPathFinder (iteration=381, hf=1.0, queue=36, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2694174 paths in 274.91 seconds
# Starting search: ActionPathFinder (iteration=386, hf=0.5, queue=32, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2735369 paths in 280.68 seconds
# Starting search: ActionPathFinder (iteration=393, hf=0.6, queue=26, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2772770 paths in 285.88 seconds
# Starting search: ActionPathFinder (iteration=400, hf=0.7, queue=20, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2822502 paths in 291.24 seconds
# Starting search: ActionPathFinder (iteration=406, hf=0.8, queue=15, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2876875 paths in 297.61 seconds
# Starting search: ActionPathFinder (iteration=415, hf=0.9, queue=7, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# Skipped 2928734 paths in 303.83 seconds
# Starting search: ActionPathFinder (iteration=420, hf=1.0, queue=3, seen=217, last=ActionPath(g=162, h=2.0, hVelocity=SprintRight))
# PlotTensor: 0 69

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
