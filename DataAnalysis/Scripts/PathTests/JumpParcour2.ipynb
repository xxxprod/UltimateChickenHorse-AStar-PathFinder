# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'JumpParcour2'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 1), 
    # heuristicFactors=np.arange(0.9, 1.0, 0.01),
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 172
# GoalDistanceFlood: Start Position: (-51.6299969, 22.52), Goal Positions: [(25.5, 20.5), (25.5, 20.5), (25.5, 33.5), (25.5, 33.5)], Goal Distance: 78.5
# PlotTensor: 0 85

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 4665 paths in 5.26 seconds
# Starting search: ActionPathFinder (iteration=21, hf=0.91, queue=153, seen=140, last=None)
# Found path ActionPath(g=415, h=1.0, hVelocity=IdleRight) in 9.3 seconds after 51 iterations and 10302 skipped paths
# Starting search: ActionPathFinder (iteration=51, hf=0.92, queue=286, seen=265, last=ActionPath(g=415, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=413, h=1.0, hVelocity=IdleRight) in 9.3 seconds after 52 iterations and 10312 skipped paths
# Starting search: ActionPathFinder (iteration=52, hf=0.93, queue=288, seen=265, last=ActionPath(g=413, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=412, h=1.0, hVelocity=WalkRight) in 9.3 seconds after 54 iterations and 10328 skipped paths
# Starting search: ActionPathFinder (iteration=54, hf=0.94, queue=289, seen=267, last=ActionPath(g=412, h=1.0, hVelocity=WalkRight))
# Found path ActionPath(g=399, h=0.5, hVelocity=IdleRight) in 11.45 seconds after 81 iterations and 13116 skipped paths
# Starting search: ActionPathFinder (iteration=81, hf=0.95, queue=303, seen=301, last=ActionPath(g=399, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=398, h=0.5, hVelocity=WalkRight) in 12.89 seconds after 99 iterations and 14826 skipped paths
# Starting search: ActionPathFinder (iteration=99, hf=0.96, queue=305, seen=302, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 19820 paths in 18.05 seconds
# Starting search: ActionPathFinder (iteration=195, hf=0.97, queue=237, seen=320, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 27008 paths in 23.08 seconds
# Starting search: ActionPathFinder (iteration=248, hf=0.98, queue=231, seen=335, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 35251 paths in 28.63 seconds
# Starting search: ActionPathFinder (iteration=327, hf=0.99, queue=220, seen=338, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 42466 paths in 33.69 seconds
# Starting search: ActionPathFinder (iteration=365, hf=0.9, queue=207, seen=348, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 49560 paths in 38.71 seconds
# Starting search: ActionPathFinder (iteration=397, hf=0.91, queue=229, seen=363, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 58294 paths in 44.07 seconds
# Starting search: ActionPathFinder (iteration=457, hf=0.92, queue=225, seen=367, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 66100 paths in 49.16 seconds
# Starting search: ActionPathFinder (iteration=501, hf=0.93, queue=205, seen=376, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 76326 paths in 54.29 seconds
# Starting search: ActionPathFinder (iteration=559, hf=0.94, queue=170, seen=378, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 86791 paths in 59.31 seconds
# Starting search: ActionPathFinder (iteration=611, hf=0.95, queue=120, seen=379, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 94498 paths in 64.76 seconds
# Starting search: ActionPathFinder (iteration=632, hf=0.96, queue=100, seen=379, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 100749 paths in 70.1 seconds
# Starting search: ActionPathFinder (iteration=669, hf=0.97, queue=74, seen=384, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 109246 paths in 75.15 seconds
# Starting search: ActionPathFinder (iteration=707, hf=0.98, queue=107, seen=407, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 119689 paths in 80.18 seconds
# Starting search: ActionPathFinder (iteration=762, hf=0.99, queue=96, seen=414, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 128372 paths in 85.44 seconds
# Starting search: ActionPathFinder (iteration=795, hf=0.9, queue=82, seen=421, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 139677 paths in 90.94 seconds
# Starting search: ActionPathFinder (iteration=855, hf=0.91, queue=140, seen=424, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 148570 paths in 95.96 seconds
# Starting search: ActionPathFinder (iteration=898, hf=0.92, queue=138, seen=426, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 155073 paths in 101.09 seconds
# Starting search: ActionPathFinder (iteration=916, hf=0.93, queue=131, seen=429, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 161469 paths in 106.1 seconds
# Starting search: ActionPathFinder (iteration=942, hf=0.94, queue=129, seen=434, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 169155 paths in 111.34 seconds
# Starting search: ActionPathFinder (iteration=977, hf=0.95, queue=117, seen=434, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 176671 paths in 116.37 seconds
# Starting search: ActionPathFinder (iteration=1006, hf=0.96, queue=110, seen=434, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 189856 paths in 121.43 seconds
# Starting search: ActionPathFinder (iteration=1058, hf=0.97, queue=82, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 204936 paths in 126.44 seconds
# Starting search: ActionPathFinder (iteration=1101, hf=0.98, queue=72, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 225475 paths in 131.49 seconds
# Starting search: ActionPathFinder (iteration=1144, hf=0.99, queue=71, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 237823 paths in 136.56 seconds
# Starting search: ActionPathFinder (iteration=1164, hf=0.9, queue=54, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 257617 paths in 141.66 seconds
# Starting search: ActionPathFinder (iteration=1205, hf=0.91, queue=37, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Skipped 271902 paths in 146.94 seconds
# Starting search: ActionPathFinder (iteration=1231, hf=0.92, queue=12, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.93, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.94, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.95, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.96, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.97, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.98, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# Starting search: ActionPathFinder (iteration=1243, hf=0.99, queue=0, seen=440, last=ActionPath(g=398, h=0.5, hVelocity=WalkRight))
# PlotTensor: 0 85

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[1])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
