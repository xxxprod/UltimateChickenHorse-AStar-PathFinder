# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'TallClimb2'

# %%
PlayerConstants.frameCollisionOffset = 0.1
PlayerConstants.frameCollisionEndFrame = -4

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 2), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 195
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(15.5, -7.5)], Goal Distance: 94.5
# PlotTensor: 0 97

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=1507, hf=0.9, queue=357, seen=559, last=445)
# Skipped 2069140 paths in 334.76 seconds
# Starting search: ActionPathFinder (iteration=1528, hf=0.91, queue=355, seen=563, last=445)
# Skipped 2106344 paths in 339.8 seconds
# Starting search: ActionPathFinder (iteration=1545, hf=0.92, queue=359, seen=564, last=445)
# Skipped 2123919 paths in 345.43 seconds
# Starting search: ActionPathFinder (iteration=1562, hf=0.93, queue=352, seen=568, last=445)
# Skipped 2131788 paths in 350.53 seconds
# Starting search: ActionPathFinder (iteration=1572, hf=0.94, queue=361, seen=573, last=445)
# Found path ActionPath(state=Undefined, g=442, h=-0.5) in 352.99 seconds after 1586 iterations and 2155296 skipped paths
# Starting search: ActionPathFinder (iteration=1586, hf=0.95, queue=362, seen=575, last=442)
# Skipped 2177127 paths in 358.06 seconds
# Starting search: ActionPathFinder (iteration=1610, hf=0.96, queue=351, seen=575, last=442)
# Skipped 2185956 paths in 363.11 seconds
# Starting search: ActionPathFinder (iteration=1619, hf=0.97, queue=352, seen=577, last=442)
# Skipped 2204279 paths in 368.65 seconds
# Starting search: ActionPathFinder (iteration=1636, hf=0.98, queue=344, seen=580, last=442)
# Found path ActionPath(state=Undefined, g=441, h=-0.5) in 372.02 seconds after 1655 iterations and 2236884 skipped paths
# Starting search: ActionPathFinder (iteration=1655, hf=0.99, queue=353, seen=581, last=441)
# Skipped 2255444 paths in 377.88 seconds
# Starting search: ActionPathFinder (iteration=1679, hf=0.9, queue=342, seen=582, last=441)
# Found path ActionPath(state=Undefined, g=439, h=-0.5) in 377.88 seconds after 1680 iterations and 2255803 skipped paths
# Starting search: ActionPathFinder (iteration=1680, hf=0.91, queue=357, seen=583, last=439)
# Skipped 2284344 paths in 383.25 seconds
# Starting search: ActionPathFinder (iteration=1706, hf=0.92, queue=345, seen=583, last=439)
# Found path ActionPath(state=Undefined, g=438, h=2.0) in 383.68 seconds after 1710 iterations and 2286836 skipped paths
# Starting search: ActionPathFinder (iteration=1710, hf=0.93, queue=348, seen=585, last=438)
# Found path ActionPath(state=Undefined, g=437, h=2.0) in 384.08 seconds after 1717 iterations and 2296582 skipped paths
# Starting search: ActionPathFinder (iteration=1717, hf=0.94, queue=352, seen=587, last=437)
# Found path ActionPath(state=Undefined, g=434, h=-0.5) in 386.24 seconds after 1729 iterations and 2308294 skipped paths
# Starting search: ActionPathFinder (iteration=1729, hf=0.95, queue=358, seen=588, last=434)
# Skipped 2330965 paths in 392.17 seconds
# Starting search: ActionPathFinder (iteration=1752, hf=0.96, queue=346, seen=588, last=434)
# Found path ActionPath(state=Undefined, g=433, h=2.0) in 395.85 seconds after 1760 iterations and 2341176 skipped paths
# Starting search: ActionPathFinder (iteration=1760, hf=0.97, queue=351, seen=591, last=433)
# Skipped 2359953 paths in 401.49 seconds
# Starting search: ActionPathFinder (iteration=1780, hf=0.98, queue=339, seen=593, last=433)
# Skipped 2368182 paths in 408.11 seconds
# Starting search: ActionPathFinder (iteration=1793, hf=0.99, queue=336, seen=598, last=433)
# Found path ActionPath(state=Undefined, g=430, h=-0.5) in 408.11 seconds after 1795 iterations and 2368490 skipped paths
# Starting search: ActionPathFinder (iteration=1795, hf=0.9, queue=344, seen=599, last=430)
# Skipped 2390940 paths in 413.8 seconds
# Starting search: ActionPathFinder (iteration=1814, hf=0.91, queue=336, seen=601, last=430)
# Found path ActionPath(state=Undefined, g=429, h=-0.5) in 413.83 seconds after 1817 iterations and 2391785 skipped paths
# Starting search: ActionPathFinder (iteration=1817, hf=0.92, queue=340, seen=603, last=429)
# Found path ActionPath(state=Undefined, g=427, h=-0.5) in 414.21 seconds after 1822 iterations and 2395105 skipped paths
# Starting search: ActionPathFinder (iteration=1822, hf=0.93, queue=342, seen=604, last=427)
# Found path ActionPath(state=Undefined, g=426, h=-0.5) in 414.95 seconds after 1831 iterations and 2400246 skipped paths
# Starting search: ActionPathFinder (iteration=1831, hf=0.94, queue=338, seen=607, last=426)
# Found path ActionPath(state=Undefined, g=425, h=-0.5) in 416.59 seconds after 1836 iterations and 2401815 skipped paths
# Starting search: ActionPathFinder (iteration=1836, hf=0.95, queue=339, seen=610, last=425)
# Found path ActionPath(state=Undefined, g=424, h=-0.5) in 421.37 seconds after 1843 iterations and 2405800 skipped paths
# Starting search: ActionPathFinder (iteration=1843, hf=0.96, queue=336, seen=612, last=424)
# Found path ActionPath(state=Undefined, g=423, h=2.0) in 421.37 seconds after 1844 iterations and 2405831 skipped paths
# Starting search: ActionPathFinder (iteration=1844, hf=0.97, queue=335, seen=612, last=423)
# Skipped 2409885 paths in 427.14 seconds
# Starting search: ActionPathFinder (iteration=1852, hf=0.98, queue=331, seen=614, last=423)
# Found path ActionPath(state=Undefined, g=422, h=1.0) in 431.97 seconds after 1861 iterations and 2413885 skipped paths
# Starting search: ActionPathFinder (iteration=1861, hf=0.99, queue=329, seen=619, last=422)
# Found path ActionPath(state=Undefined, g=421, h=1.0) in 436.74 seconds after 1871 iterations and 2418070 skipped paths
# Starting search: ActionPathFinder (iteration=1871, hf=0.9, queue=328, seen=624, last=421)
# Found path ActionPath(state=Undefined, g=420, h=1.0) in 436.74 seconds after 1872 iterations and 2418092 skipped paths
# Starting search: ActionPathFinder (iteration=1872, hf=0.91, queue=329, seen=624, last=420)
# Found path ActionPath(state=Undefined, g=419, h=1.0) in 436.74 seconds after 1873 iterations and 2418113 skipped paths
# Starting search: ActionPathFinder (iteration=1873, hf=0.92, queue=330, seen=625, last=419)
# Found path ActionPath(state=Undefined, g=418, h=1.0) in 436.75 seconds after 1875 iterations and 2418336 skipped paths
# Starting search: ActionPathFinder (iteration=1875, hf=0.93, queue=330, seen=627, last=418)
# Found path ActionPath(state=Undefined, g=417, h=1.0) in 438.3 seconds after 1879 iterations and 2420032 skipped paths
# Starting search: ActionPathFinder (iteration=1879, hf=0.94, queue=334, seen=631, last=417)
# Found path ActionPath(state=Undefined, g=416, h=1.0) in 438.3 seconds after 1880 iterations and 2420051 skipped paths
# Starting search: ActionPathFinder (iteration=1880, hf=0.95, queue=335, seen=632, last=416)
# Found path ActionPath(state=Undefined, g=415, h=1.0) in 439.88 seconds after 1884 iterations and 2421339 skipped paths
# Starting search: ActionPathFinder (iteration=1884, hf=0.96, queue=332, seen=633, last=415)
# Skipped 2426839 paths in 446.17 seconds
# Starting search: ActionPathFinder (iteration=1895, hf=0.97, queue=327, seen=637, last=415)
# Skipped 2432383 paths in 452.46 seconds
# Starting search: ActionPathFinder (iteration=1909, hf=0.98, queue=320, seen=643, last=415)
# Skipped 2437738 paths in 458.75 seconds
# Starting search: ActionPathFinder (iteration=1920, hf=0.99, queue=315, seen=648, last=415)
# Skipped 2443340 paths in 465.18 seconds
# Starting search: ActionPathFinder (iteration=1930, hf=0.9, queue=320, seen=653, last=415)
# Skipped 2448976 paths in 471.79 seconds
# Starting search: ActionPathFinder (iteration=1936, hf=0.91, queue=339, seen=666, last=415)
# Skipped 2452732 paths in 477.05 seconds
# Starting search: ActionPathFinder (iteration=1941, hf=0.92, queue=350, seen=670, last=415)
# Skipped 2457467 paths in 482.74 seconds
# Starting search: ActionPathFinder (iteration=1952, hf=0.93, queue=347, seen=673, last=415)
# Skipped 2462028 paths in 488.34 seconds
# Starting search: ActionPathFinder (iteration=1959, hf=0.94, queue=351, seen=678, last=415)
# Skipped 2467102 paths in 494.94 seconds
# Starting search: ActionPathFinder (iteration=1977, hf=0.95, queue=340, seen=682, last=415)
# Skipped 2471064 paths in 499.99 seconds
# Starting search: ActionPathFinder (iteration=1982, hf=0.96, queue=339, seen=683, last=415)
# Skipped 2475961 paths in 505.97 seconds
# Starting search: ActionPathFinder (iteration=2012, hf=0.97, queue=317, seen=689, last=415)
# Skipped 2480974 paths in 511.78 seconds
# Starting search: ActionPathFinder (iteration=2038, hf=0.98, queue=293, seen=690, last=415)
# Skipped 2485503 paths in 517.37 seconds
# Starting search: ActionPathFinder (iteration=2046, hf=0.99, queue=291, seen=694, last=415)
# Skipped 2491187 paths in 524.56 seconds
# Starting search: ActionPathFinder (iteration=2061, hf=0.9, queue=288, seen=701, last=415)
# Skipped 2496876 paths in 530.97 seconds
# Starting search: ActionPathFinder (iteration=2074, hf=0.91, queue=291, seen=705, last=415)
# Skipped 2500597 paths in 536.52 seconds
# Starting search: ActionPathFinder (iteration=2085, hf=0.92, queue=291, seen=706, last=415)
# Skipped 2505106 paths in 541.88 seconds
# Starting search: ActionPathFinder (iteration=2092, hf=0.93, queue=293, seen=707, last=415)
# Skipped 2509478 paths in 547.14 seconds
# Starting search: ActionPathFinder (iteration=2099, hf=0.94, queue=297, seen=707, last=415)
# Skipped 2514069 paths in 552.63 seconds
# Starting search: ActionPathFinder (iteration=2116, hf=0.95, queue=283, seen=708, last=415)
# Skipped 2519189 paths in 558.54 seconds
# Starting search: ActionPathFinder (iteration=2150, hf=0.96, queue=266, seen=716, last=415)
# Skipped 2524939 paths in 563.58 seconds
# Starting search: ActionPathFinder (iteration=2166, hf=0.97, queue=294, seen=716, last=415)
# Skipped 2531544 paths in 570.27 seconds
# Starting search: ActionPathFinder (iteration=2176, hf=0.98, queue=293, seen=716, last=415)
# Skipped 2536265 paths in 575.87 seconds
# Starting search: ActionPathFinder (iteration=2183, hf=0.99, queue=293, seen=716, last=415)
# Skipped 2541730 paths in 582.38 seconds
# Starting search: ActionPathFinder (iteration=2190, hf=0.9, queue=291, seen=716, last=415)
# Skipped 2547494 paths in 589.54 seconds
# Starting search: ActionPathFinder (iteration=2204, hf=0.91, queue=281, seen=716, last=415)
# Skipped 2551850 paths in 595.83 seconds
# Starting search: ActionPathFinder (iteration=2213, hf=0.92, queue=278, seen=717, last=415)
# Skipped 2556387 paths in 601.08 seconds
# Starting search: ActionPathFinder (iteration=2229, hf=0.93, queue=278, seen=717, last=415)
# Skipped 2561499 paths in 607.13 seconds
# Starting search: ActionPathFinder (iteration=2238, hf=0.94, queue=278, seen=717, last=415)
# Skipped 2566569 paths in 613.34 seconds
# Starting search: ActionPathFinder (iteration=2245, hf=0.95, queue=276, seen=717, last=415)
# Skipped 2571764 paths in 619.46 seconds
# Starting search: ActionPathFinder (iteration=2262, hf=0.96, queue=265, seen=719, last=415)
# Skipped 2576880 paths in 624.86 seconds
# Starting search: ActionPathFinder (iteration=2288, hf=0.97, queue=265, seen=739, last=415)
# Skipped 2582514 paths in 630.98 seconds
# Starting search: ActionPathFinder (iteration=2306, hf=0.98, queue=261, seen=740, last=415)
# Skipped 2592632 paths in 636.18 seconds
# Starting search: ActionPathFinder (iteration=2320, hf=0.99, queue=324, seen=740, last=415)
# Skipped 2603555 paths in 641.89 seconds
# Starting search: ActionPathFinder (iteration=2342, hf=0.9, queue=319, seen=740, last=415)
# Skipped 2612550 paths in 647.52 seconds
# Starting search: ActionPathFinder (iteration=2357, hf=0.91, queue=315, seen=740, last=415)
# Skipped 2620282 paths in 652.69 seconds
# Starting search: ActionPathFinder (iteration=2367, hf=0.92, queue=314, seen=740, last=415)
# Skipped 2628059 paths in 658.05 seconds
# Starting search: ActionPathFinder (iteration=2376, hf=0.93, queue=312, seen=740, last=415)
# Skipped 2636367 paths in 664.25 seconds
# Starting search: ActionPathFinder (iteration=2387, hf=0.94, queue=312, seen=740, last=415)
# Skipped 2642955 paths in 669.59 seconds
# Starting search: ActionPathFinder (iteration=2394, hf=0.95, queue=310, seen=740, last=415)
# Skipped 2648022 paths in 674.77 seconds
# Starting search: ActionPathFinder (iteration=2401, hf=0.96, queue=309, seen=740, last=415)
# Skipped 2654662 paths in 680.74 seconds
# Starting search: ActionPathFinder (iteration=2409, hf=0.97, queue=306, seen=740, last=415)
# Skipped 2661006 paths in 687.04 seconds
# Starting search: ActionPathFinder (iteration=2417, hf=0.98, queue=307, seen=740, last=415)
# Skipped 2667310 paths in 693.58 seconds
# Starting search: ActionPathFinder (iteration=2426, hf=0.99, queue=308, seen=740, last=415)
# Skipped 2673409 paths in 700.12 seconds
# Starting search: ActionPathFinder (iteration=2434, hf=0.9, queue=303, seen=740, last=415)
# Skipped 2678030 paths in 705.24 seconds
# Starting search: ActionPathFinder (iteration=2440, hf=0.91, queue=305, seen=740, last=415)
# Path search interrupted by User. FoundPaths: 34, QueueSize: 305
# PlotTensor: 0 97

# %%
pathFinder.plotAnimation(fps=30, skipFrames=5)
break

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 97
