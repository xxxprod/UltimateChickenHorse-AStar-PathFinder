# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'WireJumpTest1'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 84
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(-13.5, -7.5), (-13.5, -7.5)], Goal Distance: 31.5
# PlotTensor: 0 41

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 7289 paths in 5.23 seconds
# Starting search: ActionPathFinder (iteration=22, hf=0.91, queue=177, seen=154, last=None)
# Found path ActionPath(g=176, h=1.0, hVelocity=IdleRight) in 5.91 seconds after 28 iterations and 7918 skipped paths
# Starting search: ActionPathFinder (iteration=28, hf=0.92, queue=198, seen=176, last=ActionPath(g=176, h=1.0, hVelocity=IdleRight))
# Skipped 12146 paths in 11.76 seconds
# Starting search: ActionPathFinder (iteration=36, hf=0.93, queue=199, seen=253, last=ActionPath(g=176, h=1.0, hVelocity=IdleRight))
# Skipped 17090 paths in 17.15 seconds
# Starting search: ActionPathFinder (iteration=48, hf=0.94, queue=203, seen=270, last=ActionPath(g=176, h=1.0, hVelocity=IdleRight))
# Skipped 21411 paths in 22.37 seconds
# Starting search: ActionPathFinder (iteration=60, hf=0.95, queue=207, seen=277, last=ActionPath(g=176, h=1.0, hVelocity=IdleRight))
# Skipped 26219 paths in 27.91 seconds
# Starting search: ActionPathFinder (iteration=87, hf=0.96, queue=191, seen=301, last=ActionPath(g=176, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=172, h=0.5, hVelocity=IdleRight) in 29.26 seconds after 94 iterations and 27470 skipped paths
# Starting search: ActionPathFinder (iteration=94, hf=0.97, queue=192, seen=303, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 32207 paths in 34.37 seconds
# Starting search: ActionPathFinder (iteration=102, hf=0.98, queue=198, seen=303, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 37117 paths in 39.86 seconds
# Starting search: ActionPathFinder (iteration=117, hf=0.99, queue=199, seen=303, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 41166 paths in 45.16 seconds
# Starting search: ActionPathFinder (iteration=141, hf=0.9, queue=191, seen=313, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Skipped 46900 paths in 50.64 seconds
# Starting search: ActionPathFinder (iteration=155, hf=0.91, queue=186, seen=313, last=ActionPath(g=172, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=171, h=0.5, hVelocity=IdleRight) in 50.65 seconds after 159 iterations and 47011 skipped paths
# Starting search: ActionPathFinder (iteration=159, hf=0.92, queue=182, seen=313, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 51283 paths in 56.39 seconds
# Starting search: ActionPathFinder (iteration=190, hf=0.93, queue=196, seen=353, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 56737 paths in 62.24 seconds
# Starting search: ActionPathFinder (iteration=210, hf=0.94, queue=210, seen=356, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Skipped 62395 paths in 67.75 seconds
# Starting search: ActionPathFinder (iteration=230, hf=0.95, queue=214, seen=364, last=ActionPath(g=171, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=164, h=1.0, hVelocity=IdleRight) in 69.29 seconds after 237 iterations and 63835 skipped paths
# Starting search: ActionPathFinder (iteration=237, hf=0.96, queue=236, seen=364, last=ActionPath(g=164, h=1.0, hVelocity=IdleRight))
# Skipped 69717 paths in 74.93 seconds
# Starting search: ActionPathFinder (iteration=247, hf=0.97, queue=235, seen=364, last=ActionPath(g=164, h=1.0, hVelocity=IdleRight))
# Skipped 75509 paths in 79.94 seconds
# Starting search: ActionPathFinder (iteration=263, hf=0.98, queue=245, seen=364, last=ActionPath(g=164, h=1.0, hVelocity=IdleRight))
# Skipped 79831 paths in 84.97 seconds
# Starting search: ActionPathFinder (iteration=281, hf=0.99, queue=237, seen=364, last=ActionPath(g=164, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=160, h=0.5, hVelocity=IdleRight) in 89.35 seconds after 302 iterations and 83609 skipped paths
# Starting search: ActionPathFinder (iteration=302, hf=0.9, queue=230, seen=364, last=ActionPath(g=160, h=0.5, hVelocity=IdleRight))
# Skipped 89132 paths in 94.55 seconds
# Starting search: ActionPathFinder (iteration=311, hf=0.91, queue=235, seen=364, last=ActionPath(g=160, h=0.5, hVelocity=IdleRight))
# Skipped 93992 paths in 99.77 seconds
# Starting search: ActionPathFinder (iteration=326, hf=0.92, queue=244, seen=364, last=ActionPath(g=160, h=0.5, hVelocity=IdleRight))
# Skipped 99112 paths in 105.41 seconds
# Starting search: ActionPathFinder (iteration=339, hf=0.93, queue=240, seen=364, last=ActionPath(g=160, h=0.5, hVelocity=IdleRight))
# Skipped 102566 paths in 110.83 seconds
# Starting search: ActionPathFinder (iteration=358, hf=0.94, queue=228, seen=364, last=ActionPath(g=160, h=0.5, hVelocity=IdleRight))
# Found path ActionPath(g=159, h=0.5, hVelocity=IdleRight) in 111.53 seconds after 364 iterations and 103148 skipped paths
# Starting search: ActionPathFinder (iteration=364, hf=0.95, queue=223, seen=364, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 108631 paths in 116.89 seconds
# Starting search: ActionPathFinder (iteration=389, hf=0.96, queue=204, seen=364, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 114534 paths in 122.34 seconds
# Starting search: ActionPathFinder (iteration=405, hf=0.97, queue=212, seen=368, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 119580 paths in 127.46 seconds
# Starting search: ActionPathFinder (iteration=413, hf=0.98, queue=206, seen=369, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 124646 paths in 133.26 seconds
# Starting search: ActionPathFinder (iteration=420, hf=0.99, queue=200, seen=369, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 131276 paths in 138.78 seconds
# Starting search: ActionPathFinder (iteration=432, hf=0.9, queue=193, seen=371, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 137176 paths in 144.45 seconds
# Starting search: ActionPathFinder (iteration=452, hf=0.91, queue=231, seen=375, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 143125 paths in 150.23 seconds
# Starting search: ActionPathFinder (iteration=471, hf=0.92, queue=221, seen=375, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 149734 paths in 155.82 seconds
# Starting search: ActionPathFinder (iteration=494, hf=0.93, queue=209, seen=378, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 155207 paths in 160.83 seconds
# Starting search: ActionPathFinder (iteration=515, hf=0.94, queue=214, seen=380, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 161552 paths in 166.41 seconds
# Starting search: ActionPathFinder (iteration=532, hf=0.95, queue=208, seen=381, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 167086 paths in 171.48 seconds
# Starting search: ActionPathFinder (iteration=548, hf=0.96, queue=208, seen=384, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 173465 paths in 177.1 seconds
# Starting search: ActionPathFinder (iteration=564, hf=0.97, queue=208, seen=389, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 179102 paths in 182.57 seconds
# Starting search: ActionPathFinder (iteration=572, hf=0.98, queue=202, seen=389, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 184693 paths in 187.8 seconds
# Starting search: ActionPathFinder (iteration=580, hf=0.99, queue=195, seen=389, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 190215 paths in 193.27 seconds
# Starting search: ActionPathFinder (iteration=588, hf=0.9, queue=188, seen=389, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 196029 paths in 198.43 seconds
# Starting search: ActionPathFinder (iteration=609, hf=0.91, queue=199, seen=389, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 201545 paths in 203.44 seconds
# Starting search: ActionPathFinder (iteration=632, hf=0.92, queue=210, seen=398, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 215198 paths in 208.73 seconds
# Starting search: ActionPathFinder (iteration=670, hf=0.93, queue=206, seen=403, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 227633 paths in 214.09 seconds
# Starting search: ActionPathFinder (iteration=706, hf=0.94, queue=184, seen=403, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 241242 paths in 219.49 seconds
# Starting search: ActionPathFinder (iteration=726, hf=0.95, queue=171, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 249854 paths in 224.55 seconds
# Starting search: ActionPathFinder (iteration=737, hf=0.96, queue=161, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 257538 paths in 229.91 seconds
# Starting search: ActionPathFinder (iteration=750, hf=0.97, queue=152, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 275548 paths in 235.39 seconds
# Starting search: ActionPathFinder (iteration=774, hf=0.98, queue=133, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 300844 paths in 240.6 seconds
# Starting search: ActionPathFinder (iteration=797, hf=0.99, queue=114, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 325033 paths in 245.78 seconds
# Starting search: ActionPathFinder (iteration=819, hf=0.9, queue=95, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 344159 paths in 251.36 seconds
# Starting search: ActionPathFinder (iteration=843, hf=0.91, queue=75, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 370738 paths in 256.4 seconds
# Starting search: ActionPathFinder (iteration=875, hf=0.92, queue=44, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Skipped 416447 paths in 261.57 seconds
# Starting search: ActionPathFinder (iteration=911, hf=0.93, queue=9, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.94, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.95, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.96, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.97, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.98, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=920, hf=0.99, queue=0, seen=404, last=ActionPath(g=159, h=0.5, hVelocity=IdleRight))
# PlotTensor: 0 41

# %%
# pathFinder.plotAnimation(fps=30, skipFrames=3)
break
# Out:
# 225
# PlotTensor: 0 41
#   Cell In[6], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# PlotTensor: 0 41

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 10) & (dfx.Segment < 12)]
dfx
