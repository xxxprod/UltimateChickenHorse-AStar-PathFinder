# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'TallClimb3'

# %%
PlayerConstants.frameCollisionOffset=0.1

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 11), 
    # heuristicFactors=np.arange(0.7, 1.0, 0.1),
    forceLoadLevel=False, 
    forceCreateNodeMap=False,
    heuristic=ActionPathHeuristics.GoalDistanceFlood
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 195
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(15.5, -7.5)], Goal Distance: 94.5
# PlotTensor: 0 97

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=999999)
# Skipped 12325 paths in 5.4 seconds
# Starting search: ActionPathFinder (iteration=32, hf=0.91, queue=419, seen=357, last=999999)
# Skipped 17718 paths in 11.43 seconds
# Starting search: ActionPathFinder (iteration=85, hf=0.92, queue=414, seen=386, last=999999)
# Skipped 22706 paths in 17.38 seconds
# Starting search: ActionPathFinder (iteration=116, hf=0.93, queue=410, seen=405, last=999999)
# Skipped 27856 paths in 23.22 seconds
# Starting search: ActionPathFinder (iteration=146, hf=0.94, queue=487, seen=504, last=999999)
# Skipped 33097 paths in 30.28 seconds
# Starting search: ActionPathFinder (iteration=160, hf=0.95, queue=919, seen=924, last=999999)
# Found path ActionPath(state=Undefined, g=514, h=2.0) in 30.28 seconds after 161 iterations and 33183 skipped paths
# Starting search: ActionPathFinder (iteration=161, hf=0.96, queue=964, seen=970, last=514)
# Skipped 37651 paths in 35.31 seconds
# Starting search: ActionPathFinder (iteration=177, hf=0.97, queue=949, seen=1028, last=514)
# Skipped 54463 paths in 40.41 seconds
# Starting search: ActionPathFinder (iteration=192, hf=0.98, queue=945, seen=1040, last=514)
# Skipped 120973 paths in 45.75 seconds
# Starting search: ActionPathFinder (iteration=227, hf=0.99, queue=968, seen=1051, last=514)
# Path search interrupted by User. FoundPaths: 1, QueueSize: 969
# PlotTensor: 0 97

# %%
# pathFinder.plotAnimation(fps=30, skipFrames=30)
break

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 97

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 10) & (dfx.Segment < 15)]
dfx #.head(100)
