# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = '9DPV-UYUB'

# %%
PlayerConstants.frameCollisionOffset = 0.1

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # costWeights=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

print(Rect(pathFinder.blockMap.rtree.bounds).size)
print(len(pathFinder.blockMap.blocks))

pathFinder.plotPaths()
# Out:
# Device used: cpu
# Flood fill steps: 189
# GoalDistanceFlood: Start Position: (26.3700011, -20.48), Goal Positions: [(-24.5, 18.5)], Goal Distance: 91.0
# (74.0, 48.0)
# 909
# PlotTensor: -0.5 94.0

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 2341 paths in 5.01 seconds
# Starting search: ActionPathFinder (iteration=60, hf=0.91, queue=106, seen=72, last=None)
# Skipped 5523 paths in 10.16 seconds
# Starting search: ActionPathFinder (iteration=110, hf=0.92, queue=191, seen=160, last=None)
# Skipped 8643 paths in 15.76 seconds
# Starting search: ActionPathFinder (iteration=137, hf=0.93, queue=408, seen=342, last=None)
# Skipped 11174 paths in 21.87 seconds
# Starting search: ActionPathFinder (iteration=161, hf=0.94, queue=635, seen=543, last=None)
# Found path ActionPath(g=518, h=3.0, hVelocity=WalkRight) in 25.8 seconds after 174 iterations and 12596 skipped paths
# Starting search: ActionPathFinder (iteration=174, hf=0.95, queue=714, seen=613, last=ActionPath(g=518, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=511, h=2.5, hVelocity=WalkRight) in 25.8 seconds after 183 iterations and 12614 skipped paths
# Starting search: ActionPathFinder (iteration=183, hf=0.96, queue=711, seen=618, last=ActionPath(g=511, h=2.5, hVelocity=WalkRight))
# Found path ActionPath(g=510, h=2.5, hVelocity=SprintRight) in 25.8 seconds after 188 iterations and 12627 skipped paths
# Starting search: ActionPathFinder (iteration=188, hf=0.97, queue=707, seen=618, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 14467 paths in 31.03 seconds
# Starting search: ActionPathFinder (iteration=201, hf=0.98, queue=705, seen=633, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 15382 paths in 36.46 seconds
# Starting search: ActionPathFinder (iteration=219, hf=0.99, queue=721, seen=643, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 17843 paths in 42.11 seconds
# Starting search: ActionPathFinder (iteration=230, hf=0.9, queue=725, seen=643, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 21762 paths in 47.41 seconds
# Starting search: ActionPathFinder (iteration=263, hf=0.91, queue=789, seen=652, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 26087 paths in 53.4 seconds
# Starting search: ActionPathFinder (iteration=286, hf=0.92, queue=821, seen=658, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 28318 paths in 58.5 seconds
# Starting search: ActionPathFinder (iteration=306, hf=0.93, queue=822, seen=666, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Skipped 31525 paths in 63.62 seconds
# Starting search: ActionPathFinder (iteration=334, hf=0.94, queue=841, seen=671, last=ActionPath(g=510, h=2.5, hVelocity=SprintRight))
# Found path ActionPath(g=509, h=2.5, hVelocity=WalkRight) in 67.32 seconds after 346 iterations and 33615 skipped paths
# Starting search: ActionPathFinder (iteration=346, hf=0.95, queue=845, seen=671, last=ActionPath(g=509, h=2.5, hVelocity=WalkRight))
# Found path ActionPath(g=506, h=3.0, hVelocity=WalkRight) in 67.32 seconds after 348 iterations and 33639 skipped paths
# Starting search: ActionPathFinder (iteration=348, hf=0.96, queue=844, seen=673, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 39065 paths in 73.45 seconds
# Starting search: ActionPathFinder (iteration=391, hf=0.97, queue=806, seen=675, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 43233 paths in 78.81 seconds
# Starting search: ActionPathFinder (iteration=421, hf=0.98, queue=784, seen=679, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 46300 paths in 84.6 seconds
# Starting search: ActionPathFinder (iteration=432, hf=0.99, queue=787, seen=689, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 49547 paths in 89.89 seconds
# Starting search: ActionPathFinder (iteration=456, hf=0.9, queue=768, seen=693, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 53578 paths in 95.65 seconds
# Starting search: ActionPathFinder (iteration=488, hf=0.91, queue=779, seen=702, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 57527 paths in 101.14 seconds
# Starting search: ActionPathFinder (iteration=514, hf=0.92, queue=838, seen=707, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Skipped 60173 paths in 106.25 seconds
# Starting search: ActionPathFinder (iteration=549, hf=0.93, queue=926, seen=708, last=ActionPath(g=506, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=504, h=3.0, hVelocity=WalkRight) in 107.74 seconds after 555 iterations and 60906 skipped paths
# Starting search: ActionPathFinder (iteration=555, hf=0.94, queue=928, seen=708, last=ActionPath(g=504, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=497, h=2.5, hVelocity=WalkRight) in 107.74 seconds after 559 iterations and 60922 skipped paths
# Starting search: ActionPathFinder (iteration=559, hf=0.95, queue=928, seen=708, last=ActionPath(g=497, h=2.5, hVelocity=WalkRight))
# Found path ActionPath(g=494, h=3.0, hVelocity=WalkRight) in 107.74 seconds after 562 iterations and 60946 skipped paths
# Starting search: ActionPathFinder (iteration=562, hf=0.96, queue=926, seen=708, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 64343 paths in 112.76 seconds
# Starting search: ActionPathFinder (iteration=589, hf=0.97, queue=904, seen=708, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 68983 paths in 118.59 seconds
# Starting search: ActionPathFinder (iteration=622, hf=0.98, queue=897, seen=708, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 72890 paths in 124.26 seconds
# Starting search: ActionPathFinder (iteration=657, hf=0.99, queue=894, seen=709, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 75679 paths in 129.46 seconds
# Starting search: ActionPathFinder (iteration=670, hf=0.9, queue=899, seen=711, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 78008 paths in 134.97 seconds
# Starting search: ActionPathFinder (iteration=693, hf=0.91, queue=915, seen=711, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 81542 paths in 140.64 seconds
# Starting search: ActionPathFinder (iteration=716, hf=0.92, queue=911, seen=711, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 85426 paths in 145.91 seconds
# Starting search: ActionPathFinder (iteration=748, hf=0.93, queue=902, seen=713, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 88150 paths in 151.01 seconds
# Starting search: ActionPathFinder (iteration=764, hf=0.94, queue=891, seen=713, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 91382 paths in 157.06 seconds
# Starting search: ActionPathFinder (iteration=802, hf=0.95, queue=866, seen=718, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 94704 paths in 163.41 seconds
# Starting search: ActionPathFinder (iteration=832, hf=0.96, queue=841, seen=720, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 98704 paths in 169.1 seconds
# Starting search: ActionPathFinder (iteration=920, hf=0.97, queue=757, seen=722, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 102295 paths in 174.15 seconds
# Starting search: ActionPathFinder (iteration=939, hf=0.98, queue=742, seen=725, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 106603 paths in 180.11 seconds
# Starting search: ActionPathFinder (iteration=956, hf=0.99, queue=731, seen=728, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 110242 paths in 185.78 seconds
# Starting search: ActionPathFinder (iteration=1035, hf=0.9, queue=715, seen=735, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 112988 paths in 191.27 seconds
# Starting search: ActionPathFinder (iteration=1072, hf=0.91, queue=747, seen=740, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 115049 paths in 196.37 seconds
# Starting search: ActionPathFinder (iteration=1105, hf=0.92, queue=777, seen=755, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 119110 paths in 201.54 seconds
# Starting search: ActionPathFinder (iteration=1150, hf=0.93, queue=789, seen=777, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 122882 paths in 206.75 seconds
# Starting search: ActionPathFinder (iteration=1216, hf=0.94, queue=777, seen=784, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 128073 paths in 212.35 seconds
# Starting search: ActionPathFinder (iteration=1294, hf=0.95, queue=736, seen=794, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 133124 paths in 217.85 seconds
# Starting search: ActionPathFinder (iteration=1360, hf=0.96, queue=690, seen=803, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 137619 paths in 223.58 seconds
# Starting search: ActionPathFinder (iteration=1398, hf=0.97, queue=663, seen=809, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 142055 paths in 229.07 seconds
# Starting search: ActionPathFinder (iteration=1422, hf=0.98, queue=646, seen=814, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 147315 paths in 234.59 seconds
# Starting search: ActionPathFinder (iteration=1460, hf=0.99, queue=648, seen=849, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 155743 paths in 239.89 seconds
# Starting search: ActionPathFinder (iteration=1506, hf=0.9, queue=651, seen=858, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Skipped 159507 paths in 246.18 seconds
# Starting search: ActionPathFinder (iteration=1525, hf=0.91, queue=762, seen=861, last=ActionPath(g=494, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=493, h=2.5, hVelocity=SprintRight) in 246.18 seconds after 1528 iterations and 159523 skipped paths
# Starting search: ActionPathFinder (iteration=1528, hf=0.92, queue=762, seen=861, last=ActionPath(g=493, h=2.5, hVelocity=SprintRight))
# Found path ActionPath(g=491, h=3.0, hVelocity=WalkRight) in 246.18 seconds after 1531 iterations and 159539 skipped paths
# Starting search: ActionPathFinder (iteration=1531, hf=0.93, queue=761, seen=861, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 162017 paths in 251.2 seconds
# Starting search: ActionPathFinder (iteration=1546, hf=0.94, queue=750, seen=861, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 165041 paths in 256.23 seconds
# Starting search: ActionPathFinder (iteration=1558, hf=0.95, queue=754, seen=861, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 168145 paths in 261.41 seconds
# Starting search: ActionPathFinder (iteration=1591, hf=0.96, queue=741, seen=861, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 171335 paths in 266.9 seconds
# Starting search: ActionPathFinder (iteration=1610, hf=0.97, queue=732, seen=861, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 173671 paths in 272.16 seconds
# Starting search: ActionPathFinder (iteration=1634, hf=0.98, queue=722, seen=862, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 177556 paths in 277.39 seconds
# Starting search: ActionPathFinder (iteration=1647, hf=0.99, queue=760, seen=863, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 180709 paths in 283.37 seconds
# Starting search: ActionPathFinder (iteration=1698, hf=0.9, queue=722, seen=863, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 183068 paths in 288.74 seconds
# Starting search: ActionPathFinder (iteration=1721, hf=0.91, queue=772, seen=863, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 187074 paths in 293.89 seconds
# Starting search: ActionPathFinder (iteration=1759, hf=0.92, queue=781, seen=864, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 189938 paths in 299.44 seconds
# Starting search: ActionPathFinder (iteration=1787, hf=0.93, queue=798, seen=864, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 194287 paths in 305.78 seconds
# Starting search: ActionPathFinder (iteration=1809, hf=0.94, queue=800, seen=865, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 197417 paths in 311.63 seconds
# Starting search: ActionPathFinder (iteration=1823, hf=0.95, queue=791, seen=865, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 200951 paths in 317.88 seconds
# Starting search: ActionPathFinder (iteration=1844, hf=0.96, queue=781, seen=866, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 205936 paths in 323.83 seconds
# Starting search: ActionPathFinder (iteration=1898, hf=0.97, queue=753, seen=867, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 210244 paths in 329.42 seconds
# Starting search: ActionPathFinder (iteration=1915, hf=0.98, queue=751, seen=868, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 214385 paths in 335.02 seconds
# Starting search: ActionPathFinder (iteration=1935, hf=0.99, queue=741, seen=870, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 220140 paths in 340.62 seconds
# Starting search: ActionPathFinder (iteration=1968, hf=0.9, queue=751, seen=871, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 223386 paths in 346.33 seconds
# Starting search: ActionPathFinder (iteration=2004, hf=0.91, queue=749, seen=877, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 226861 paths in 352.15 seconds
# Starting search: ActionPathFinder (iteration=2028, hf=0.92, queue=745, seen=888, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 230029 paths in 358.11 seconds
# Starting search: ActionPathFinder (iteration=2055, hf=0.93, queue=752, seen=909, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 232898 paths in 364.2 seconds
# Starting search: ActionPathFinder (iteration=2078, hf=0.94, queue=756, seen=913, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 236053 paths in 369.87 seconds
# Starting search: ActionPathFinder (iteration=2094, hf=0.95, queue=764, seen=916, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 241481 paths in 375.36 seconds
# Starting search: ActionPathFinder (iteration=2140, hf=0.96, queue=776, seen=929, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 246395 paths in 380.71 seconds
# Starting search: ActionPathFinder (iteration=2184, hf=0.97, queue=747, seen=937, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 251162 paths in 385.73 seconds
# Starting search: ActionPathFinder (iteration=2240, hf=0.98, queue=710, seen=944, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 256443 paths in 391.18 seconds
# Starting search: ActionPathFinder (iteration=2293, hf=0.99, queue=685, seen=952, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 262493 paths in 396.44 seconds
# Starting search: ActionPathFinder (iteration=2352, hf=0.9, queue=657, seen=975, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 265852 paths in 402.32 seconds
# Starting search: ActionPathFinder (iteration=2361, hf=0.91, queue=670, seen=981, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 268289 paths in 408.53 seconds
# Starting search: ActionPathFinder (iteration=2381, hf=0.92, queue=659, seen=987, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 270793 paths in 413.67 seconds
# Starting search: ActionPathFinder (iteration=2392, hf=0.93, queue=677, seen=1005, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 273141 paths in 418.83 seconds
# Starting search: ActionPathFinder (iteration=2410, hf=0.94, queue=679, seen=1020, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 275048 paths in 424.59 seconds
# Starting search: ActionPathFinder (iteration=2486, hf=0.95, queue=629, seen=1038, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 279249 paths in 430.57 seconds
# Starting search: ActionPathFinder (iteration=2544, hf=0.96, queue=607, seen=1058, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 282789 paths in 435.85 seconds
# Starting search: ActionPathFinder (iteration=2583, hf=0.97, queue=630, seen=1102, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 286748 paths in 441.14 seconds
# Starting search: ActionPathFinder (iteration=2629, hf=0.98, queue=662, seen=1138, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 290831 paths in 446.19 seconds
# Starting search: ActionPathFinder (iteration=2704, hf=0.99, queue=609, seen=1147, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 294501 paths in 451.22 seconds
# Starting search: ActionPathFinder (iteration=2757, hf=0.9, queue=597, seen=1169, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 296543 paths in 456.36 seconds
# Starting search: ActionPathFinder (iteration=2785, hf=0.91, queue=606, seen=1187, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 299459 paths in 461.44 seconds
# Starting search: ActionPathFinder (iteration=2801, hf=0.92, queue=603, seen=1192, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 301739 paths in 466.88 seconds
# Starting search: ActionPathFinder (iteration=2816, hf=0.93, queue=603, seen=1199, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 303685 paths in 472.11 seconds
# Starting search: ActionPathFinder (iteration=2860, hf=0.94, queue=581, seen=1215, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 306367 paths in 477.65 seconds
# Starting search: ActionPathFinder (iteration=2906, hf=0.95, queue=571, seen=1229, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 308176 paths in 482.88 seconds
# Starting search: ActionPathFinder (iteration=2946, hf=0.96, queue=569, seen=1247, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 311177 paths in 488.01 seconds
# Starting search: ActionPathFinder (iteration=2991, hf=0.97, queue=545, seen=1261, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 313326 paths in 493.34 seconds
# Starting search: ActionPathFinder (iteration=3024, hf=0.98, queue=538, seen=1279, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 316266 paths in 498.54 seconds
# Starting search: ActionPathFinder (iteration=3054, hf=0.99, queue=526, seen=1283, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 318866 paths in 504.08 seconds
# Starting search: ActionPathFinder (iteration=3076, hf=0.9, queue=513, seen=1287, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 322100 paths in 509.49 seconds
# Starting search: ActionPathFinder (iteration=3113, hf=0.91, queue=519, seen=1300, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 325794 paths in 515.08 seconds
# Starting search: ActionPathFinder (iteration=3141, hf=0.92, queue=505, seen=1304, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 329835 paths in 520.94 seconds
# Starting search: ActionPathFinder (iteration=3235, hf=0.93, queue=526, seen=1339, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 333040 paths in 526.37 seconds
# Starting search: ActionPathFinder (iteration=3262, hf=0.94, queue=515, seen=1345, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 336035 paths in 531.42 seconds
# Starting search: ActionPathFinder (iteration=3276, hf=0.95, queue=509, seen=1346, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 339124 paths in 536.54 seconds
# Starting search: ActionPathFinder (iteration=3287, hf=0.96, queue=509, seen=1347, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 342333 paths in 541.7 seconds
# Starting search: ActionPathFinder (iteration=3299, hf=0.97, queue=503, seen=1349, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 345570 paths in 546.88 seconds
# Starting search: ActionPathFinder (iteration=3310, hf=0.98, queue=496, seen=1351, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 349217 paths in 552.59 seconds
# Starting search: ActionPathFinder (iteration=3326, hf=0.99, queue=487, seen=1353, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 352296 paths in 557.81 seconds
# Starting search: ActionPathFinder (iteration=3343, hf=0.9, queue=479, seen=1359, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 356607 paths in 563.29 seconds
# Starting search: ActionPathFinder (iteration=3370, hf=0.91, queue=545, seen=1369, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 361439 paths in 569.21 seconds
# Starting search: ActionPathFinder (iteration=3398, hf=0.92, queue=607, seen=1379, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 365840 paths in 574.48 seconds
# Starting search: ActionPathFinder (iteration=3434, hf=0.93, queue=589, seen=1383, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 370010 paths in 579.51 seconds
# Starting search: ActionPathFinder (iteration=3522, hf=0.94, queue=535, seen=1395, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 373404 paths in 584.73 seconds
# Starting search: ActionPathFinder (iteration=3544, hf=0.95, queue=541, seen=1400, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 375386 paths in 589.8 seconds
# Starting search: ActionPathFinder (iteration=3590, hf=0.96, queue=514, seen=1430, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 380271 paths in 594.89 seconds
# Starting search: ActionPathFinder (iteration=3643, hf=0.97, queue=522, seen=1466, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 387520 paths in 600.25 seconds
# Starting search: ActionPathFinder (iteration=3671, hf=0.98, queue=517, seen=1485, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 392690 paths in 605.29 seconds
# Starting search: ActionPathFinder (iteration=3723, hf=0.99, queue=500, seen=1509, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 399316 paths in 610.34 seconds
# Starting search: ActionPathFinder (iteration=3748, hf=0.9, queue=479, seen=1539, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 403560 paths in 615.5 seconds
# Starting search: ActionPathFinder (iteration=3806, hf=0.91, queue=514, seen=1548, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 407686 paths in 620.92 seconds
# Starting search: ActionPathFinder (iteration=3877, hf=0.92, queue=453, seen=1554, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 414764 paths in 626.58 seconds
# Starting search: ActionPathFinder (iteration=3994, hf=0.93, queue=403, seen=1559, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 419267 paths in 632.98 seconds
# Starting search: ActionPathFinder (iteration=4011, hf=0.94, queue=543, seen=1559, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Skipped 421924 paths in 638.6 seconds
# Starting search: ActionPathFinder (iteration=4047, hf=0.95, queue=636, seen=1559, last=ActionPath(g=491, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=490, h=2.5, hVelocity=WalkRight) in 643.24 seconds after 4067 iterations and 424318 skipped paths
# Starting search: ActionPathFinder (iteration=4067, hf=0.96, queue=658, seen=1559, last=ActionPath(g=490, h=2.5, hVelocity=WalkRight))
# Found path ActionPath(g=487, h=3.0, hVelocity=WalkRight) in 643.24 seconds after 4069 iterations and 424342 skipped paths
# Starting search: ActionPathFinder (iteration=4069, hf=0.97, queue=657, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 427023 paths in 648.3 seconds
# Starting search: ActionPathFinder (iteration=4086, hf=0.98, queue=645, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 431699 paths in 653.31 seconds
# Starting search: ActionPathFinder (iteration=4124, hf=0.99, queue=636, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 435455 paths in 659.05 seconds
# Starting search: ActionPathFinder (iteration=4146, hf=0.9, queue=644, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 437660 paths in 664.27 seconds
# Starting search: ActionPathFinder (iteration=4166, hf=0.91, queue=648, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 441213 paths in 669.75 seconds
# Starting search: ActionPathFinder (iteration=4190, hf=0.92, queue=634, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 444545 paths in 674.87 seconds
# Starting search: ActionPathFinder (iteration=4215, hf=0.93, queue=627, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 447338 paths in 680.09 seconds
# Starting search: ActionPathFinder (iteration=4227, hf=0.94, queue=627, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 449959 paths in 685.23 seconds
# Starting search: ActionPathFinder (iteration=4238, hf=0.95, queue=621, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 453090 paths in 691.11 seconds
# Starting search: ActionPathFinder (iteration=4256, hf=0.96, queue=608, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 456572 paths in 697.54 seconds
# Starting search: ActionPathFinder (iteration=4272, hf=0.97, queue=604, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 460326 paths in 703.15 seconds
# Starting search: ActionPathFinder (iteration=4311, hf=0.98, queue=589, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 463506 paths in 708.98 seconds
# Starting search: ActionPathFinder (iteration=4346, hf=0.99, queue=597, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 467876 paths in 714.63 seconds
# Starting search: ActionPathFinder (iteration=4379, hf=0.9, queue=579, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Skipped 471797 paths in 720.39 seconds
# Starting search: ActionPathFinder (iteration=4400, hf=0.91, queue=660, seen=1559, last=ActionPath(g=487, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=486, h=2.5, hVelocity=SprintRight) in 723.41 seconds after 4410 iterations and 473254 skipped paths
# Starting search: ActionPathFinder (iteration=4410, hf=0.92, queue=677, seen=1559, last=ActionPath(g=486, h=2.5, hVelocity=SprintRight))
# Found path ActionPath(g=484, h=3.0, hVelocity=WalkRight) in 723.41 seconds after 4413 iterations and 473270 skipped paths
# Starting search: ActionPathFinder (iteration=4413, hf=0.93, queue=676, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 475748 paths in 728.72 seconds
# Starting search: ActionPathFinder (iteration=4428, hf=0.94, queue=665, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 478817 paths in 733.73 seconds
# Starting search: ActionPathFinder (iteration=4443, hf=0.95, queue=667, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 481875 paths in 739.16 seconds
# Starting search: ActionPathFinder (iteration=4475, hf=0.96, queue=655, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 485065 paths in 744.84 seconds
# Starting search: ActionPathFinder (iteration=4494, hf=0.97, queue=646, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 487402 paths in 750.12 seconds
# Starting search: ActionPathFinder (iteration=4518, hf=0.98, queue=635, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 491993 paths in 756.2 seconds
# Starting search: ActionPathFinder (iteration=4533, hf=0.99, queue=667, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 495146 paths in 762.0 seconds
# Starting search: ActionPathFinder (iteration=4584, hf=0.9, queue=629, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 497507 paths in 767.39 seconds
# Starting search: ActionPathFinder (iteration=4604, hf=0.91, queue=680, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 501515 paths in 772.72 seconds
# Starting search: ActionPathFinder (iteration=4646, hf=0.92, queue=689, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 504379 paths in 778.22 seconds
# Starting search: ActionPathFinder (iteration=4674, hf=0.93, queue=706, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 508729 paths in 783.71 seconds
# Starting search: ActionPathFinder (iteration=4696, hf=0.94, queue=708, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 511859 paths in 789.44 seconds
# Starting search: ActionPathFinder (iteration=4710, hf=0.95, queue=699, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 515393 paths in 795.73 seconds
# Starting search: ActionPathFinder (iteration=4731, hf=0.96, queue=689, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 520434 paths in 800.82 seconds
# Starting search: ActionPathFinder (iteration=4797, hf=0.97, queue=648, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 524687 paths in 806.37 seconds
# Starting search: ActionPathFinder (iteration=4813, hf=0.98, queue=646, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 528936 paths in 812.14 seconds
# Starting search: ActionPathFinder (iteration=4836, hf=0.99, queue=634, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 534810 paths in 817.82 seconds
# Starting search: ActionPathFinder (iteration=4880, hf=0.9, queue=614, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 538481 paths in 824.19 seconds
# Starting search: ActionPathFinder (iteration=4915, hf=0.91, queue=599, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 542061 paths in 830.17 seconds
# Starting search: ActionPathFinder (iteration=4936, hf=0.92, queue=603, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 545017 paths in 835.73 seconds
# Starting search: ActionPathFinder (iteration=4957, hf=0.93, queue=591, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 548034 paths in 841.59 seconds
# Starting search: ActionPathFinder (iteration=4973, hf=0.94, queue=598, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 551649 paths in 847.17 seconds
# Starting search: ActionPathFinder (iteration=5000, hf=0.95, queue=619, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 555713 paths in 852.23 seconds
# Starting search: ActionPathFinder (iteration=5033, hf=0.96, queue=603, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 559010 paths in 857.26 seconds
# Starting search: ActionPathFinder (iteration=5068, hf=0.97, queue=590, seen=1559, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 562723 paths in 863.31 seconds
# Starting search: ActionPathFinder (iteration=5104, hf=0.98, queue=600, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 565548 paths in 868.56 seconds
# Starting search: ActionPathFinder (iteration=5149, hf=0.99, queue=597, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 568553 paths in 873.67 seconds
# Starting search: ActionPathFinder (iteration=5170, hf=0.9, queue=627, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 571433 paths in 879.67 seconds
# Starting search: ActionPathFinder (iteration=5183, hf=0.91, queue=640, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 574016 paths in 885.69 seconds
# Starting search: ActionPathFinder (iteration=5200, hf=0.92, queue=643, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 576523 paths in 890.76 seconds
# Starting search: ActionPathFinder (iteration=5212, hf=0.93, queue=639, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 578853 paths in 896.04 seconds
# Starting search: ActionPathFinder (iteration=5224, hf=0.94, queue=658, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 581103 paths in 901.56 seconds
# Starting search: ActionPathFinder (iteration=5254, hf=0.95, queue=638, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 583190 paths in 907.6 seconds
# Starting search: ActionPathFinder (iteration=5290, hf=0.96, queue=619, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 586712 paths in 912.88 seconds
# Starting search: ActionPathFinder (iteration=5334, hf=0.97, queue=636, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 590481 paths in 918.0 seconds
# Starting search: ActionPathFinder (iteration=5371, hf=0.98, queue=623, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 592851 paths in 923.03 seconds
# Starting search: ActionPathFinder (iteration=5423, hf=0.99, queue=604, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 595710 paths in 928.35 seconds
# Starting search: ActionPathFinder (iteration=5463, hf=0.9, queue=593, seen=1560, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 597171 paths in 933.43 seconds
# Starting search: ActionPathFinder (iteration=5492, hf=0.91, queue=581, seen=1562, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 599665 paths in 938.97 seconds
# Starting search: ActionPathFinder (iteration=5517, hf=0.92, queue=592, seen=1563, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 602661 paths in 944.94 seconds
# Starting search: ActionPathFinder (iteration=5578, hf=0.93, queue=554, seen=1564, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 605971 paths in 950.47 seconds
# Starting search: ActionPathFinder (iteration=5606, hf=0.94, queue=554, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 608757 paths in 955.76 seconds
# Starting search: ActionPathFinder (iteration=5631, hf=0.95, queue=538, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 611565 paths in 960.93 seconds
# Starting search: ActionPathFinder (iteration=5650, hf=0.96, queue=534, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 614110 paths in 966.47 seconds
# Starting search: ActionPathFinder (iteration=5684, hf=0.97, queue=516, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 617700 paths in 972.1 seconds
# Starting search: ActionPathFinder (iteration=5699, hf=0.98, queue=508, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 621345 paths in 978.09 seconds
# Starting search: ActionPathFinder (iteration=5712, hf=0.99, queue=510, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 624401 paths in 983.13 seconds
# Starting search: ActionPathFinder (iteration=5727, hf=0.9, queue=503, seen=1566, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 628355 paths in 988.77 seconds
# Starting search: ActionPathFinder (iteration=5760, hf=0.91, queue=515, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 632972 paths in 994.52 seconds
# Starting search: ActionPathFinder (iteration=5801, hf=0.92, queue=534, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 636609 paths in 999.92 seconds
# Starting search: ActionPathFinder (iteration=5840, hf=0.93, queue=512, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 640482 paths in 1005.35 seconds
# Starting search: ActionPathFinder (iteration=5871, hf=0.94, queue=505, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 643888 paths in 1010.54 seconds
# Starting search: ActionPathFinder (iteration=5895, hf=0.95, queue=508, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 646288 paths in 1015.64 seconds
# Starting search: ActionPathFinder (iteration=5939, hf=0.96, queue=484, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 651484 paths in 1020.85 seconds
# Starting search: ActionPathFinder (iteration=5984, hf=0.97, queue=509, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 657560 paths in 1025.9 seconds
# Starting search: ActionPathFinder (iteration=6011, hf=0.98, queue=494, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 662894 paths in 1030.94 seconds
# Starting search: ActionPathFinder (iteration=6051, hf=0.99, queue=488, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 668555 paths in 1036.02 seconds
# Starting search: ActionPathFinder (iteration=6078, hf=0.9, queue=465, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 672458 paths in 1041.33 seconds
# Starting search: ActionPathFinder (iteration=6124, hf=0.91, queue=491, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 676546 paths in 1046.85 seconds
# Starting search: ActionPathFinder (iteration=6180, hf=0.92, queue=451, seen=1567, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 681523 paths in 1052.23 seconds
# Starting search: ActionPathFinder (iteration=6235, hf=0.93, queue=475, seen=1569, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 685476 paths in 1058.11 seconds
# Starting search: ActionPathFinder (iteration=6262, hf=0.94, queue=590, seen=1569, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 688853 paths in 1063.13 seconds
# Starting search: ActionPathFinder (iteration=6290, hf=0.95, queue=745, seen=1569, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Skipped 690685 paths in 1068.55 seconds
# Starting search: ActionPathFinder (iteration=6315, hf=0.96, queue=769, seen=1569, last=ActionPath(g=484, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=479, h=2.5, hVelocity=WalkRight) in 1070.26 seconds after 6321 iterations and 691341 skipped paths
# Starting search: ActionPathFinder (iteration=6321, hf=0.97, queue=768, seen=1569, last=ActionPath(g=479, h=2.5, hVelocity=WalkRight))
# Found path ActionPath(g=476, h=3.0, hVelocity=WalkRight) in 1070.26 seconds after 6324 iterations and 691365 skipped paths
# Starting search: ActionPathFinder (iteration=6324, hf=0.98, queue=766, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 693212 paths in 1075.65 seconds
# Starting search: ActionPathFinder (iteration=6338, hf=0.99, queue=757, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 699120 paths in 1080.86 seconds
# Starting search: ActionPathFinder (iteration=6374, hf=0.9, queue=753, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 701320 paths in 1086.45 seconds
# Starting search: ActionPathFinder (iteration=6398, hf=0.91, queue=758, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 704878 paths in 1092.89 seconds
# Starting search: ActionPathFinder (iteration=6429, hf=0.92, queue=745, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 708964 paths in 1098.2 seconds
# Starting search: ActionPathFinder (iteration=6458, hf=0.93, queue=752, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 712895 paths in 1103.87 seconds
# Starting search: ActionPathFinder (iteration=6489, hf=0.94, queue=742, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 715862 paths in 1110.07 seconds
# Starting search: ActionPathFinder (iteration=6498, hf=0.95, queue=740, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 718600 paths in 1115.48 seconds
# Starting search: ActionPathFinder (iteration=6521, hf=0.96, queue=724, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 721377 paths in 1120.62 seconds
# Starting search: ActionPathFinder (iteration=6549, hf=0.97, queue=707, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 724653 paths in 1126.42 seconds
# Starting search: ActionPathFinder (iteration=6566, hf=0.98, queue=695, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 728879 paths in 1132.03 seconds
# Starting search: ActionPathFinder (iteration=6604, hf=0.99, queue=689, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 732274 paths in 1137.59 seconds
# Starting search: ActionPathFinder (iteration=6661, hf=0.9, queue=692, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 735251 paths in 1142.87 seconds
# Starting search: ActionPathFinder (iteration=6679, hf=0.91, queue=699, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 738258 paths in 1148.12 seconds
# Starting search: ActionPathFinder (iteration=6703, hf=0.92, queue=690, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 741769 paths in 1153.41 seconds
# Starting search: ActionPathFinder (iteration=6746, hf=0.93, queue=752, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Skipped 744375 paths in 1159.36 seconds
# Starting search: ActionPathFinder (iteration=6762, hf=0.94, queue=771, seen=1569, last=ActionPath(g=476, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=475, h=2.5, hVelocity=SprintRight) in 1159.36 seconds after 6765 iterations and 744391 skipped paths
# Starting search: ActionPathFinder (iteration=6765, hf=0.95, queue=771, seen=1569, last=ActionPath(g=475, h=2.5, hVelocity=SprintRight))
# Found path ActionPath(g=473, h=3.0, hVelocity=WalkRight) in 1159.36 seconds after 6767 iterations and 744407 skipped paths
# Starting search: ActionPathFinder (iteration=6767, hf=0.96, queue=770, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 747268 paths in 1164.45 seconds
# Starting search: ActionPathFinder (iteration=6783, hf=0.97, queue=762, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 750555 paths in 1170.04 seconds
# Starting search: ActionPathFinder (iteration=6799, hf=0.98, queue=765, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 753103 paths in 1175.16 seconds
# Starting search: ActionPathFinder (iteration=6829, hf=0.99, queue=747, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 756306 paths in 1180.74 seconds
# Starting search: ActionPathFinder (iteration=6856, hf=0.9, queue=735, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 759394 paths in 1186.73 seconds
# Starting search: ActionPathFinder (iteration=6877, hf=0.91, queue=730, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 761834 paths in 1191.74 seconds
# Starting search: ActionPathFinder (iteration=6897, hf=0.92, queue=757, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 764677 paths in 1196.91 seconds
# Starting search: ActionPathFinder (iteration=6925, hf=0.93, queue=804, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 768005 paths in 1203.28 seconds
# Starting search: ActionPathFinder (iteration=6976, hf=0.94, queue=769, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 773516 paths in 1209.07 seconds
# Starting search: ActionPathFinder (iteration=7027, hf=0.95, queue=749, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 777486 paths in 1215.05 seconds
# Starting search: ActionPathFinder (iteration=7058, hf=0.96, queue=778, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 781304 paths in 1220.8 seconds
# Starting search: ActionPathFinder (iteration=7076, hf=0.97, queue=776, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 784938 paths in 1226.92 seconds
# Starting search: ActionPathFinder (iteration=7088, hf=0.98, queue=778, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 788491 paths in 1233.02 seconds
# Starting search: ActionPathFinder (iteration=7114, hf=0.99, queue=762, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 792904 paths in 1238.87 seconds
# Starting search: ActionPathFinder (iteration=7152, hf=0.9, queue=747, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 796188 paths in 1244.38 seconds
# Starting search: ActionPathFinder (iteration=7189, hf=0.91, queue=729, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 800077 paths in 1250.5 seconds
# Starting search: ActionPathFinder (iteration=7219, hf=0.92, queue=725, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 804583 paths in 1256.35 seconds
# Starting search: ActionPathFinder (iteration=7242, hf=0.93, queue=721, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 808214 paths in 1261.46 seconds
# Starting search: ActionPathFinder (iteration=7261, hf=0.94, queue=710, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 811720 paths in 1266.66 seconds
# Starting search: ActionPathFinder (iteration=7276, hf=0.95, queue=699, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 816303 paths in 1272.01 seconds
# Starting search: ActionPathFinder (iteration=7296, hf=0.96, queue=695, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 822196 paths in 1278.41 seconds
# Starting search: ActionPathFinder (iteration=7348, hf=0.97, queue=708, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 825971 paths in 1283.88 seconds
# Starting search: ActionPathFinder (iteration=7393, hf=0.98, queue=692, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 829506 paths in 1288.89 seconds
# Starting search: ActionPathFinder (iteration=7416, hf=0.99, queue=679, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 833108 paths in 1294.12 seconds
# Starting search: ActionPathFinder (iteration=7466, hf=0.9, queue=673, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 835987 paths in 1300.14 seconds
# Starting search: ActionPathFinder (iteration=7481, hf=0.91, queue=686, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 837978 paths in 1305.78 seconds
# Starting search: ActionPathFinder (iteration=7500, hf=0.92, queue=690, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 841134 paths in 1311.96 seconds
# Starting search: ActionPathFinder (iteration=7517, hf=0.93, queue=685, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 844201 paths in 1318.29 seconds
# Starting search: ActionPathFinder (iteration=7532, hf=0.94, queue=696, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 847178 paths in 1324.47 seconds
# Starting search: ActionPathFinder (iteration=7553, hf=0.95, queue=695, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 848958 paths in 1329.57 seconds
# Starting search: ActionPathFinder (iteration=7586, hf=0.96, queue=682, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 852444 paths in 1335.11 seconds
# Starting search: ActionPathFinder (iteration=7633, hf=0.97, queue=708, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 855656 paths in 1340.42 seconds
# Starting search: ActionPathFinder (iteration=7661, hf=0.98, queue=721, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 859668 paths in 1345.8 seconds
# Starting search: ActionPathFinder (iteration=7715, hf=0.99, queue=717, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 863584 paths in 1351.07 seconds
# Starting search: ActionPathFinder (iteration=7757, hf=0.9, queue=713, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 865058 paths in 1356.54 seconds
# Starting search: ActionPathFinder (iteration=7799, hf=0.91, queue=689, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 867809 paths in 1362.47 seconds
# Starting search: ActionPathFinder (iteration=7817, hf=0.92, queue=708, seen=1569, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 870797 paths in 1367.81 seconds
# Starting search: ActionPathFinder (iteration=7837, hf=0.93, queue=704, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 873165 paths in 1372.95 seconds
# Starting search: ActionPathFinder (iteration=7856, hf=0.94, queue=691, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 875681 paths in 1378.23 seconds
# Starting search: ActionPathFinder (iteration=7913, hf=0.95, queue=676, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 877797 paths in 1383.35 seconds
# Starting search: ActionPathFinder (iteration=7964, hf=0.96, queue=656, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 880619 paths in 1388.79 seconds
# Starting search: ActionPathFinder (iteration=7996, hf=0.97, queue=639, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 883641 paths in 1393.91 seconds
# Starting search: ActionPathFinder (iteration=8021, hf=0.98, queue=639, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 886324 paths in 1398.92 seconds
# Starting search: ActionPathFinder (iteration=8042, hf=0.99, queue=627, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# Skipped 889292 paths in 1404.3 seconds
# Starting search: ActionPathFinder (iteration=8051, hf=0.9, queue=621, seen=1570, last=ActionPath(g=473, h=3.0, hVelocity=WalkRight))
# ...
# Starting search: ActionPathFinder (iteration=9791, hf=0.98, queue=499, seen=1579, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1099164 paths in 1719.02 seconds
# Starting search: ActionPathFinder (iteration=9834, hf=0.99, queue=536, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1102673 paths in 1724.03 seconds
# Starting search: ActionPathFinder (iteration=9880, hf=0.9, queue=518, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1105022 paths in 1729.13 seconds
# Starting search: ActionPathFinder (iteration=9904, hf=0.91, queue=507, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1107514 paths in 1734.26 seconds
# Starting search: ActionPathFinder (iteration=9921, hf=0.92, queue=512, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1109561 paths in 1739.79 seconds
# Starting search: ActionPathFinder (iteration=9937, hf=0.93, queue=507, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1112157 paths in 1745.89 seconds
# Starting search: ActionPathFinder (iteration=9970, hf=0.94, queue=511, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1115232 paths in 1751.7 seconds
# Starting search: ActionPathFinder (iteration=10028, hf=0.95, queue=488, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1118362 paths in 1757.51 seconds
# Starting search: ActionPathFinder (iteration=10074, hf=0.96, queue=457, seen=1582, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1121190 paths in 1763.05 seconds
# Starting search: ActionPathFinder (iteration=10099, hf=0.97, queue=447, seen=1583, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1124527 paths in 1768.38 seconds
# Starting search: ActionPathFinder (iteration=10119, hf=0.98, queue=439, seen=1583, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1127382 paths in 1773.5 seconds
# Starting search: ActionPathFinder (iteration=10167, hf=0.99, queue=425, seen=1584, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1133210 paths in 1778.52 seconds
# Starting search: ActionPathFinder (iteration=10207, hf=0.9, queue=431, seen=1584, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1137553 paths in 1783.96 seconds
# Starting search: ActionPathFinder (iteration=10241, hf=0.91, queue=435, seen=1584, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1141955 paths in 1789.22 seconds
# Starting search: ActionPathFinder (iteration=10300, hf=0.92, queue=399, seen=1584, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1146918 paths in 1795.12 seconds
# Starting search: ActionPathFinder (iteration=10377, hf=0.93, queue=342, seen=1586, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1154127 paths in 1800.4 seconds
# Starting search: ActionPathFinder (iteration=10455, hf=0.94, queue=287, seen=1588, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1157641 paths in 1805.59 seconds
# Starting search: ActionPathFinder (iteration=10513, hf=0.95, queue=242, seen=1592, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1161855 paths in 1810.9 seconds
# Starting search: ActionPathFinder (iteration=10628, hf=0.96, queue=406, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1167840 paths in 1816.24 seconds
# Starting search: ActionPathFinder (iteration=10680, hf=0.97, queue=417, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1170715 paths in 1821.25 seconds
# Starting search: ActionPathFinder (iteration=10707, hf=0.98, queue=430, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1175469 paths in 1826.26 seconds
# Starting search: ActionPathFinder (iteration=10728, hf=0.99, queue=429, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1181440 paths in 1831.53 seconds
# Starting search: ActionPathFinder (iteration=10776, hf=0.9, queue=401, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1186108 paths in 1836.6 seconds
# Starting search: ActionPathFinder (iteration=10826, hf=0.91, queue=456, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1190956 paths in 1841.65 seconds
# Starting search: ActionPathFinder (iteration=10871, hf=0.92, queue=481, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1196482 paths in 1846.96 seconds
# Starting search: ActionPathFinder (iteration=10913, hf=0.93, queue=449, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1202952 paths in 1852.37 seconds
# Starting search: ActionPathFinder (iteration=10945, hf=0.94, queue=465, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1208746 paths in 1857.86 seconds
# Starting search: ActionPathFinder (iteration=10984, hf=0.95, queue=457, seen=1680, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1212598 paths in 1862.97 seconds
# Starting search: ActionPathFinder (iteration=11038, hf=0.96, queue=479, seen=1681, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1216367 paths in 1868.13 seconds
# Starting search: ActionPathFinder (iteration=11095, hf=0.97, queue=448, seen=1681, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1219286 paths in 1874.0 seconds
# Starting search: ActionPathFinder (iteration=11170, hf=0.98, queue=440, seen=1683, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1221974 paths in 1879.29 seconds
# Starting search: ActionPathFinder (iteration=11226, hf=0.99, queue=429, seen=1684, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1224006 paths in 1884.35 seconds
# Starting search: ActionPathFinder (iteration=11269, hf=0.9, queue=405, seen=1684, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1226422 paths in 1889.56 seconds
# Starting search: ActionPathFinder (iteration=11325, hf=0.91, queue=401, seen=1686, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1230328 paths in 1895.13 seconds
# Starting search: ActionPathFinder (iteration=11365, hf=0.92, queue=418, seen=1704, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1233115 paths in 1900.14 seconds
# Starting search: ActionPathFinder (iteration=11414, hf=0.93, queue=426, seen=1726, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1235657 paths in 1905.2 seconds
# Starting search: ActionPathFinder (iteration=11452, hf=0.94, queue=414, seen=1731, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1239442 paths in 1910.85 seconds
# Starting search: ActionPathFinder (iteration=11468, hf=0.95, queue=414, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1242811 paths in 1916.31 seconds
# Starting search: ActionPathFinder (iteration=11482, hf=0.96, queue=405, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1246420 paths in 1922.01 seconds
# Starting search: ActionPathFinder (iteration=11494, hf=0.97, queue=411, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1249968 paths in 1927.69 seconds
# Starting search: ActionPathFinder (iteration=11509, hf=0.98, queue=404, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1253416 paths in 1932.9 seconds
# Starting search: ActionPathFinder (iteration=11523, hf=0.99, queue=401, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1257287 paths in 1938.84 seconds
# Starting search: ActionPathFinder (iteration=11539, hf=0.9, queue=399, seen=1732, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1264303 paths in 1944.37 seconds
# Starting search: ActionPathFinder (iteration=11572, hf=0.91, queue=395, seen=1735, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1269486 paths in 1949.56 seconds
# Starting search: ActionPathFinder (iteration=11597, hf=0.92, queue=380, seen=1736, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1274228 paths in 1954.6 seconds
# Starting search: ActionPathFinder (iteration=11641, hf=0.93, queue=371, seen=1743, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1277715 paths in 1960.18 seconds
# Starting search: ActionPathFinder (iteration=11658, hf=0.94, queue=388, seen=1743, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1280940 paths in 1965.45 seconds
# Starting search: ActionPathFinder (iteration=11681, hf=0.95, queue=372, seen=1743, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1283496 paths in 1970.65 seconds
# Starting search: ActionPathFinder (iteration=11726, hf=0.96, queue=383, seen=1748, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1287081 paths in 1976.27 seconds
# Starting search: ActionPathFinder (iteration=11748, hf=0.97, queue=379, seen=1748, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1290589 paths in 1981.91 seconds
# Starting search: ActionPathFinder (iteration=11771, hf=0.98, queue=368, seen=1748, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1293710 paths in 1987.0 seconds
# Starting search: ActionPathFinder (iteration=11830, hf=0.99, queue=319, seen=1748, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1298886 paths in 1992.43 seconds
# Starting search: ActionPathFinder (iteration=11881, hf=0.9, queue=278, seen=1750, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1303125 paths in 1997.51 seconds
# Starting search: ActionPathFinder (iteration=11942, hf=0.91, queue=267, seen=1763, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1307805 paths in 2002.99 seconds
# Starting search: ActionPathFinder (iteration=11984, hf=0.92, queue=365, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1311930 paths in 2008.68 seconds
# Starting search: ActionPathFinder (iteration=12008, hf=0.93, queue=362, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1317589 paths in 2013.79 seconds
# Starting search: ActionPathFinder (iteration=12034, hf=0.94, queue=377, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1322228 paths in 2019.28 seconds
# Starting search: ActionPathFinder (iteration=12074, hf=0.95, queue=420, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1327149 paths in 2024.7 seconds
# Starting search: ActionPathFinder (iteration=12133, hf=0.96, queue=383, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1330143 paths in 2029.93 seconds
# Starting search: ActionPathFinder (iteration=12177, hf=0.97, queue=399, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1332103 paths in 2035.14 seconds
# Starting search: ActionPathFinder (iteration=12238, hf=0.98, queue=382, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1334708 paths in 2040.39 seconds
# Starting search: ActionPathFinder (iteration=12285, hf=0.99, queue=366, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1337693 paths in 2045.95 seconds
# Starting search: ActionPathFinder (iteration=12319, hf=0.9, queue=354, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1340926 paths in 2051.48 seconds
# Starting search: ActionPathFinder (iteration=12365, hf=0.91, queue=379, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1346261 paths in 2056.5 seconds
# Starting search: ActionPathFinder (iteration=12422, hf=0.92, queue=379, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1349570 paths in 2061.58 seconds
# Starting search: ActionPathFinder (iteration=12450, hf=0.93, queue=358, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1353617 paths in 2066.7 seconds
# Starting search: ActionPathFinder (iteration=12474, hf=0.94, queue=347, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1356619 paths in 2071.76 seconds
# Starting search: ActionPathFinder (iteration=12506, hf=0.95, queue=347, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1360346 paths in 2077.41 seconds
# Starting search: ActionPathFinder (iteration=12528, hf=0.96, queue=368, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1363920 paths in 2082.89 seconds
# Starting search: ActionPathFinder (iteration=12549, hf=0.97, queue=357, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1368537 paths in 2088.35 seconds
# Starting search: ActionPathFinder (iteration=12604, hf=0.98, queue=318, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1373882 paths in 2093.65 seconds
# Starting search: ActionPathFinder (iteration=12638, hf=0.99, queue=301, seen=1766, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1377540 paths in 2098.76 seconds
# Starting search: ActionPathFinder (iteration=12683, hf=0.9, queue=303, seen=1770, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1382391 paths in 2104.06 seconds
# Starting search: ActionPathFinder (iteration=12738, hf=0.91, queue=276, seen=1774, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1388253 paths in 2109.21 seconds
# Starting search: ActionPathFinder (iteration=12774, hf=0.92, queue=254, seen=1784, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1397835 paths in 2114.64 seconds
# Starting search: ActionPathFinder (iteration=12877, hf=0.93, queue=185, seen=1806, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1404567 paths in 2120.13 seconds
# Starting search: ActionPathFinder (iteration=12950, hf=0.94, queue=131, seen=1810, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1413271 paths in 2125.28 seconds
# Starting search: ActionPathFinder (iteration=13000, hf=0.95, queue=95, seen=1819, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1419859 paths in 2130.29 seconds
# Starting search: ActionPathFinder (iteration=13032, hf=0.96, queue=80, seen=1832, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1424623 paths in 2135.32 seconds
# Starting search: ActionPathFinder (iteration=13052, hf=0.97, queue=76, seen=1834, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1432930 paths in 2141.07 seconds
# Starting search: ActionPathFinder (iteration=13072, hf=0.98, queue=63, seen=1835, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1437521 paths in 2146.08 seconds
# Starting search: ActionPathFinder (iteration=13086, hf=0.99, queue=65, seen=1837, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1442063 paths in 2151.47 seconds
# Starting search: ActionPathFinder (iteration=13105, hf=0.9, queue=53, seen=1841, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Skipped 1449000 paths in 2157.24 seconds
# Starting search: ActionPathFinder (iteration=13151, hf=0.91, queue=26, seen=1849, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.92, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.93, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.94, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.95, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.96, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.97, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.98, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=13178, hf=0.99, queue=0, seen=1850, last=ActionPath(g=467, h=2.5, hVelocity=SprintRight))
# PlotTensor: 0 94

# %%
pathFinder.plotAnimation(fps=30, skipFrames=50)
break
# Out:
# 270
# PlotTensor: 0 94
#   Cell In[8], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 94

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
