# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'CWYY-0ZNT'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)
print(Rect(pathFinder.blockMap.rtree.bounds).size)
print(len(pathFinder.blockMap.blocks))

pathFinder.plotPaths()
# Out:
# Device used: cpu
# Flood fill steps: 359
# GoalDistanceFlood: Start Position: (-23.6299989, 1.5200000999999999), Goal Positions: [(-30.5, 7.5)], Goal Distance: 173.0
# (82.0, 48.0)
# 302
# PlotTensor: -0.5 179.0

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 3015 paths in 5.29 seconds
# Starting search: ActionPathFinder (iteration=18, hf=0.91, queue=135, seen=120, last=None)
# Skipped 5493 paths in 10.35 seconds
# Starting search: ActionPathFinder (iteration=34, hf=0.92, queue=258, seen=240, last=None)
# Skipped 7863 paths in 15.41 seconds
# Starting search: ActionPathFinder (iteration=50, hf=0.93, queue=330, seen=306, last=None)
# Skipped 11891 paths in 20.8 seconds
# Starting search: ActionPathFinder (iteration=70, hf=0.94, queue=338, seen=323, last=None)
# Skipped 17920 paths in 26.39 seconds
# Starting search: ActionPathFinder (iteration=98, hf=0.95, queue=481, seen=473, last=None)
# Skipped 20956 paths in 31.51 seconds
# Starting search: ActionPathFinder (iteration=119, hf=0.96, queue=539, seen=541, last=None)
# Found path ActionPath(g=1133, h=-0.5, hVelocity=SprintRight) in 33.0 seconds after 127 iterations and 21791 skipped paths
# Starting search: ActionPathFinder (iteration=127, hf=0.97, queue=598, seen=594, last=ActionPath(g=1133, h=-0.5, hVelocity=SprintRight))
# Skipped 23951 paths in 38.49 seconds
# Starting search: ActionPathFinder (iteration=176, hf=0.98, queue=565, seen=606, last=ActionPath(g=1133, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1125, h=-0.5, hVelocity=SprintRight) in 39.98 seconds after 185 iterations and 24794 skipped paths
# Starting search: ActionPathFinder (iteration=185, hf=0.99, queue=610, seen=606, last=ActionPath(g=1125, h=-0.5, hVelocity=SprintRight))
# Skipped 27247 paths in 45.52 seconds
# Starting search: ActionPathFinder (iteration=231, hf=0.9, queue=581, seen=614, last=ActionPath(g=1125, h=-0.5, hVelocity=SprintRight))
# Skipped 30321 paths in 51.2 seconds
# Starting search: ActionPathFinder (iteration=248, hf=0.91, queue=628, seen=623, last=ActionPath(g=1125, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1124, h=-0.5, hVelocity=SprintRight) in 53.52 seconds after 264 iterations and 31687 skipped paths
# Starting search: ActionPathFinder (iteration=264, hf=0.92, queue=629, seen=623, last=ActionPath(g=1124, h=-0.5, hVelocity=SprintRight))
# Skipped 34794 paths in 59.5 seconds
# Starting search: ActionPathFinder (iteration=312, hf=0.93, queue=609, seen=629, last=ActionPath(g=1124, h=-0.5, hVelocity=SprintRight))
# Skipped 37717 paths in 65.07 seconds
# Starting search: ActionPathFinder (iteration=334, hf=0.94, queue=640, seen=629, last=ActionPath(g=1124, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1120, h=-0.5, hVelocity=SprintRight) in 65.85 seconds after 337 iterations and 38296 skipped paths
# Starting search: ActionPathFinder (iteration=337, hf=0.95, queue=656, seen=629, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 40241 paths in 71.04 seconds
# Starting search: ActionPathFinder (iteration=371, hf=0.96, queue=634, seen=629, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 42830 paths in 76.71 seconds
# Starting search: ActionPathFinder (iteration=395, hf=0.97, queue=629, seen=641, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 45975 paths in 81.93 seconds
# Starting search: ActionPathFinder (iteration=412, hf=0.98, queue=627, seen=644, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 48340 paths in 87.24 seconds
# Starting search: ActionPathFinder (iteration=440, hf=0.99, queue=609, seen=653, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 51483 paths in 92.96 seconds
# Starting search: ActionPathFinder (iteration=457, hf=0.9, queue=605, seen=665, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Skipped 54351 paths in 98.69 seconds
# Starting search: ActionPathFinder (iteration=479, hf=0.91, queue=651, seen=668, last=ActionPath(g=1120, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1117, h=-0.5, hVelocity=SprintRight) in 103.45 seconds after 497 iterations and 56814 skipped paths
# Starting search: ActionPathFinder (iteration=497, hf=0.92, queue=684, seen=668, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 58970 paths in 108.58 seconds
# Starting search: ActionPathFinder (iteration=545, hf=0.93, queue=669, seen=671, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 62042 paths in 114.42 seconds
# Starting search: ActionPathFinder (iteration=568, hf=0.94, queue=674, seen=672, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 64379 paths in 119.45 seconds
# Starting search: ActionPathFinder (iteration=600, hf=0.95, queue=657, seen=672, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 66217 paths in 124.56 seconds
# Starting search: ActionPathFinder (iteration=623, hf=0.96, queue=666, seen=679, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 68383 paths in 130.06 seconds
# Starting search: ActionPathFinder (iteration=639, hf=0.97, queue=675, seen=687, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 70623 paths in 135.32 seconds
# Starting search: ActionPathFinder (iteration=670, hf=0.98, queue=676, seen=687, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 72716 paths in 140.37 seconds
# Starting search: ActionPathFinder (iteration=699, hf=0.99, queue=658, seen=689, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 76269 paths in 145.86 seconds
# Starting search: ActionPathFinder (iteration=712, hf=0.9, queue=656, seen=692, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 80629 paths in 151.69 seconds
# Starting search: ActionPathFinder (iteration=736, hf=0.91, queue=703, seen=718, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Skipped 83849 paths in 157.47 seconds
# Starting search: ActionPathFinder (iteration=760, hf=0.92, queue=765, seen=724, last=ActionPath(g=1117, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1109, h=-0.5, hVelocity=SprintRight) in 160.32 seconds after 772 iterations and 85263 skipped paths
# Starting search: ActionPathFinder (iteration=772, hf=0.93, queue=782, seen=724, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 87438 paths in 165.86 seconds
# Starting search: ActionPathFinder (iteration=812, hf=0.94, queue=775, seen=724, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 90526 paths in 171.27 seconds
# Starting search: ActionPathFinder (iteration=837, hf=0.95, queue=766, seen=724, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 93843 paths in 176.99 seconds
# Starting search: ActionPathFinder (iteration=856, hf=0.96, queue=780, seen=725, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 96947 paths in 182.27 seconds
# Starting search: ActionPathFinder (iteration=870, hf=0.97, queue=786, seen=725, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 99834 paths in 187.65 seconds
# Starting search: ActionPathFinder (iteration=890, hf=0.98, queue=781, seen=727, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 102245 paths in 193.08 seconds
# Starting search: ActionPathFinder (iteration=915, hf=0.99, queue=770, seen=727, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 105689 paths in 198.39 seconds
# Starting search: ActionPathFinder (iteration=955, hf=0.9, queue=750, seen=729, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 108855 paths in 203.67 seconds
# Starting search: ActionPathFinder (iteration=973, hf=0.91, queue=767, seen=739, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Skipped 111908 paths in 208.87 seconds
# Starting search: ActionPathFinder (iteration=990, hf=0.92, queue=841, seen=739, last=ActionPath(g=1109, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1093, h=-0.5, hVelocity=SprintRight) in 211.66 seconds after 1005 iterations and 113311 skipped paths
# Starting search: ActionPathFinder (iteration=1005, hf=0.93, queue=867, seen=739, last=ActionPath(g=1093, h=-0.5, hVelocity=SprintRight))
# Skipped 115617 paths in 216.83 seconds
# Starting search: ActionPathFinder (iteration=1050, hf=0.94, queue=832, seen=739, last=ActionPath(g=1093, h=-0.5, hVelocity=SprintRight))
# Skipped 118901 paths in 222.52 seconds
# Starting search: ActionPathFinder (iteration=1082, hf=0.95, queue=828, seen=739, last=ActionPath(g=1093, h=-0.5, hVelocity=SprintRight))
# Skipped 122122 paths in 228.09 seconds
# Starting search: ActionPathFinder (iteration=1100, hf=0.96, queue=849, seen=739, last=ActionPath(g=1093, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1092, h=-0.5, hVelocity=SprintRight) in 231.89 seconds after 1113 iterations and 123854 skipped paths
# Starting search: ActionPathFinder (iteration=1113, hf=0.97, queue=884, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Skipped 125654 paths in 236.92 seconds
# Starting search: ActionPathFinder (iteration=1150, hf=0.98, queue=859, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Skipped 128410 paths in 242.31 seconds
# Starting search: ActionPathFinder (iteration=1169, hf=0.99, queue=861, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Skipped 131288 paths in 248.1 seconds
# Starting search: ActionPathFinder (iteration=1190, hf=0.9, queue=853, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Skipped 134495 paths in 253.53 seconds
# Starting search: ActionPathFinder (iteration=1208, hf=0.91, queue=890, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Skipped 137004 paths in 259.03 seconds
# Starting search: ActionPathFinder (iteration=1229, hf=0.92, queue=907, seen=739, last=ActionPath(g=1092, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1089, h=-0.5, hVelocity=SprintRight) in 260.49 seconds after 1236 iterations and 137836 skipped paths
# Starting search: ActionPathFinder (iteration=1236, hf=0.93, queue=919, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 140044 paths in 265.58 seconds
# Starting search: ActionPathFinder (iteration=1285, hf=0.94, queue=905, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 142728 paths in 270.66 seconds
# Starting search: ActionPathFinder (iteration=1303, hf=0.95, queue=908, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 144749 paths in 276.05 seconds
# Starting search: ActionPathFinder (iteration=1336, hf=0.96, queue=888, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 146985 paths in 281.56 seconds
# Starting search: ActionPathFinder (iteration=1366, hf=0.97, queue=891, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 148788 paths in 287.2 seconds
# Starting search: ActionPathFinder (iteration=1388, hf=0.98, queue=895, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 151174 paths in 292.56 seconds
# Starting search: ActionPathFinder (iteration=1415, hf=0.99, queue=888, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 153703 paths in 298.05 seconds
# Starting search: ActionPathFinder (iteration=1447, hf=0.9, queue=886, seen=739, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 156102 paths in 303.56 seconds
# Starting search: ActionPathFinder (iteration=1475, hf=0.91, queue=876, seen=744, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 159157 paths in 309.21 seconds
# Starting search: ActionPathFinder (iteration=1514, hf=0.92, queue=858, seen=745, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Skipped 161754 paths in 314.55 seconds
# Starting search: ActionPathFinder (iteration=1537, hf=0.93, queue=887, seen=745, last=ActionPath(g=1089, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1085, h=-0.5, hVelocity=SprintRight) in 314.55 seconds after 1538 iterations and 162030 skipped paths
# Starting search: ActionPathFinder (iteration=1538, hf=0.94, queue=900, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 164035 paths in 319.88 seconds
# Starting search: ActionPathFinder (iteration=1573, hf=0.95, queue=899, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 166942 paths in 325.18 seconds
# Starting search: ActionPathFinder (iteration=1597, hf=0.96, queue=885, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 170542 paths in 330.94 seconds
# Starting search: ActionPathFinder (iteration=1615, hf=0.97, queue=895, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 173846 paths in 336.51 seconds
# Starting search: ActionPathFinder (iteration=1629, hf=0.98, queue=899, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 175963 paths in 342.05 seconds
# Starting search: ActionPathFinder (iteration=1650, hf=0.99, queue=894, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 179899 paths in 347.88 seconds
# Starting search: ActionPathFinder (iteration=1667, hf=0.9, queue=883, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 182170 paths in 353.04 seconds
# Starting search: ActionPathFinder (iteration=1696, hf=0.91, queue=887, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 184504 paths in 358.1 seconds
# Starting search: ActionPathFinder (iteration=1716, hf=0.92, queue=880, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 187669 paths in 363.12 seconds
# Starting search: ActionPathFinder (iteration=1768, hf=0.93, queue=837, seen=745, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 190859 paths in 368.17 seconds
# Starting search: ActionPathFinder (iteration=1798, hf=0.94, queue=838, seen=747, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 193445 paths in 373.5 seconds
# Starting search: ActionPathFinder (iteration=1819, hf=0.95, queue=841, seen=747, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 195440 paths in 379.01 seconds
# Starting search: ActionPathFinder (iteration=1838, hf=0.96, queue=858, seen=747, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 197387 paths in 384.22 seconds
# Starting search: ActionPathFinder (iteration=1867, hf=0.97, queue=843, seen=747, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 200849 paths in 389.93 seconds
# Starting search: ActionPathFinder (iteration=1885, hf=0.98, queue=837, seen=747, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 204439 paths in 394.94 seconds
# Starting search: ActionPathFinder (iteration=1918, hf=0.99, queue=820, seen=748, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 209035 paths in 400.1 seconds
# Starting search: ActionPathFinder (iteration=2030, hf=0.9, queue=716, seen=750, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 212457 paths in 405.34 seconds
# Starting search: ActionPathFinder (iteration=2051, hf=0.91, queue=723, seen=759, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 215501 paths in 410.76 seconds
# Starting search: ActionPathFinder (iteration=2072, hf=0.92, queue=723, seen=760, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Skipped 218870 paths in 416.59 seconds
# Starting search: ActionPathFinder (iteration=2096, hf=0.93, queue=774, seen=760, last=ActionPath(g=1085, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1077, h=-0.5, hVelocity=SprintRight) in 418.0 seconds after 2102 iterations and 219707 skipped paths
# Starting search: ActionPathFinder (iteration=2102, hf=0.94, queue=792, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 221703 paths in 423.08 seconds
# Starting search: ActionPathFinder (iteration=2142, hf=0.95, queue=765, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 224230 paths in 428.57 seconds
# Starting search: ActionPathFinder (iteration=2166, hf=0.96, queue=778, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 227077 paths in 433.76 seconds
# Starting search: ActionPathFinder (iteration=2187, hf=0.97, queue=774, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 229950 paths in 439.27 seconds
# Starting search: ActionPathFinder (iteration=2206, hf=0.98, queue=786, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 233439 paths in 445.03 seconds
# Starting search: ActionPathFinder (iteration=2230, hf=0.99, queue=769, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 236935 paths in 450.67 seconds
# Starting search: ActionPathFinder (iteration=2256, hf=0.9, queue=766, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 238920 paths in 455.95 seconds
# Starting search: ActionPathFinder (iteration=2282, hf=0.91, queue=764, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 241847 paths in 461.42 seconds
# Starting search: ActionPathFinder (iteration=2302, hf=0.92, queue=757, seen=760, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 245490 paths in 467.27 seconds
# Starting search: ActionPathFinder (iteration=2325, hf=0.93, queue=771, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 247920 paths in 472.91 seconds
# Starting search: ActionPathFinder (iteration=2344, hf=0.94, queue=775, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 249983 paths in 478.11 seconds
# Starting search: ActionPathFinder (iteration=2367, hf=0.95, queue=771, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 252322 paths in 483.64 seconds
# Starting search: ActionPathFinder (iteration=2389, hf=0.96, queue=765, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 255234 paths in 488.77 seconds
# Starting search: ActionPathFinder (iteration=2409, hf=0.97, queue=758, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 260076 paths in 494.54 seconds
# Starting search: ActionPathFinder (iteration=2448, hf=0.98, queue=727, seen=761, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 264722 paths in 500.31 seconds
# Starting search: ActionPathFinder (iteration=2512, hf=0.99, queue=673, seen=765, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 268937 paths in 506.0 seconds
# Starting search: ActionPathFinder (iteration=2580, hf=0.9, queue=606, seen=766, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 272318 paths in 511.37 seconds
# Starting search: ActionPathFinder (iteration=2596, hf=0.91, queue=599, seen=766, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 275918 paths in 516.7 seconds
# Starting search: ActionPathFinder (iteration=2639, hf=0.92, queue=573, seen=775, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 278832 paths in 522.04 seconds
# Starting search: ActionPathFinder (iteration=2664, hf=0.93, queue=562, seen=775, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 281849 paths in 527.38 seconds
# Starting search: ActionPathFinder (iteration=2713, hf=0.94, queue=526, seen=781, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 285311 paths in 532.73 seconds
# Starting search: ActionPathFinder (iteration=2776, hf=0.95, queue=484, seen=783, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 288501 paths in 537.84 seconds
# Starting search: ActionPathFinder (iteration=2792, hf=0.96, queue=478, seen=791, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 291866 paths in 543.17 seconds
# Starting search: ActionPathFinder (iteration=2819, hf=0.97, queue=475, seen=799, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 295437 paths in 548.18 seconds
# Starting search: ActionPathFinder (iteration=2836, hf=0.98, queue=477, seen=807, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 299840 paths in 553.73 seconds
# Starting search: ActionPathFinder (iteration=2867, hf=0.99, queue=458, seen=810, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 303756 paths in 559.16 seconds
# Starting search: ActionPathFinder (iteration=2903, hf=0.9, queue=470, seen=810, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 308124 paths in 565.01 seconds
# Starting search: ActionPathFinder (iteration=2925, hf=0.91, queue=494, seen=810, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 310850 paths in 570.61 seconds
# Starting search: ActionPathFinder (iteration=2948, hf=0.92, queue=507, seen=810, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Skipped 313745 paths in 576.21 seconds
# Starting search: ActionPathFinder (iteration=2972, hf=0.93, queue=579, seen=810, last=ActionPath(g=1077, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1063, h=-0.5, hVelocity=SprintRight) in 576.21 seconds after 2977 iterations and 314010 skipped paths
# Starting search: ActionPathFinder (iteration=2977, hf=0.94, queue=600, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 316220 paths in 581.32 seconds
# Starting search: ActionPathFinder (iteration=3028, hf=0.95, queue=573, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 318502 paths in 586.56 seconds
# Starting search: ActionPathFinder (iteration=3047, hf=0.96, queue=573, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 321281 paths in 591.75 seconds
# Starting search: ActionPathFinder (iteration=3065, hf=0.97, queue=583, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 324314 paths in 597.66 seconds
# Starting search: ActionPathFinder (iteration=3084, hf=0.98, queue=586, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 327635 paths in 603.52 seconds
# Starting search: ActionPathFinder (iteration=3103, hf=0.99, queue=588, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 330738 paths in 609.19 seconds
# Starting search: ActionPathFinder (iteration=3125, hf=0.9, queue=579, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 333651 paths in 614.2 seconds
# Starting search: ActionPathFinder (iteration=3140, hf=0.91, queue=592, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 336973 paths in 619.75 seconds
# Starting search: ActionPathFinder (iteration=3158, hf=0.92, queue=591, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 338826 paths in 625.01 seconds
# Starting search: ActionPathFinder (iteration=3185, hf=0.93, queue=591, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 340848 paths in 630.41 seconds
# Starting search: ActionPathFinder (iteration=3207, hf=0.94, queue=589, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 343596 paths in 635.54 seconds
# Starting search: ActionPathFinder (iteration=3235, hf=0.95, queue=576, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 346401 paths in 640.78 seconds
# Starting search: ActionPathFinder (iteration=3259, hf=0.96, queue=565, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 350325 paths in 646.76 seconds
# Starting search: ActionPathFinder (iteration=3284, hf=0.97, queue=547, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 355055 paths in 652.8 seconds
# Starting search: ActionPathFinder (iteration=3315, hf=0.98, queue=531, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 359169 paths in 658.27 seconds
# Starting search: ActionPathFinder (iteration=3330, hf=0.99, queue=525, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 362765 paths in 663.7 seconds
# Starting search: ActionPathFinder (iteration=3353, hf=0.9, queue=507, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 366020 paths in 669.57 seconds
# Starting search: ActionPathFinder (iteration=3370, hf=0.91, queue=521, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 369371 paths in 675.2 seconds
# Starting search: ActionPathFinder (iteration=3383, hf=0.92, queue=525, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 371730 paths in 680.66 seconds
# Starting search: ActionPathFinder (iteration=3400, hf=0.93, queue=540, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 374120 paths in 686.18 seconds
# Starting search: ActionPathFinder (iteration=3425, hf=0.94, queue=526, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 376216 paths in 691.32 seconds
# Starting search: ActionPathFinder (iteration=3448, hf=0.95, queue=521, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 378976 paths in 696.56 seconds
# Starting search: ActionPathFinder (iteration=3473, hf=0.96, queue=506, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 382279 paths in 701.9 seconds
# Starting search: ActionPathFinder (iteration=3493, hf=0.97, queue=504, seen=810, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 385914 paths in 707.67 seconds
# Starting search: ActionPathFinder (iteration=3523, hf=0.98, queue=488, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 388711 paths in 712.78 seconds
# Starting search: ActionPathFinder (iteration=3557, hf=0.99, queue=465, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 392136 paths in 718.23 seconds
# Starting search: ActionPathFinder (iteration=3572, hf=0.9, queue=466, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 396026 paths in 723.79 seconds
# Starting search: ActionPathFinder (iteration=3589, hf=0.91, queue=465, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 399833 paths in 728.87 seconds
# Starting search: ActionPathFinder (iteration=3605, hf=0.92, queue=466, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 403694 paths in 734.57 seconds
# Starting search: ActionPathFinder (iteration=3625, hf=0.93, queue=461, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 408109 paths in 739.81 seconds
# Starting search: ActionPathFinder (iteration=3645, hf=0.94, queue=464, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 410838 paths in 744.87 seconds
# Starting search: ActionPathFinder (iteration=3665, hf=0.95, queue=465, seen=811, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 414313 paths in 749.92 seconds
# Starting search: ActionPathFinder (iteration=3690, hf=0.96, queue=470, seen=812, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 427855 paths in 755.29 seconds
# Starting search: ActionPathFinder (iteration=3725, hf=0.97, queue=496, seen=818, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 446247 paths in 760.94 seconds
# Starting search: ActionPathFinder (iteration=3760, hf=0.98, queue=480, seen=821, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 457156 paths in 766.89 seconds
# Starting search: ActionPathFinder (iteration=3780, hf=0.99, queue=463, seen=821, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 465679 paths in 772.45 seconds
# Starting search: ActionPathFinder (iteration=3797, hf=0.9, queue=454, seen=828, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 470430 paths in 778.02 seconds
# Starting search: ActionPathFinder (iteration=3824, hf=0.91, queue=501, seen=836, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 486165 paths in 783.37 seconds
# Starting search: ActionPathFinder (iteration=3866, hf=0.92, queue=487, seen=836, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 503016 paths in 788.82 seconds
# Starting search: ActionPathFinder (iteration=3893, hf=0.93, queue=469, seen=839, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 510184 paths in 794.35 seconds
# Starting search: ActionPathFinder (iteration=3914, hf=0.94, queue=454, seen=842, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 519994 paths in 799.47 seconds
# Starting search: ActionPathFinder (iteration=3948, hf=0.95, queue=429, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 529197 paths in 805.25 seconds
# Starting search: ActionPathFinder (iteration=3968, hf=0.96, queue=410, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 542140 paths in 810.45 seconds
# Starting search: ActionPathFinder (iteration=3999, hf=0.97, queue=426, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 545401 paths in 815.53 seconds
# Starting search: ActionPathFinder (iteration=4018, hf=0.98, queue=443, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 549323 paths in 821.31 seconds
# Starting search: ActionPathFinder (iteration=4045, hf=0.99, queue=456, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 552672 paths in 827.16 seconds
# Starting search: ActionPathFinder (iteration=4063, hf=0.9, queue=453, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 556323 paths in 832.65 seconds
# Starting search: ActionPathFinder (iteration=4080, hf=0.91, queue=470, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Skipped 559308 paths in 837.97 seconds
# Starting search: ActionPathFinder (iteration=4100, hf=0.92, queue=523, seen=844, last=ActionPath(g=1063, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1053, h=-0.5, hVelocity=SprintRight) in 839.48 seconds after 4111 iterations and 560157 skipped paths
# Starting search: ActionPathFinder (iteration=4111, hf=0.93, queue=559, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 562402 paths in 844.5 seconds
# Starting search: ActionPathFinder (iteration=4151, hf=0.94, queue=535, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 564966 paths in 850.05 seconds
# Starting search: ActionPathFinder (iteration=4174, hf=0.95, queue=536, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 568516 paths in 855.93 seconds
# Starting search: ActionPathFinder (iteration=4201, hf=0.96, queue=530, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 571228 paths in 861.4 seconds
# Starting search: ActionPathFinder (iteration=4221, hf=0.97, queue=521, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 573932 paths in 866.54 seconds
# Starting search: ActionPathFinder (iteration=4240, hf=0.98, queue=538, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 577054 paths in 872.06 seconds
# Starting search: ActionPathFinder (iteration=4253, hf=0.99, queue=535, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 579642 paths in 877.72 seconds
# Starting search: ActionPathFinder (iteration=4269, hf=0.9, queue=528, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 582059 paths in 883.45 seconds
# Starting search: ActionPathFinder (iteration=4300, hf=0.91, queue=537, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 584436 paths in 889.28 seconds
# Starting search: ActionPathFinder (iteration=4326, hf=0.92, queue=525, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 587959 paths in 895.23 seconds
# Starting search: ActionPathFinder (iteration=4366, hf=0.93, queue=497, seen=844, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 591049 paths in 900.49 seconds
# Starting search: ActionPathFinder (iteration=4382, hf=0.94, queue=522, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 594555 paths in 906.29 seconds
# Starting search: ActionPathFinder (iteration=4398, hf=0.95, queue=520, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 597064 paths in 911.38 seconds
# Starting search: ActionPathFinder (iteration=4417, hf=0.96, queue=522, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 599005 paths in 917.05 seconds
# Starting search: ActionPathFinder (iteration=4435, hf=0.97, queue=531, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 600891 paths in 922.38 seconds
# Starting search: ActionPathFinder (iteration=4464, hf=0.98, queue=515, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 604257 paths in 927.97 seconds
# Starting search: ActionPathFinder (iteration=4479, hf=0.99, queue=509, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 608417 paths in 933.16 seconds
# Starting search: ActionPathFinder (iteration=4515, hf=0.9, queue=493, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 611173 paths in 938.47 seconds
# Starting search: ActionPathFinder (iteration=4539, hf=0.91, queue=477, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 615055 paths in 944.18 seconds
# Starting search: ActionPathFinder (iteration=4561, hf=0.92, queue=476, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 617639 paths in 949.25 seconds
# Starting search: ActionPathFinder (iteration=4579, hf=0.93, queue=470, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 621922 paths in 955.09 seconds
# Starting search: ActionPathFinder (iteration=4594, hf=0.94, queue=464, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 626052 paths in 960.55 seconds
# Starting search: ActionPathFinder (iteration=4620, hf=0.95, queue=445, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 629913 paths in 965.68 seconds
# Starting search: ActionPathFinder (iteration=4640, hf=0.96, queue=442, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 633444 paths in 970.97 seconds
# Starting search: ActionPathFinder (iteration=4659, hf=0.97, queue=443, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 636947 paths in 976.03 seconds
# Starting search: ActionPathFinder (iteration=4681, hf=0.98, queue=441, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 641369 paths in 981.33 seconds
# Starting search: ActionPathFinder (iteration=4714, hf=0.99, queue=431, seen=845, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 658702 paths in 986.84 seconds
# Starting search: ActionPathFinder (iteration=4743, hf=0.9, queue=425, seen=846, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 670256 paths in 992.08 seconds
# Starting search: ActionPathFinder (iteration=4763, hf=0.91, queue=423, seen=846, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 678457 paths in 997.13 seconds
# Starting search: ActionPathFinder (iteration=4784, hf=0.92, queue=429, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 687384 paths in 1002.61 seconds
# Starting search: ActionPathFinder (iteration=4816, hf=0.93, queue=442, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 694068 paths in 1007.78 seconds
# Starting search: ActionPathFinder (iteration=4837, hf=0.94, queue=467, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 697460 paths in 1013.28 seconds
# Starting search: ActionPathFinder (iteration=4859, hf=0.95, queue=469, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 701637 paths in 1019.1 seconds
# Starting search: ActionPathFinder (iteration=4878, hf=0.96, queue=480, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 704779 paths in 1024.26 seconds
# Starting search: ActionPathFinder (iteration=4896, hf=0.97, queue=498, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 707724 paths in 1029.46 seconds
# Starting search: ActionPathFinder (iteration=4914, hf=0.98, queue=492, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 710991 paths in 1035.25 seconds
# Starting search: ActionPathFinder (iteration=4931, hf=0.99, queue=508, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 713127 paths in 1040.61 seconds
# Starting search: ActionPathFinder (iteration=4948, hf=0.9, queue=502, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 715547 paths in 1045.97 seconds
# Starting search: ActionPathFinder (iteration=4974, hf=0.91, queue=501, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 717348 paths in 1050.98 seconds
# Starting search: ActionPathFinder (iteration=4996, hf=0.92, queue=497, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 720438 paths in 1056.18 seconds
# Starting search: ActionPathFinder (iteration=5015, hf=0.93, queue=492, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 723523 paths in 1061.29 seconds
# Starting search: ActionPathFinder (iteration=5044, hf=0.94, queue=474, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 726757 paths in 1066.78 seconds
# Starting search: ActionPathFinder (iteration=5061, hf=0.95, queue=471, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 730686 paths in 1072.98 seconds
# Starting search: ActionPathFinder (iteration=5080, hf=0.96, queue=469, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 735259 paths in 1078.5 seconds
# Starting search: ActionPathFinder (iteration=5098, hf=0.97, queue=462, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 738525 paths in 1083.61 seconds
# Starting search: ActionPathFinder (iteration=5122, hf=0.98, queue=457, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 749414 paths in 1088.64 seconds
# Starting search: ActionPathFinder (iteration=5148, hf=0.99, queue=448, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 760555 paths in 1093.91 seconds
# Starting search: ActionPathFinder (iteration=5168, hf=0.9, queue=442, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 772137 paths in 1098.96 seconds
# Starting search: ActionPathFinder (iteration=5189, hf=0.91, queue=452, seen=848, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 798959 paths in 1104.04 seconds
# Starting search: ActionPathFinder (iteration=5224, hf=0.92, queue=427, seen=851, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 823035 paths in 1109.42 seconds
# Starting search: ActionPathFinder (iteration=5256, hf=0.93, queue=399, seen=854, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 834963 paths in 1114.72 seconds
# Starting search: ActionPathFinder (iteration=5293, hf=0.94, queue=388, seen=867, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 850156 paths in 1120.03 seconds
# Starting search: ActionPathFinder (iteration=5331, hf=0.95, queue=363, seen=878, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 859786 paths in 1125.07 seconds
# Starting search: ActionPathFinder (iteration=5370, hf=0.96, queue=395, seen=892, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 864607 paths in 1130.08 seconds
# Starting search: ActionPathFinder (iteration=5410, hf=0.97, queue=366, seen=895, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 866354 paths in 1135.35 seconds
# Starting search: ActionPathFinder (iteration=5469, hf=0.98, queue=368, seen=926, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 870886 paths in 1140.48 seconds
# Starting search: ActionPathFinder (iteration=5520, hf=0.99, queue=331, seen=932, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 874768 paths in 1146.36 seconds
# Starting search: ActionPathFinder (iteration=5551, hf=0.9, queue=321, seen=935, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 878800 paths in 1152.17 seconds
# Starting search: ActionPathFinder (iteration=5582, hf=0.91, queue=336, seen=946, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 883353 paths in 1157.37 seconds
# Starting search: ActionPathFinder (iteration=5604, hf=0.92, queue=367, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 889200 paths in 1162.57 seconds
# Starting search: ActionPathFinder (iteration=5634, hf=0.93, queue=374, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 897441 paths in 1168.11 seconds
# Starting search: ActionPathFinder (iteration=5657, hf=0.94, queue=403, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 899738 paths in 1173.53 seconds
# Starting search: ActionPathFinder (iteration=5672, hf=0.95, queue=405, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 902942 paths in 1178.78 seconds
# Starting search: ActionPathFinder (iteration=5695, hf=0.96, queue=414, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 906021 paths in 1184.16 seconds
# Starting search: ActionPathFinder (iteration=5710, hf=0.97, queue=413, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 909088 paths in 1189.32 seconds
# Starting search: ActionPathFinder (iteration=5737, hf=0.98, queue=403, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 912683 paths in 1194.46 seconds
# Starting search: ActionPathFinder (iteration=5757, hf=0.99, queue=409, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 916117 paths in 1200.01 seconds
# Starting search: ActionPathFinder (iteration=5782, hf=0.9, queue=407, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 919192 paths in 1205.38 seconds
# Starting search: ActionPathFinder (iteration=5799, hf=0.91, queue=401, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 922997 paths in 1210.72 seconds
# Starting search: ActionPathFinder (iteration=5817, hf=0.92, queue=402, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 927440 paths in 1216.15 seconds
# Starting search: ActionPathFinder (iteration=5836, hf=0.93, queue=401, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 930803 paths in 1221.21 seconds
# Starting search: ActionPathFinder (iteration=5858, hf=0.94, queue=401, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 934515 paths in 1226.47 seconds
# Starting search: ActionPathFinder (iteration=5884, hf=0.95, queue=397, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 947938 paths in 1231.69 seconds
# Starting search: ActionPathFinder (iteration=5916, hf=0.96, queue=384, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 959604 paths in 1236.93 seconds
# Starting search: ActionPathFinder (iteration=5935, hf=0.97, queue=372, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 973682 paths in 1242.11 seconds
# Starting search: ActionPathFinder (iteration=5960, hf=0.98, queue=363, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 988806 paths in 1247.41 seconds
# Starting search: ActionPathFinder (iteration=5981, hf=0.99, queue=359, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 1003795 paths in 1252.66 seconds
# Starting search: ActionPathFinder (iteration=6011, hf=0.9, queue=342, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 1010134 paths in 1258.05 seconds
# Starting search: ActionPathFinder (iteration=6032, hf=0.91, queue=382, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 1017700 paths in 1263.07 seconds
# Starting search: ActionPathFinder (iteration=6058, hf=0.92, queue=383, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 1021911 paths in 1268.77 seconds
# Starting search: ActionPathFinder (iteration=6082, hf=0.93, queue=403, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Skipped 1025498 paths in 1273.81 seconds
# Starting search: ActionPathFinder (iteration=6101, hf=0.94, queue=421, seen=947, last=ActionPath(g=1053, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=1044, h=-0.5, hVelocity=SprintRight) in 1278.34 seconds after 6123 iterations and 1028004 skipped paths
# Starting search: ActionPathFinder (iteration=6123, hf=0.95, queue=478, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1029985 paths in 1283.49 seconds
# Starting search: ActionPathFinder (iteration=6168, hf=0.96, queue=456, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1032751 paths in 1289.13 seconds
# Starting search: ActionPathFinder (iteration=6189, hf=0.97, queue=465, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1035784 paths in 1294.94 seconds
# Starting search: ActionPathFinder (iteration=6208, hf=0.98, queue=468, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1038799 paths in 1300.24 seconds
# Starting search: ActionPathFinder (iteration=6224, hf=0.99, queue=467, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1041396 paths in 1305.57 seconds
# Starting search: ActionPathFinder (iteration=6244, hf=0.9, queue=458, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1045050 paths in 1311.32 seconds
# Starting search: ActionPathFinder (iteration=6262, hf=0.91, queue=470, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1047544 paths in 1316.8 seconds
# Starting search: ActionPathFinder (iteration=6288, hf=0.92, queue=470, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1049091 paths in 1322.17 seconds
# Starting search: ActionPathFinder (iteration=6306, hf=0.93, queue=471, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1052397 paths in 1328.06 seconds
# Starting search: ActionPathFinder (iteration=6329, hf=0.94, queue=465, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1055119 paths in 1333.47 seconds
# Starting search: ActionPathFinder (iteration=6357, hf=0.95, queue=446, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1059298 paths in 1339.09 seconds
# Starting search: ActionPathFinder (iteration=6381, hf=0.96, queue=434, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1063840 paths in 1344.75 seconds
# Starting search: ActionPathFinder (iteration=6401, hf=0.97, queue=423, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1067496 paths in 1349.85 seconds
# Starting search: ActionPathFinder (iteration=6421, hf=0.98, queue=412, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1070552 paths in 1355.27 seconds
# Starting search: ActionPathFinder (iteration=6437, hf=0.99, queue=432, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1073239 paths in 1360.62 seconds
# Starting search: ActionPathFinder (iteration=6451, hf=0.9, queue=429, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1075613 paths in 1365.81 seconds
# Starting search: ActionPathFinder (iteration=6469, hf=0.91, queue=435, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1078105 paths in 1371.79 seconds
# Starting search: ActionPathFinder (iteration=6495, hf=0.92, queue=431, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1081053 paths in 1377.45 seconds
# Starting search: ActionPathFinder (iteration=6513, hf=0.93, queue=430, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1084031 paths in 1383.06 seconds
# Starting search: ActionPathFinder (iteration=6542, hf=0.94, queue=412, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1087186 paths in 1388.55 seconds
# Starting search: ActionPathFinder (iteration=6566, hf=0.95, queue=401, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1091049 paths in 1394.07 seconds
# Starting search: ActionPathFinder (iteration=6586, hf=0.96, queue=398, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# Skipped 1094628 paths in 1399.53 seconds
# Starting search: ActionPathFinder (iteration=6606, hf=0.97, queue=400, seen=947, last=ActionPath(g=1044, h=-0.5, hVelocity=SprintRight))
# ...
# Skipped 5256145 paths in 5870.08 seconds
# Starting search: ActionPathFinder (iteration=26643, hf=0.99, queue=450, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5260248 paths in 5875.43 seconds
# Starting search: ActionPathFinder (iteration=26669, hf=0.9, queue=434, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5263436 paths in 5880.52 seconds
# Starting search: ActionPathFinder (iteration=26688, hf=0.91, queue=429, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5267298 paths in 5885.86 seconds
# Starting search: ActionPathFinder (iteration=26709, hf=0.92, queue=427, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5271794 paths in 5891.27 seconds
# Starting search: ActionPathFinder (iteration=26731, hf=0.93, queue=425, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5276567 paths in 5896.79 seconds
# Starting search: ActionPathFinder (iteration=26756, hf=0.94, queue=414, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5280053 paths in 5902.11 seconds
# Starting search: ActionPathFinder (iteration=26777, hf=0.95, queue=410, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5285575 paths in 5907.14 seconds
# Starting search: ActionPathFinder (iteration=26809, hf=0.96, queue=403, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5303154 paths in 5912.19 seconds
# Starting search: ActionPathFinder (iteration=26834, hf=0.97, queue=394, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5312869 paths in 5917.31 seconds
# Starting search: ActionPathFinder (iteration=26855, hf=0.98, queue=388, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5325111 paths in 5922.72 seconds
# Starting search: ActionPathFinder (iteration=26872, hf=0.99, queue=384, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5338905 paths in 5927.82 seconds
# Starting search: ActionPathFinder (iteration=26904, hf=0.9, queue=380, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5343297 paths in 5933.19 seconds
# Starting search: ActionPathFinder (iteration=26925, hf=0.91, queue=378, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5350219 paths in 5938.36 seconds
# Starting search: ActionPathFinder (iteration=26970, hf=0.92, queue=386, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5353178 paths in 5943.84 seconds
# Starting search: ActionPathFinder (iteration=27022, hf=0.93, queue=357, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5356435 paths in 5949.58 seconds
# Starting search: ActionPathFinder (iteration=27052, hf=0.94, queue=369, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5361950 paths in 5955.21 seconds
# Starting search: ActionPathFinder (iteration=27072, hf=0.95, queue=399, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5368191 paths in 5960.44 seconds
# Starting search: ActionPathFinder (iteration=27101, hf=0.96, queue=387, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5373324 paths in 5965.98 seconds
# Starting search: ActionPathFinder (iteration=27123, hf=0.97, queue=419, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5377402 paths in 5971.74 seconds
# Starting search: ActionPathFinder (iteration=27149, hf=0.98, queue=425, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Skipped 5380683 paths in 5976.8 seconds
# Starting search: ActionPathFinder (iteration=27170, hf=0.99, queue=432, seen=1254, last=ActionPath(g=995, h=-0.5, hVelocity=SprintRight))
# Found path ActionPath(g=994, h=-0.5, hVelocity=SprintRight) in 5981.69 seconds after 27192 iterations and 5383724 skipped paths
# Starting search: ActionPathFinder (iteration=27192, hf=0.9, queue=459, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5386214 paths in 5986.71 seconds
# Starting search: ActionPathFinder (iteration=27221, hf=0.91, queue=451, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5389706 paths in 5991.94 seconds
# Starting search: ActionPathFinder (iteration=27236, hf=0.92, queue=454, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5392353 paths in 5997.15 seconds
# Starting search: ActionPathFinder (iteration=27257, hf=0.93, queue=458, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5394710 paths in 6002.67 seconds
# Starting search: ActionPathFinder (iteration=27283, hf=0.94, queue=457, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5397250 paths in 6007.81 seconds
# Starting search: ActionPathFinder (iteration=27308, hf=0.95, queue=447, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5400240 paths in 6013.26 seconds
# Starting search: ActionPathFinder (iteration=27333, hf=0.96, queue=439, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5404114 paths in 6018.44 seconds
# Starting search: ActionPathFinder (iteration=27356, hf=0.97, queue=429, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5407819 paths in 6023.49 seconds
# Starting search: ActionPathFinder (iteration=27370, hf=0.98, queue=428, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5411784 paths in 6029.25 seconds
# Starting search: ActionPathFinder (iteration=27396, hf=0.99, queue=419, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5416348 paths in 6034.71 seconds
# Starting search: ActionPathFinder (iteration=27415, hf=0.9, queue=417, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5420788 paths in 6039.9 seconds
# Starting search: ActionPathFinder (iteration=27435, hf=0.91, queue=411, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5425276 paths in 6045.04 seconds
# Starting search: ActionPathFinder (iteration=27458, hf=0.92, queue=408, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5435516 paths in 6050.44 seconds
# Starting search: ActionPathFinder (iteration=27491, hf=0.93, queue=402, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5447822 paths in 6055.93 seconds
# Starting search: ActionPathFinder (iteration=27513, hf=0.94, queue=391, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5464680 paths in 6061.09 seconds
# Starting search: ActionPathFinder (iteration=27536, hf=0.95, queue=382, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5476231 paths in 6066.3 seconds
# Starting search: ActionPathFinder (iteration=27563, hf=0.96, queue=373, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5479495 paths in 6072.01 seconds
# Starting search: ActionPathFinder (iteration=27604, hf=0.97, queue=374, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5484074 paths in 6077.06 seconds
# Starting search: ActionPathFinder (iteration=27631, hf=0.98, queue=364, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5489358 paths in 6082.18 seconds
# Starting search: ActionPathFinder (iteration=27673, hf=0.99, queue=354, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5493588 paths in 6087.31 seconds
# Starting search: ActionPathFinder (iteration=27702, hf=0.9, queue=347, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5496654 paths in 6093.07 seconds
# Starting search: ActionPathFinder (iteration=27721, hf=0.91, queue=344, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5499068 paths in 6098.74 seconds
# Starting search: ActionPathFinder (iteration=27738, hf=0.92, queue=336, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5501621 paths in 6104.3 seconds
# Starting search: ActionPathFinder (iteration=27757, hf=0.93, queue=327, seen=1254, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5505073 paths in 6109.52 seconds
# Starting search: ActionPathFinder (iteration=27774, hf=0.94, queue=317, seen=1255, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5508716 paths in 6114.86 seconds
# Starting search: ActionPathFinder (iteration=27790, hf=0.95, queue=331, seen=1256, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5512120 paths in 6119.94 seconds
# Starting search: ActionPathFinder (iteration=27807, hf=0.96, queue=356, seen=1256, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5517433 paths in 6125.76 seconds
# Starting search: ActionPathFinder (iteration=27830, hf=0.97, queue=342, seen=1256, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5520892 paths in 6131.55 seconds
# Starting search: ActionPathFinder (iteration=27848, hf=0.98, queue=337, seen=1258, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5525450 paths in 6136.65 seconds
# Starting search: ActionPathFinder (iteration=27871, hf=0.99, queue=318, seen=1258, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5529988 paths in 6142.3 seconds
# Starting search: ActionPathFinder (iteration=27887, hf=0.9, queue=303, seen=1258, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5538819 paths in 6147.79 seconds
# Starting search: ActionPathFinder (iteration=27916, hf=0.91, queue=374, seen=1263, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5542099 paths in 6153.01 seconds
# Starting search: ActionPathFinder (iteration=27944, hf=0.92, queue=359, seen=1266, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5550838 paths in 6158.03 seconds
# Starting search: ActionPathFinder (iteration=27977, hf=0.93, queue=334, seen=1270, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5561867 paths in 6163.6 seconds
# Starting search: ActionPathFinder (iteration=28019, hf=0.94, queue=296, seen=1272, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5566947 paths in 6168.67 seconds
# Starting search: ActionPathFinder (iteration=28044, hf=0.95, queue=272, seen=1272, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5570609 paths in 6174.26 seconds
# Starting search: ActionPathFinder (iteration=28061, hf=0.96, queue=282, seen=1294, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5574344 paths in 6179.91 seconds
# Starting search: ActionPathFinder (iteration=28079, hf=0.97, queue=297, seen=1300, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5577634 paths in 6185.61 seconds
# Starting search: ActionPathFinder (iteration=28098, hf=0.98, queue=287, seen=1304, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5580952 paths in 6190.87 seconds
# Starting search: ActionPathFinder (iteration=28113, hf=0.99, queue=302, seen=1307, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5584300 paths in 6196.51 seconds
# Starting search: ActionPathFinder (iteration=28129, hf=0.9, queue=291, seen=1311, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5589227 paths in 6201.81 seconds
# Starting search: ActionPathFinder (iteration=28152, hf=0.91, queue=300, seen=1325, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5598376 paths in 6207.22 seconds
# Starting search: ActionPathFinder (iteration=28176, hf=0.92, queue=284, seen=1329, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5609556 paths in 6212.23 seconds
# Starting search: ActionPathFinder (iteration=28212, hf=0.93, queue=263, seen=1334, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5624411 paths in 6217.89 seconds
# Starting search: ActionPathFinder (iteration=28257, hf=0.94, queue=227, seen=1338, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5637315 paths in 6223.58 seconds
# Starting search: ActionPathFinder (iteration=28297, hf=0.95, queue=188, seen=1338, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5640565 paths in 6228.82 seconds
# Starting search: ActionPathFinder (iteration=28313, hf=0.96, queue=189, seen=1339, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5643027 paths in 6234.39 seconds
# Starting search: ActionPathFinder (iteration=28323, hf=0.97, queue=187, seen=1342, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5646322 paths in 6239.92 seconds
# Starting search: ActionPathFinder (iteration=28339, hf=0.98, queue=178, seen=1346, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5648951 paths in 6245.45 seconds
# Starting search: ActionPathFinder (iteration=28358, hf=0.99, queue=166, seen=1349, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5651946 paths in 6250.69 seconds
# Starting search: ActionPathFinder (iteration=28372, hf=0.9, queue=161, seen=1355, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5656438 paths in 6255.89 seconds
# Starting search: ActionPathFinder (iteration=28398, hf=0.91, queue=147, seen=1360, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5662098 paths in 6261.23 seconds
# Starting search: ActionPathFinder (iteration=28422, hf=0.92, queue=126, seen=1361, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5676038 paths in 6266.97 seconds
# Starting search: ActionPathFinder (iteration=28494, hf=0.93, queue=57, seen=1362, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5678869 paths in 6272.67 seconds
# Starting search: ActionPathFinder (iteration=28506, hf=0.94, queue=48, seen=1362, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5681692 paths in 6278.04 seconds
# Starting search: ActionPathFinder (iteration=28524, hf=0.95, queue=58, seen=1382, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5684729 paths in 6283.75 seconds
# Starting search: ActionPathFinder (iteration=28545, hf=0.96, queue=42, seen=1386, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5687691 paths in 6289.4 seconds
# Starting search: ActionPathFinder (iteration=28561, hf=0.97, queue=44, seen=1395, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5690215 paths in 6295.19 seconds
# Starting search: ActionPathFinder (iteration=28580, hf=0.98, queue=30, seen=1399, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5693496 paths in 6301.27 seconds
# Starting search: ActionPathFinder (iteration=28602, hf=0.99, queue=23, seen=1407, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Skipped 5696611 paths in 6306.88 seconds
# Starting search: ActionPathFinder (iteration=28628, hf=0.9, queue=8, seen=1415, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.91, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.92, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.93, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.94, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.95, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.96, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.97, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.98, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=28639, hf=0.99, queue=0, seen=1418, last=ActionPath(g=994, h=-0.5, hVelocity=SprintRight))
# PlotTensor: 0 179

# %%
pathFinder.plotAnimation(fps=30, skipFrames=50)
break
# Out:
# 575
# PlotTensor: 0 179
#   Cell In[10], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 179

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
