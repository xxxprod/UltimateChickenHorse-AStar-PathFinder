# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'DeadEndTest2'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 72
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(-13.5, -7.5), (-13.5, -7.5)], Goal Distance: 18.5
# PlotTensor: 0 35

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 7677 paths in 5.43 seconds
# Starting search: ActionPathFinder (iteration=41, hf=0.91, queue=54, seen=53, last=None)
# Skipped 14934 paths in 10.5 seconds
# Starting search: ActionPathFinder (iteration=88, hf=0.92, queue=22, seen=62, last=None)
# Skipped 20703 paths in 15.71 seconds
# Starting search: ActionPathFinder (iteration=137, hf=0.93, queue=34, seen=105, last=None)
# Found path ActionPath(g=208, h=1.0, hVelocity=IdleRight) in 19.46 seconds after 183 iterations and 27018 skipped paths
# Starting search: ActionPathFinder (iteration=183, hf=0.94, queue=64, seen=162, last=ActionPath(g=208, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=205, h=1.0, hVelocity=IdleRight) in 23.49 seconds after 196 iterations and 30424 skipped paths
# Starting search: ActionPathFinder (iteration=196, hf=0.95, queue=81, seen=212, last=ActionPath(g=205, h=1.0, hVelocity=IdleRight))
# Skipped 36346 paths in 28.82 seconds
# Starting search: ActionPathFinder (iteration=222, hf=0.96, queue=107, seen=230, last=ActionPath(g=205, h=1.0, hVelocity=IdleRight))
# Found path ActionPath(g=198, h=0.5, hVelocity=IdleRight) in 33.54 seconds after 257 iterations and 43372 skipped paths
# Starting search: ActionPathFinder (iteration=257, hf=0.97, queue=100, seen=233, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 49487 paths in 39.19 seconds
# Starting search: ActionPathFinder (iteration=279, hf=0.98, queue=90, seen=233, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 63644 paths in 44.26 seconds
# Starting search: ActionPathFinder (iteration=328, hf=0.99, queue=75, seen=235, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 72961 paths in 49.3 seconds
# Starting search: ActionPathFinder (iteration=351, hf=0.9, queue=78, seen=238, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 83710 paths in 54.8 seconds
# Starting search: ActionPathFinder (iteration=391, hf=0.91, queue=92, seen=241, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 106271 paths in 59.86 seconds
# Starting search: ActionPathFinder (iteration=424, hf=0.92, queue=87, seen=243, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 123937 paths in 65.34 seconds
# Starting search: ActionPathFinder (iteration=457, hf=0.93, queue=67, seen=244, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Skipped 138400 paths in 70.47 seconds
# Starting search: ActionPathFinder (iteration=504, hf=0.94, queue=28, seen=247, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=535, hf=0.95, queue=0, seen=250, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=535, hf=0.96, queue=0, seen=250, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=535, hf=0.97, queue=0, seen=250, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=535, hf=0.98, queue=0, seen=250, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# Starting search: ActionPathFinder (iteration=535, hf=0.99, queue=0, seen=250, last=ActionPath(g=198, h=0.5, hVelocity=IdleRight))
# PlotTensor: 0 35

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
