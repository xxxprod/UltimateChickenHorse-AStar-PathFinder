# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'NarrowSpikePathTest'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(3, 3), 
    costWeights=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False,
    heuristic=ActionPathHeuristics.GoalDistanceFlood,
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 145
# GoalDistanceFlood: Start Position: (-17.6299989, -9.48), Goal Positions: [(15.5, -7.5), (15.5, -7.5)], Goal Distance: 39.5
# PlotTensor: 0 72

# %%
for path in pathFinder.findPaths():
    break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.5, queue=1, seen=0, last=None)
# Skipped 6863 paths in 5.15 seconds
# Starting search: ActionPathFinder (iteration=17, hf=0.6, queue=145, seen=114, last=None)
# Skipped 15061 paths in 10.34 seconds
# Starting search: ActionPathFinder (iteration=59, hf=0.7, queue=143, seen=123, last=None)
# Skipped 34006 paths in 15.44 seconds
# Starting search: ActionPathFinder (iteration=93, hf=0.8, queue=199, seen=212, last=None)
# Found path ActionPath(g=163, h=2.0, hVelocity=SprintRight) in 18.43 seconds after 143 iterations and 34018 skipped paths
# PlotTensor: 0 72

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Waiting for response...
# Waiting for response...

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
