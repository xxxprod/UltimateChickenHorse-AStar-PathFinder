# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'TestLevel_FlatGrounds'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    quantizationFactor=(2, 2), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 172
# GoalDistanceFlood: Start Position: (-33.6299969, -16.48), Goal Positions: [(33.5, -14.5), (33.5, -14.5)], Goal Distance: 68.0
# PlotTensor: 0 85

# %%
for path in pathFinder.findPaths():
    break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Found path ActionPath(g=319, h=2.0, hVelocity=SprintRight) in 0.0 seconds after 1 iterations and 100397 skipped paths
# PlotTensor: 0 85

# %%
pathFinder.plotAnimation(fps=1)
break
# Out:
# 3
# PlotTensor: 0 85
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
