# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'JumpParcour4'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)

pathFinder.plotPaths()
# Out:
# Device used: cuda
# Flood fill steps: 172
# GoalDistanceFlood: Start Position: (-33.6299969, -24.48), Goal Positions: [(31.5, -7.5)], Goal Distance: 81.0
# PlotTensor: 0 85

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=999999)
# Found path ActionPath(state=Undefined, g=336, h=2.0) in 1.47 seconds after 11 iterations and 6937 skipped paths
# Starting search: ActionPathFinder (iteration=11, hf=0.91, queue=187, seen=184, last=336)
# Skipped 22120 paths in 6.79 seconds
# Starting search: ActionPathFinder (iteration=44, hf=0.92, queue=170, seen=206, last=336)
# Skipped 38990 paths in 12.13 seconds
# Starting search: ActionPathFinder (iteration=84, hf=0.93, queue=227, seen=222, last=336)
# Skipped 78938 paths in 17.29 seconds
# Starting search: ActionPathFinder (iteration=149, hf=0.94, queue=202, seen=223, last=336)
# Skipped 118608 paths in 22.45 seconds
# Starting search: ActionPathFinder (iteration=215, hf=0.95, queue=160, seen=230, last=336)
# Skipped 135398 paths in 27.74 seconds
# Starting search: ActionPathFinder (iteration=258, hf=0.96, queue=172, seen=238, last=336)
# Skipped 174121 paths in 32.87 seconds
# Starting search: ActionPathFinder (iteration=329, hf=0.97, queue=162, seen=246, last=336)
# Skipped 217690 paths in 38.01 seconds
# Starting search: ActionPathFinder (iteration=403, hf=0.98, queue=130, seen=247, last=336)
# Skipped 244842 paths in 43.28 seconds
# Starting search: ActionPathFinder (iteration=464, hf=0.99, queue=101, seen=256, last=336)
# Skipped 276283 paths in 48.35 seconds
# Starting search: ActionPathFinder (iteration=530, hf=0.9, queue=97, seen=262, last=336)
# Skipped 307272 paths in 53.38 seconds
# Starting search: ActionPathFinder (iteration=571, hf=0.91, queue=119, seen=263, last=336)
# Skipped 331736 paths in 58.4 seconds
# Starting search: ActionPathFinder (iteration=618, hf=0.92, queue=74, seen=264, last=336)
# Skipped 351012 paths in 63.58 seconds
# Starting search: ActionPathFinder (iteration=673, hf=0.93, queue=31, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.94, queue=0, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.95, queue=0, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.96, queue=0, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.97, queue=0, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.98, queue=0, seen=267, last=336)
# Starting search: ActionPathFinder (iteration=711, hf=0.99, queue=0, seen=267, last=336)
# PlotTensor: 0 85

# %%
# pathFinder.plotAnimation(fps=30)
break
# Out:
#   Cell In[5], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
