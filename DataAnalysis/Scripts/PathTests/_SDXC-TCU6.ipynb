# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from services.UCHPathFinder import *

# %%
levelName = 'SDXC-TCU6'

# %%
pathFinder = UCHPathFinder(
    levelName, 
    # quantizationFactor=(3, 3), 
    # heuristicFactors=[1],
    forceLoadLevel=False, 
    forceCreateNodeMap=False
)
print(Rect(pathFinder.blockMap.rtree.bounds).size)
print(len(pathFinder.blockMap.blocks))

pathFinder.plotPaths()
# Out:
# Device used: cpu
# Flood fill steps: 214
# GoalDistanceFlood: Start Position: (-31.629996900000002, -30.48), Goal Positions: [(29.5, -20.5)], Goal Distance: 88.5
# (85.0, 52.0)
# 862
# PlotTensor: -0.5 106.5

# %%
for path in pathFinder.findPaths():
    # break
    pass

pathFinder.plotPaths()
# Out:
# Starting search: ActionPathFinder (iteration=0, hf=0.9, queue=1, seen=0, last=None)
# Skipped 2994 paths in 7.13 seconds
# Starting search: ActionPathFinder (iteration=21, hf=0.91, queue=120, seen=107, last=None)
# Skipped 6133 paths in 12.8 seconds
# Starting search: ActionPathFinder (iteration=41, hf=0.92, queue=234, seen=223, last=None)
# Skipped 10941 paths in 19.03 seconds
# Starting search: ActionPathFinder (iteration=63, hf=0.93, queue=337, seen=325, last=None)
# Skipped 14212 paths in 24.23 seconds
# Starting search: ActionPathFinder (iteration=82, hf=0.94, queue=524, seen=476, last=None)
# Found path ActionPath(g=445, h=3.0, hVelocity=WalkRight) in 26.89 seconds after 103 iterations and 15637 skipped paths
# Starting search: ActionPathFinder (iteration=103, hf=0.95, queue=578, seen=531, last=ActionPath(g=445, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=444, h=3.0, hVelocity=SprintRight) in 26.89 seconds after 110 iterations and 15679 skipped paths
# Starting search: ActionPathFinder (iteration=110, hf=0.96, queue=571, seen=532, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 19341 paths in 33.06 seconds
# Starting search: ActionPathFinder (iteration=138, hf=0.97, queue=570, seen=570, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 22936 paths in 39.17 seconds
# Starting search: ActionPathFinder (iteration=160, hf=0.98, queue=580, seen=578, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 26164 paths in 44.82 seconds
# Starting search: ActionPathFinder (iteration=196, hf=0.99, queue=553, seen=594, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 29706 paths in 50.53 seconds
# Starting search: ActionPathFinder (iteration=216, hf=0.9, queue=542, seen=603, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 32913 paths in 56.22 seconds
# Starting search: ActionPathFinder (iteration=233, hf=0.91, queue=577, seen=605, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Skipped 35899 paths in 61.31 seconds
# Starting search: ActionPathFinder (iteration=248, hf=0.92, queue=632, seen=626, last=ActionPath(g=444, h=3.0, hVelocity=SprintRight))
# Found path ActionPath(g=440, h=3.0, hVelocity=WalkRight) in 61.32 seconds after 250 iterations and 36002 skipped paths
# Starting search: ActionPathFinder (iteration=250, hf=0.93, queue=635, seen=626, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 39052 paths in 66.38 seconds
# Starting search: ActionPathFinder (iteration=269, hf=0.94, queue=622, seen=627, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 42682 paths in 72.2 seconds
# Starting search: ActionPathFinder (iteration=296, hf=0.95, queue=605, seen=640, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 46418 paths in 77.79 seconds
# Starting search: ActionPathFinder (iteration=358, hf=0.96, queue=565, seen=661, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 50473 paths in 83.68 seconds
# Starting search: ActionPathFinder (iteration=395, hf=0.97, queue=531, seen=669, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 54432 paths in 89.33 seconds
# Starting search: ActionPathFinder (iteration=426, hf=0.98, queue=522, seen=707, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 58367 paths in 95.57 seconds
# Starting search: ActionPathFinder (iteration=563, hf=0.99, queue=413, seen=727, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 60889 paths in 101.3 seconds
# Starting search: ActionPathFinder (iteration=582, hf=0.9, queue=417, seen=738, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 66679 paths in 106.51 seconds
# Starting search: ActionPathFinder (iteration=635, hf=0.91, queue=490, seen=756, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 70808 paths in 112.17 seconds
# Starting search: ActionPathFinder (iteration=660, hf=0.92, queue=562, seen=758, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 73963 paths in 117.18 seconds
# Starting search: ActionPathFinder (iteration=681, hf=0.93, queue=576, seen=758, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 77251 paths in 123.22 seconds
# Starting search: ActionPathFinder (iteration=701, hf=0.94, queue=572, seen=759, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 80306 paths in 128.23 seconds
# Starting search: ActionPathFinder (iteration=712, hf=0.95, queue=577, seen=759, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Skipped 83398 paths in 133.62 seconds
# Starting search: ActionPathFinder (iteration=720, hf=0.96, queue=581, seen=760, last=ActionPath(g=440, h=3.0, hVelocity=WalkRight))
# Found path ActionPath(g=438, h=3.0, hVelocity=SprintRight) in 136.81 seconds after 741 iterations and 85474 skipped paths
# Starting search: ActionPathFinder (iteration=741, hf=0.97, queue=579, seen=762, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 89729 paths in 142.05 seconds
# Starting search: ActionPathFinder (iteration=780, hf=0.98, queue=547, seen=789, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 91533 paths in 147.68 seconds
# Starting search: ActionPathFinder (iteration=828, hf=0.99, queue=529, seen=794, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 94813 paths in 153.31 seconds
# Starting search: ActionPathFinder (iteration=905, hf=0.9, queue=464, seen=799, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 99351 paths in 159.57 seconds
# Starting search: ActionPathFinder (iteration=941, hf=0.91, queue=486, seen=814, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 103275 paths in 164.63 seconds
# Starting search: ActionPathFinder (iteration=966, hf=0.92, queue=471, seen=820, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 107976 paths in 170.85 seconds
# Starting search: ActionPathFinder (iteration=977, hf=0.93, queue=476, seen=826, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 112647 paths in 176.5 seconds
# Starting search: ActionPathFinder (iteration=994, hf=0.94, queue=478, seen=831, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 117941 paths in 181.77 seconds
# Starting search: ActionPathFinder (iteration=1017, hf=0.95, queue=461, seen=834, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 122203 paths in 187.58 seconds
# Starting search: ActionPathFinder (iteration=1051, hf=0.96, queue=440, seen=838, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 124656 paths in 193.3 seconds
# Starting search: ActionPathFinder (iteration=1112, hf=0.97, queue=408, seen=845, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 127184 paths in 198.35 seconds
# Starting search: ActionPathFinder (iteration=1138, hf=0.98, queue=390, seen=850, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 130462 paths in 203.85 seconds
# Starting search: ActionPathFinder (iteration=1174, hf=0.99, queue=439, seen=854, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 132839 paths in 209.44 seconds
# Starting search: ActionPathFinder (iteration=1212, hf=0.9, queue=447, seen=854, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 137000 paths in 214.98 seconds
# Starting search: ActionPathFinder (iteration=1257, hf=0.91, queue=437, seen=855, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 140323 paths in 220.46 seconds
# Starting search: ActionPathFinder (iteration=1280, hf=0.92, queue=427, seen=855, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 144632 paths in 226.43 seconds
# Starting search: ActionPathFinder (iteration=1297, hf=0.93, queue=421, seen=855, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 146747 paths in 231.48 seconds
# Starting search: ActionPathFinder (iteration=1334, hf=0.94, queue=431, seen=860, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 148741 paths in 236.62 seconds
# Starting search: ActionPathFinder (iteration=1357, hf=0.95, queue=434, seen=867, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 151719 paths in 242.0 seconds
# Starting search: ActionPathFinder (iteration=1398, hf=0.96, queue=430, seen=879, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 154720 paths in 247.42 seconds
# Starting search: ActionPathFinder (iteration=1444, hf=0.97, queue=414, seen=897, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 157649 paths in 252.79 seconds
# Starting search: ActionPathFinder (iteration=1491, hf=0.98, queue=393, seen=907, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 161083 paths in 258.31 seconds
# Starting search: ActionPathFinder (iteration=1555, hf=0.99, queue=355, seen=921, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 164348 paths in 263.39 seconds
# Starting search: ActionPathFinder (iteration=1584, hf=0.9, queue=368, seen=922, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 168032 paths in 268.86 seconds
# Starting search: ActionPathFinder (iteration=1603, hf=0.91, queue=375, seen=935, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 170487 paths in 274.07 seconds
# Starting search: ActionPathFinder (iteration=1630, hf=0.92, queue=412, seen=940, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 173577 paths in 279.29 seconds
# Starting search: ActionPathFinder (iteration=1672, hf=0.93, queue=434, seen=954, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 177256 paths in 284.39 seconds
# Starting search: ActionPathFinder (iteration=1703, hf=0.94, queue=443, seen=966, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 181053 paths in 290.4 seconds
# Starting search: ActionPathFinder (iteration=1721, hf=0.95, queue=431, seen=966, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 185066 paths in 295.81 seconds
# Starting search: ActionPathFinder (iteration=1743, hf=0.96, queue=419, seen=970, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 190682 paths in 301.09 seconds
# Starting search: ActionPathFinder (iteration=1777, hf=0.97, queue=393, seen=970, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 193858 paths in 306.51 seconds
# Starting search: ActionPathFinder (iteration=1796, hf=0.98, queue=388, seen=981, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 198335 paths in 312.1 seconds
# Starting search: ActionPathFinder (iteration=1819, hf=0.99, queue=382, seen=984, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 201934 paths in 317.73 seconds
# Starting search: ActionPathFinder (iteration=1856, hf=0.9, queue=361, seen=984, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 206816 paths in 322.93 seconds
# Starting search: ActionPathFinder (iteration=1914, hf=0.91, queue=443, seen=1021, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 209423 paths in 328.38 seconds
# Starting search: ActionPathFinder (iteration=1938, hf=0.92, queue=428, seen=1023, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 213148 paths in 333.66 seconds
# Starting search: ActionPathFinder (iteration=1961, hf=0.93, queue=421, seen=1025, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 216757 paths in 338.93 seconds
# Starting search: ActionPathFinder (iteration=1980, hf=0.94, queue=409, seen=1025, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 220500 paths in 344.41 seconds
# Starting search: ActionPathFinder (iteration=2015, hf=0.95, queue=380, seen=1027, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 224882 paths in 350.12 seconds
# Starting search: ActionPathFinder (iteration=2057, hf=0.96, queue=356, seen=1037, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 229234 paths in 355.73 seconds
# Starting search: ActionPathFinder (iteration=2126, hf=0.97, queue=296, seen=1041, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 233375 paths in 361.13 seconds
# Starting search: ActionPathFinder (iteration=2187, hf=0.98, queue=243, seen=1043, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 237320 paths in 366.95 seconds
# Starting search: ActionPathFinder (iteration=2249, hf=0.99, queue=203, seen=1056, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 241117 paths in 372.22 seconds
# Starting search: ActionPathFinder (iteration=2294, hf=0.9, queue=186, seen=1057, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 245075 paths in 377.94 seconds
# Starting search: ActionPathFinder (iteration=2338, hf=0.91, queue=240, seen=1064, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 247537 paths in 383.54 seconds
# Starting search: ActionPathFinder (iteration=2357, hf=0.92, queue=235, seen=1064, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 253200 paths in 388.6 seconds
# Starting search: ActionPathFinder (iteration=2385, hf=0.93, queue=220, seen=1064, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 257183 paths in 394.8 seconds
# Starting search: ActionPathFinder (iteration=2454, hf=0.94, queue=184, seen=1080, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 261481 paths in 400.44 seconds
# Starting search: ActionPathFinder (iteration=2484, hf=0.95, queue=186, seen=1085, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 265519 paths in 405.93 seconds
# Starting search: ActionPathFinder (iteration=2514, hf=0.96, queue=177, seen=1087, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 268234 paths in 411.62 seconds
# Starting search: ActionPathFinder (iteration=2546, hf=0.97, queue=181, seen=1109, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 270595 paths in 416.87 seconds
# Starting search: ActionPathFinder (iteration=2565, hf=0.98, queue=172, seen=1112, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 272442 paths in 421.91 seconds
# Starting search: ActionPathFinder (iteration=2592, hf=0.99, queue=170, seen=1116, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 274832 paths in 427.58 seconds
# Starting search: ActionPathFinder (iteration=2652, hf=0.9, queue=154, seen=1137, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 278710 paths in 433.63 seconds
# Starting search: ActionPathFinder (iteration=2686, hf=0.91, queue=139, seen=1145, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 282890 paths in 439.51 seconds
# Starting search: ActionPathFinder (iteration=2723, hf=0.92, queue=150, seen=1148, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 286059 paths in 444.57 seconds
# Starting search: ActionPathFinder (iteration=2736, hf=0.93, queue=169, seen=1160, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 288160 paths in 449.68 seconds
# Starting search: ActionPathFinder (iteration=2787, hf=0.94, queue=182, seen=1167, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 291067 paths in 454.95 seconds
# Starting search: ActionPathFinder (iteration=2805, hf=0.95, queue=258, seen=1167, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 293960 paths in 460.09 seconds
# Starting search: ActionPathFinder (iteration=2824, hf=0.96, queue=255, seen=1167, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 297556 paths in 466.0 seconds
# Starting search: ActionPathFinder (iteration=2842, hf=0.97, queue=325, seen=1219, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 300903 paths in 471.67 seconds
# Starting search: ActionPathFinder (iteration=2876, hf=0.98, queue=318, seen=1226, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 304641 paths in 477.05 seconds
# Starting search: ActionPathFinder (iteration=2907, hf=0.99, queue=337, seen=1235, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 306774 paths in 482.38 seconds
# Starting search: ActionPathFinder (iteration=2973, hf=0.9, queue=298, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 310789 paths in 487.89 seconds
# Starting search: ActionPathFinder (iteration=2984, hf=0.91, queue=378, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 314410 paths in 492.93 seconds
# Starting search: ActionPathFinder (iteration=3029, hf=0.92, queue=412, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 316635 paths in 498.19 seconds
# Starting search: ActionPathFinder (iteration=3054, hf=0.93, queue=427, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 318499 paths in 503.48 seconds
# Starting search: ActionPathFinder (iteration=3099, hf=0.94, queue=413, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 322067 paths in 508.86 seconds
# Starting search: ActionPathFinder (iteration=3127, hf=0.95, queue=409, seen=1237, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 326609 paths in 516.08 seconds
# Starting search: ActionPathFinder (iteration=3145, hf=0.96, queue=401, seen=1238, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 330414 paths in 521.35 seconds
# Starting search: ActionPathFinder (iteration=3176, hf=0.97, queue=379, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 331898 paths in 526.73 seconds
# Starting search: ActionPathFinder (iteration=3202, hf=0.98, queue=364, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 334718 paths in 532.14 seconds
# Starting search: ActionPathFinder (iteration=3229, hf=0.99, queue=401, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 337307 paths in 537.87 seconds
# Starting search: ActionPathFinder (iteration=3256, hf=0.9, queue=411, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 341465 paths in 543.66 seconds
# Starting search: ActionPathFinder (iteration=3304, hf=0.91, queue=402, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 345011 paths in 549.55 seconds
# Starting search: ActionPathFinder (iteration=3334, hf=0.92, queue=392, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 349208 paths in 555.8 seconds
# Starting search: ActionPathFinder (iteration=3348, hf=0.93, queue=387, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 351614 paths in 561.01 seconds
# Starting search: ActionPathFinder (iteration=3388, hf=0.94, queue=375, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 353645 paths in 566.92 seconds
# Starting search: ActionPathFinder (iteration=3412, hf=0.95, queue=362, seen=1239, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 356029 paths in 572.21 seconds
# Starting search: ActionPathFinder (iteration=3438, hf=0.96, queue=376, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 359280 paths in 577.47 seconds
# Starting search: ActionPathFinder (iteration=3479, hf=0.97, queue=370, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 362234 paths in 583.17 seconds
# Starting search: ActionPathFinder (iteration=3496, hf=0.98, queue=379, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 366289 paths in 589.17 seconds
# Starting search: ActionPathFinder (iteration=3546, hf=0.99, queue=341, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 369519 paths in 594.78 seconds
# Starting search: ActionPathFinder (iteration=3575, hf=0.9, queue=360, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 372142 paths in 599.91 seconds
# Starting search: ActionPathFinder (iteration=3593, hf=0.91, queue=357, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 374452 paths in 605.59 seconds
# Starting search: ActionPathFinder (iteration=3613, hf=0.92, queue=354, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 378001 paths in 610.71 seconds
# Starting search: ActionPathFinder (iteration=3633, hf=0.93, queue=347, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 381214 paths in 616.05 seconds
# Starting search: ActionPathFinder (iteration=3663, hf=0.94, queue=351, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 384038 paths in 621.16 seconds
# Starting search: ActionPathFinder (iteration=3682, hf=0.95, queue=339, seen=1241, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 388496 paths in 627.13 seconds
# Starting search: ActionPathFinder (iteration=3706, hf=0.96, queue=326, seen=1242, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 392531 paths in 632.4 seconds
# Starting search: ActionPathFinder (iteration=3732, hf=0.97, queue=307, seen=1242, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 396389 paths in 637.9 seconds
# Starting search: ActionPathFinder (iteration=3748, hf=0.98, queue=299, seen=1242, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 400998 paths in 643.71 seconds
# Starting search: ActionPathFinder (iteration=3770, hf=0.99, queue=287, seen=1242, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 404241 paths in 648.99 seconds
# Starting search: ActionPathFinder (iteration=3799, hf=0.9, queue=268, seen=1244, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 409482 paths in 654.69 seconds
# Starting search: ActionPathFinder (iteration=3821, hf=0.91, queue=333, seen=1244, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 413335 paths in 660.62 seconds
# Starting search: ActionPathFinder (iteration=3868, hf=0.92, queue=341, seen=1245, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 418337 paths in 665.75 seconds
# Starting search: ActionPathFinder (iteration=3890, hf=0.93, queue=357, seen=1247, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 422897 paths in 671.9 seconds
# Starting search: ActionPathFinder (iteration=3935, hf=0.94, queue=316, seen=1247, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 426699 paths in 677.08 seconds
# Starting search: ActionPathFinder (iteration=3963, hf=0.95, queue=301, seen=1247, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 429918 paths in 682.77 seconds
# Starting search: ActionPathFinder (iteration=4001, hf=0.96, queue=275, seen=1249, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 434060 paths in 688.37 seconds
# Starting search: ActionPathFinder (iteration=4027, hf=0.97, queue=255, seen=1249, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 437761 paths in 693.43 seconds
# Starting search: ActionPathFinder (iteration=4054, hf=0.98, queue=229, seen=1249, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 439836 paths in 698.54 seconds
# Starting search: ActionPathFinder (iteration=4086, hf=0.99, queue=222, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 441917 paths in 703.88 seconds
# Starting search: ActionPathFinder (iteration=4119, hf=0.9, queue=220, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 445840 paths in 709.02 seconds
# Starting search: ActionPathFinder (iteration=4132, hf=0.91, queue=310, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 449893 paths in 714.28 seconds
# Starting search: ActionPathFinder (iteration=4144, hf=0.92, queue=391, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 454843 paths in 719.57 seconds
# Starting search: ActionPathFinder (iteration=4180, hf=0.93, queue=418, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 458984 paths in 724.69 seconds
# Starting search: ActionPathFinder (iteration=4203, hf=0.94, queue=432, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 462651 paths in 729.99 seconds
# Starting search: ActionPathFinder (iteration=4242, hf=0.95, queue=452, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 467510 paths in 735.73 seconds
# Starting search: ActionPathFinder (iteration=4253, hf=0.96, queue=446, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 472220 paths in 742.06 seconds
# Starting search: ActionPathFinder (iteration=4262, hf=0.97, queue=443, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 476944 paths in 747.73 seconds
# Starting search: ActionPathFinder (iteration=4289, hf=0.98, queue=419, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 480184 paths in 752.77 seconds
# Starting search: ActionPathFinder (iteration=4329, hf=0.99, queue=393, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 482343 paths in 758.36 seconds
# Starting search: ActionPathFinder (iteration=4352, hf=0.9, queue=381, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 486094 paths in 764.11 seconds
# Starting search: ActionPathFinder (iteration=4370, hf=0.91, queue=380, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 489739 paths in 769.4 seconds
# Starting search: ActionPathFinder (iteration=4400, hf=0.92, queue=394, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 492682 paths in 774.76 seconds
# Starting search: ActionPathFinder (iteration=4427, hf=0.93, queue=415, seen=1250, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 496344 paths in 780.56 seconds
# Starting search: ActionPathFinder (iteration=4456, hf=0.94, queue=470, seen=1251, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 499641 paths in 786.74 seconds
# Starting search: ActionPathFinder (iteration=4478, hf=0.95, queue=462, seen=1251, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 503505 paths in 793.51 seconds
# Starting search: ActionPathFinder (iteration=4492, hf=0.96, queue=461, seen=1251, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 506516 paths in 798.73 seconds
# Starting search: ActionPathFinder (iteration=4501, hf=0.97, queue=464, seen=1251, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Skipped 509876 paths in 804.5 seconds
# Starting search: ActionPathFinder (iteration=4527, hf=0.98, queue=465, seen=1252, last=ActionPath(g=438, h=3.0, hVelocity=SprintRight))
# Found path ActionPath(g=436, h=3.0, hVelocity=SprintRight) in 807.73 seconds after 4544 iterations and 512130 skipped paths
# Starting search: ActionPathFinder (iteration=4544, hf=0.99, queue=455, seen=1252, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 515284 paths in 813.52 seconds
# Starting search: ActionPathFinder (iteration=4598, hf=0.9, queue=451, seen=1252, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 518575 paths in 819.79 seconds
# Starting search: ActionPathFinder (iteration=4619, hf=0.91, queue=443, seen=1252, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 522119 paths in 825.8 seconds
# Starting search: ActionPathFinder (iteration=4633, hf=0.92, queue=449, seen=1252, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 525212 paths in 831.24 seconds
# Starting search: ActionPathFinder (iteration=4644, hf=0.93, queue=447, seen=1252, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 529019 paths in 837.38 seconds
# Starting search: ActionPathFinder (iteration=4666, hf=0.94, queue=431, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 532390 paths in 842.57 seconds
# Starting search: ActionPathFinder (iteration=4689, hf=0.95, queue=471, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 535696 paths in 848.87 seconds
# Starting search: ActionPathFinder (iteration=4714, hf=0.96, queue=462, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 538796 paths in 854.45 seconds
# Starting search: ActionPathFinder (iteration=4725, hf=0.97, queue=465, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 541813 paths in 859.46 seconds
# Starting search: ActionPathFinder (iteration=4735, hf=0.98, queue=461, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 544971 paths in 865.18 seconds
# Starting search: ActionPathFinder (iteration=4748, hf=0.99, queue=459, seen=1253, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 549002 paths in 871.08 seconds
# Starting search: ActionPathFinder (iteration=4777, hf=0.9, queue=438, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 551776 paths in 876.43 seconds
# Starting search: ActionPathFinder (iteration=4797, hf=0.91, queue=479, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 554913 paths in 881.78 seconds
# Starting search: ActionPathFinder (iteration=4814, hf=0.92, queue=503, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 558134 paths in 887.84 seconds
# Starting search: ActionPathFinder (iteration=4832, hf=0.93, queue=500, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 561182 paths in 892.86 seconds
# Starting search: ActionPathFinder (iteration=4843, hf=0.94, queue=494, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Skipped 564016 paths in 898.03 seconds
# Starting search: ActionPathFinder (iteration=4859, hf=0.95, queue=507, seen=1255, last=ActionPath(g=436, h=3.0, hVelocity=SprintRight))
# Found path ActionPath(g=434, h=3.0, hVelocity=SprintRight) in 898.04 seconds after 4861 iterations and 564130 skipped paths
# Starting search: ActionPathFinder (iteration=4861, hf=0.96, queue=508, seen=1255, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 567219 paths in 903.36 seconds
# Starting search: ActionPathFinder (iteration=4889, hf=0.97, queue=486, seen=1255, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 571256 paths in 909.13 seconds
# Starting search: ActionPathFinder (iteration=4925, hf=0.98, queue=456, seen=1255, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 574655 paths in 915.05 seconds
# Starting search: ActionPathFinder (iteration=4974, hf=0.99, queue=413, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 578098 paths in 921.89 seconds
# Starting search: ActionPathFinder (iteration=5008, hf=0.9, queue=388, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 582802 paths in 927.72 seconds
# Starting search: ActionPathFinder (iteration=5022, hf=0.91, queue=387, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 586330 paths in 933.57 seconds
# Starting search: ActionPathFinder (iteration=5055, hf=0.92, queue=379, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 589390 paths in 939.76 seconds
# Starting search: ActionPathFinder (iteration=5084, hf=0.93, queue=376, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 591645 paths in 945.73 seconds
# Starting search: ActionPathFinder (iteration=5122, hf=0.94, queue=378, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 594557 paths in 951.06 seconds
# Starting search: ActionPathFinder (iteration=5141, hf=0.95, queue=405, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 597868 paths in 956.26 seconds
# Starting search: ActionPathFinder (iteration=5167, hf=0.96, queue=393, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 601017 paths in 962.1 seconds
# Starting search: ActionPathFinder (iteration=5203, hf=0.97, queue=368, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 603715 paths in 967.16 seconds
# Starting search: ActionPathFinder (iteration=5223, hf=0.98, queue=366, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 607142 paths in 972.73 seconds
# Starting search: ActionPathFinder (iteration=5258, hf=0.99, queue=351, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 610526 paths in 977.97 seconds
# Starting search: ActionPathFinder (iteration=5269, hf=0.9, queue=346, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 614809 paths in 983.43 seconds
# Starting search: ActionPathFinder (iteration=5291, hf=0.91, queue=358, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 618948 paths in 988.83 seconds
# Starting search: ActionPathFinder (iteration=5323, hf=0.92, queue=388, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 622981 paths in 994.07 seconds
# Starting search: ActionPathFinder (iteration=5369, hf=0.93, queue=377, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 628096 paths in 999.87 seconds
# Starting search: ActionPathFinder (iteration=5383, hf=0.94, queue=367, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 631347 paths in 1005.08 seconds
# Starting search: ActionPathFinder (iteration=5397, hf=0.95, queue=363, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 634627 paths in 1010.25 seconds
# Starting search: ActionPathFinder (iteration=5417, hf=0.96, queue=360, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 638615 paths in 1015.49 seconds
# Starting search: ActionPathFinder (iteration=5457, hf=0.97, queue=339, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 643206 paths in 1021.66 seconds
# Starting search: ActionPathFinder (iteration=5488, hf=0.98, queue=316, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 646882 paths in 1027.26 seconds
# Starting search: ActionPathFinder (iteration=5502, hf=0.99, queue=310, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 651058 paths in 1033.25 seconds
# Starting search: ActionPathFinder (iteration=5540, hf=0.9, queue=287, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 654435 paths in 1038.35 seconds
# Starting search: ActionPathFinder (iteration=5582, hf=0.91, queue=285, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 658021 paths in 1043.59 seconds
# Starting search: ActionPathFinder (iteration=5625, hf=0.92, queue=266, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 662716 paths in 1049.54 seconds
# Starting search: ActionPathFinder (iteration=5645, hf=0.93, queue=254, seen=1267, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 665910 paths in 1055.16 seconds
# Starting search: ActionPathFinder (iteration=5696, hf=0.94, queue=235, seen=1268, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 668055 paths in 1060.63 seconds
# Starting search: ActionPathFinder (iteration=5724, hf=0.95, queue=237, seen=1268, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 669726 paths in 1065.84 seconds
# Starting search: ActionPathFinder (iteration=5760, hf=0.96, queue=217, seen=1268, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 671549 paths in 1071.26 seconds
# Starting search: ActionPathFinder (iteration=5795, hf=0.97, queue=210, seen=1270, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 673934 paths in 1076.48 seconds
# Starting search: ActionPathFinder (iteration=5846, hf=0.98, queue=203, seen=1272, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 675863 paths in 1081.73 seconds
# Starting search: ActionPathFinder (iteration=5926, hf=0.99, queue=145, seen=1273, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 682263 paths in 1087.79 seconds
# Starting search: ActionPathFinder (iteration=5983, hf=0.9, queue=157, seen=1312, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 687393 paths in 1093.12 seconds
# Starting search: ActionPathFinder (iteration=6006, hf=0.91, queue=148, seen=1319, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 690615 paths in 1098.73 seconds
# Starting search: ActionPathFinder (iteration=6026, hf=0.92, queue=164, seen=1323, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 693153 paths in 1104.68 seconds
# Starting search: ActionPathFinder (iteration=6064, hf=0.93, queue=146, seen=1329, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 696694 paths in 1110.28 seconds
# Starting search: ActionPathFinder (iteration=6086, hf=0.94, queue=149, seen=1333, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 698610 paths in 1115.55 seconds
# Starting search: ActionPathFinder (iteration=6125, hf=0.95, queue=145, seen=1333, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 703196 paths in 1121.28 seconds
# Starting search: ActionPathFinder (iteration=6157, hf=0.96, queue=117, seen=1334, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 708208 paths in 1126.57 seconds
# Starting search: ActionPathFinder (iteration=6183, hf=0.97, queue=99, seen=1340, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 712839 paths in 1131.79 seconds
# Starting search: ActionPathFinder (iteration=6203, hf=0.98, queue=92, seen=1347, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 719739 paths in 1137.21 seconds
# Starting search: ActionPathFinder (iteration=6249, hf=0.99, queue=58, seen=1353, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 725712 paths in 1142.79 seconds
# Starting search: ActionPathFinder (iteration=6268, hf=0.9, queue=45, seen=1355, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 729254 paths in 1147.88 seconds
# Starting search: ActionPathFinder (iteration=6282, hf=0.91, queue=44, seen=1358, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Skipped 734522 paths in 1153.68 seconds
# Starting search: ActionPathFinder (iteration=6307, hf=0.92, queue=23, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.93, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.94, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.95, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.96, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.97, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.98, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# Starting search: ActionPathFinder (iteration=6330, hf=0.99, queue=0, seen=1359, last=ActionPath(g=434, h=3.0, hVelocity=SprintRight))
# PlotTensor: 0 106

# %%
pathFinder.plotAnimation(fps=30, skipFrames=20)
break
# Out:
# 295
# PlotTensor: 0 106
#   Cell In[7], line 2
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
df = pathFinder.executePath(pathFinder.foundPaths[0])
# Out:
# Sending path to the game...
# Starting UCH: "D:/Development/mai/master-thesis/UltimateChickenHorse/UltimateChickenHorse.exe"
# Waiting for response...
# Waiting for response...
# PlotTensor: 0 106

# %%
dfx = df
dfx = dfx[(dfx.Segment >= 5) & (dfx.Segment < 8)]
dfx #.head(100)
